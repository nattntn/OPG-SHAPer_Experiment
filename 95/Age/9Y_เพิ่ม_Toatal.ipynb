# %% [markdown]
# <a href="https://colab.research.google.com/github/nattntn/OPG-SHAPer_WebApp/blob/main/95/Age/9Y_%E0%B9%80%E0%B8%9E%E0%B8%B4%E0%B9%88%E0%B8%A1_Toatal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import data set (เรียกใช้ CSV)

# %%
import pandas as pd
import shutil
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import io

# %%
#เชื่อม google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # ตารางผลการทำนายการประมาณค่าอายุ

# %%
test_age = pd.read_csv (r'/content/gdrive/My Drive/Tooth_Shap_GPT/Deep_tooth/OPG_SHAPer/Data/test_age_all.csv')
test_age = test_age.iloc[:,1:]
print(test_age.shape)
test_age
# Out:
# (291, 13)
#      Age(year) Gender Folder_type Folder_name  \
# 0            7      F      Normal        Both
# 1            7      F      Normal        Both
# 2            7      F      Normal        Both
# 3            7      F      Normal        Both
# 4            7      F      Normal        Both
# ..         ...    ...         ...         ...
# 286         22      M      Normal        Both
# 287         22      M      Normal          Rt
# 288         23      M      Normal          Rt
# 289         25      F      Normal          Lt
# 290         25      M      Normal        Both
#
#                                              Path_Name      Filename  \
# 0    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       V69.jpg
# 1    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipV69.jpg
# 2    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipV70.jpg
# 3    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       V74.jpg
# 4    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipV74.jpg
# ..                                                 ...           ...
# 286  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipU422.jpg
# 287  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      U292.jpg
# 288  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      E356.jpg
# 289  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipJ71.jpg
# 290  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ456.jpg
#
#      Gender_Class Gender_Predict  Age_predict  Age_predict_int  \
# 0               0         Female     7.423399                7
# 1               0         Female     7.415316                7
# 2               0         Female     7.492433                7
# 3               0         Female     7.343049                7
# 4               0         Female     7.095627                7
# ..            ...            ...          ...              ...
# 286             1           Male    22.010904               22
# 287             1           Male    21.844440               22
# 288             1           Male    22.836693               23
# 289             0         Female    24.869873               25
# 290             1           Male    24.887615               25
#
#      Gender_predict Gender_predict_str  Gender_predict_int
# 0          0.005142             Female                 0.0
# 1          0.046188             Female                 0.0
# 2          0.000020             Female                 0.0
# 3          0.020910             Female                 0.0
# 4          0.003455             Female                 0.0
# ..              ...                ...                 ...
# 286        0.999999               Male                 1.0
# 287        0.999998               Male                 1.0
# 288        0.999958               Male                 1.0
# 289        1.000000               Male                 1.0
# 290        0.999998               Male                 1.0
#
# [291 rows x 13 columns]

# %% [markdown]
# # ผลวิเคราะห์อายุ 291 ภาพ

# %% [markdown]
# ## positive (299 ภาพ)

# %%
positive_age = pd.read_csv (r'/content/gdrive/My Drive/Tooth_Shap_GPT/Deep_tooth/OPG_SHAPer/Result/Age/95_percentie/data/positive_age_final.csv')
positive_age = positive_age.iloc[:,1:]
print(positive_age.shape)
positive_age
# Out:
# (1872, 11)
#             ymin        xmax        ymax  confidence  class  \
# 0     318.575717  347.501520  375.691668    0.949560   13.0
# 1     295.167587  268.920413  389.243537    0.901955    3.0
# 2     217.678585  455.198303  291.415632    0.888440   14.0
# 3     221.778334  218.693814  295.307760    0.808703   16.0
# 4     326.283959  334.644869  384.783243    0.948097   13.0
# ...          ...         ...         ...         ...    ...
# 1867  199.414048  448.287460  313.925973    0.894291   19.0
# 1868  313.911832  446.391320  409.391832    0.855322   12.0
# 1869  209.775011  382.026562  300.378426    0.854067   18.0
# 1870  321.158428  469.688801  414.762481    0.825680    9.0
# 1871  197.901750  417.333175  311.158844    0.789516   14.0
#
#                            name      filename Age(year) Gender  \
# 0            Lower Second Molar       V69.jpg        7Y      F
# 1              Mandibular angle       V69.jpg        7Y      F
# 2          Upper First Premolar       V69.jpg        7Y      F
# 3     Posterior border of Ramus       V69.jpg        7Y      F
# 4            Lower Second Molar   FlipV69.jpg        7Y      F
# ...                         ...           ...       ...    ...
# 1867               Upper Canine  FlipJ456.jpg       25Y      M
# 1868       Lower First Premolar  FlipJ456.jpg       25Y      M
# 1869      Upper Second Premolar  FlipJ456.jpg       25Y      M
# 1870               Lower Canine  FlipJ456.jpg       25Y      M
# 1871       Upper First Premolar  FlipJ456.jpg       25Y      M
#
#                                           path_name_ori  \
# 0     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 1     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 2     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 3     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 4     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# ...                                                 ...
# 1867  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 1868  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 1869  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 1870  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 1871  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
#
#                                            path_pos_img
# 0     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 1     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 2     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 3     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 4     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# ...                                                 ...
# 1867  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 1868  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 1869  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 1870  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 1871  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
#
# [1872 rows x 11 columns]

# %%
print(len(positive_age['filename'].unique()))
# positive_age['filename'].unique()
# Out:
# 289

# %%
positive_age['name'].value_counts()
# Out:
# name
# Lower Second Molar           218
# Lower Third Molar            178
# Upper Second Molar           176
# Lower First Molar            136
# Upper Third Molar            124
# Upper Canine                 122
# Upper Second Premolar        116
# Upper First Premolar         115
# Upper First Molar            111
# Lower Second Premolar        110
# Mandibular angle             102
# Condyle                       97
# Upper Lateral Incisor         65
# Posterior border of Ramus     64
# Upper Central Incisor         60
# Lower First Premolar          45
# Lower Canine                  13
# Lower Central Incisor          9
# Lower Lateral Incisor          8
# Nasal                          3
# Name: count, dtype: int64

# %%
name_count_pos = {}
list_pos = positive_age['name'].tolist()
# Iterate over each list of dictionaries
for name in list_pos:
    if name in name_count_pos:
       name_count_pos[name] += 1
    else:
       name_count_pos[name] = 1

# Sort the name_count_pos dictionary by count of occurrences (descending order)
sorted_names = sorted(name_count_pos.items(), key=lambda x: x[1], reverse=True)

# Print a summary of all unique names and their occurrence counts
print("Unique names and their occurrences in positive SHAP values area:")
# Print the total number of unique names in the dataset
total_unique_names = len(sorted_names)
print(f"Total Unique Names: {total_unique_names}")

for i, (name, count) in enumerate(sorted_names, start=1):
    print(f"{i}. {name}: {count}/{len(positive_age['filename'].unique())} ({(count / len(positive_age['filename'].unique())):.2%})")#of total
# Out:
# Unique names and their occurrences in positive SHAP values area:
# Total Unique Names: 20
# 1. Lower Second Molar: 218/289 (75.43%)
# 2. Lower Third Molar: 178/289 (61.59%)
# 3. Upper Second Molar: 176/289 (60.90%)
# 4. Lower First Molar: 136/289 (47.06%)
# 5. Upper Third Molar: 124/289 (42.91%)
# 6. Upper Canine: 122/289 (42.21%)
# 7. Upper Second Premolar: 116/289 (40.14%)
# 8. Upper First Premolar: 115/289 (39.79%)
# 9. Upper First Molar: 111/289 (38.41%)
# 10. Lower Second Premolar: 110/289 (38.06%)
# 11. Mandibular angle: 102/289 (35.29%)
# 12. Condyle: 97/289 (33.56%)
# 13. Upper Lateral Incisor: 65/289 (22.49%)
# 14. Posterior border of Ramus: 64/289 (22.15%)
# 15. Upper Central Incisor: 60/289 (20.76%)
# 16. Lower First Premolar: 45/289 (15.57%)
# 17. Lower Canine: 13/289 (4.50%)
# 18. Lower Central Incisor: 9/289 (3.11%)
# 19. Lower Lateral Incisor: 8/289 (2.77%)
# 20. Nasal: 3/289 (1.04%)

# %%
# Sample DataFrame for demonstration
import pandas as pd

name_count_pos = {}
name_files = {}

# List of names
list_pos = positive_age['name'].tolist()
# List of filenames
filenames = positive_age['filename'].tolist()

# Iterate over each name and corresponding filename
for name, filename in zip(list_pos, filenames):
    if name in name_count_pos:
        name_count_pos[name] += 1
        name_files[name].append(filename)
    else:
        name_count_pos[name] = 1
        name_files[name] = [filename]

# Sort the name_count_pos dictionary by count of occurrences (descending order)
sorted_names = sorted(name_count_pos.items(), key=lambda x: x[1], reverse=True)

# Print a summary of all unique names and their occurrence counts
print("Unique names and their occurrences in positive SHAP values area:")
# Print the total number of unique names in the dataset
total_unique_names = len(sorted_names)
print(f"Total Unique Names: {total_unique_names}")

for i, (name, count) in enumerate(sorted_names, start=1):
    unique_filenames = len(set(name_files[name]))  # Calculate unique filenames
    print(f"{i}. {name}: {count}/{len(positive_age['filename'].unique())} ({(count / len(positive_age['filename'].unique())):.2%}) of total")
    print(f"    Filenames: {name_files[name]}")
# Out:
# Unique names and their occurrences in positive SHAP values area:
# Total Unique Names: 20
# 1. Lower Second Molar: 218/289 (75.43%) of total
#     Filenames: ['V69.jpg', 'FlipV69.jpg', 'V74.jpg', 'V75.jpg', 'FlipV75.jpg', 'FlipV79.jpg', 'FlipV85.jpg', 'V68.jpg', 'FlipV68.jpg', 'V88.jpg', 'VV85.jpg', 'FlipVV85.jpg', 'VV88.jpg', 'FlipVV88.jpg', 'VV89.jpg', 'FlipVV89.jpg', 'VV91.jpg', 'VV94.jpg', 'FlipVV98.jpg', 'VV100.jpg', 'FlipVV100.jpg', 'VV104.jpg', 'FlipVV104.jpg', 'FlipVV108.jpg', 'VV84.jpg', 'FlipP72.jpg', 'P74.jpg', 'FlipP74.jpg', 'P75.jpg', 'FlipP75.jpg', 'P78.jpg', 'FlipP79.jpg', 'FlipP81.jpg', 'FlipP77.jpg', 'FlipP82.jpg', 'PP70.jpg', 'PP75.jpg', 'FlipPP75.jpg', 'FlipPP76.jpg', 'PP79.jpg', 'PP80.jpg', 'FlipPP80.jpg', 'PP83.jpg', 'FlipPP83.jpg', 'FlipPP77.jpg', 'PP82.jpg', 'FlipPP82.jpg', 'PP78.jpg', 'W84.jpg', 'FlipW87.jpg', 'W91.jpg', 'FlipW91.jpg', 'FlipW92.jpg', 'W95.jpg', 'W88.jpg', 'W86.jpg', 'FlipW86.jpg', 'W97.jpg', 'FlipW97.jpg', 'FlipW90.jpg', 'WW75.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'WW81.jpg', 'FlipWW81.jpg', 'WW80.jpg', 'WW82.jpg', 'FlipWW82.jpg', 'WW88.jpg', 'FlipWW88.jpg', 'FlipWW84.jpg', 'H79.jpg', 'FlipH79.jpg', 'H83.jpg', 'FlipH83.jpg', 'H86.jpg', 'H88.jpg', 'H80.jpg', 'FlipH80.jpg', 'FlipH76.jpg', 'HH82.jpg', 'FlipHH82.jpg', 'HH87.jpg', 'FlipHH87.jpg', 'FlipHH94.jpg', 'FlipHH95.jpg', 'HH96.jpg', 'D79.jpg', 'FlipD79.jpg', 'FlipD89.jpg', 'D87.jpg', 'FlipD87.jpg', 'FlipD82.jpg', 'FlipD80.jpg', 'DD100.jpg', 'FlipDD100.jpg', 'FlipDD108.jpg', 'DD113.jpg', 'FlipDD113.jpg', 'FlipDD115.jpg', 'DD99.jpg', 'DD98.jpg', 'D86.jpg', 'O85.jpg', 'FlipO85.jpg', 'FlipO89.jpg', 'O90.jpg', 'FlipO90.jpg', 'O93.jpg', 'O94.jpg', 'O97.jpg', 'OO103.jpg', 'OO106.jpg', 'FlipOO111.jpg', 'FlipOO116.jpg', 'OO117.jpg', 'FlipOO112.jpg', 'FlipOO118.jpg', 'FlipOO101.jpg', 'OO98.jpg', 'G111.jpg', 'FlipG111.jpg', 'G83.jpg', 'G103.jpg', 'G108.jpg', 'GG117.jpg', 'FlipGG120.jpg', 'GG121.jpg', 'FlipGG121.jpg', 'GG124.jpg', 'FlipGG124.jpg', 'FlipGG125.jpg', 'GG129.jpg', 'FlipGG129.jpg', 'FlipGG132.jpg', 'GG137.jpg', 'FlipGG138.jpg', 'GG140.jpg', 'Y96.jpg', 'FlipY96.jpg', 'Y98.jpg', 'Y101.jpg', 'FlipY101.jpg', 'Y188.jpg', 'FlipY188.jpg', 'Y190.jpg', 'FlipY190.jpg', 'Y236.jpg', 'Y278.jpg', 'FlipY278.jpg', 'FlipY95.jpg', 'FlipY187.jpg', 'Y100.jpg', 'B153.jpg', 'B166.jpg', 'FlipB166.jpg', 'FlipB317.jpg', 'B332.jpg', 'T177.jpg', 'FlipT178.jpg', 'T181.jpg', 'FlipT198.jpg', 'FlipT163.jpg', 'FlipT228.jpg', 'T231.jpg', 'FlipT231.jpg', 'T250.jpg', 'FlipT250.jpg', 'K177.jpg', 'K183.jpg', 'FlipK183.jpg', 'K186.jpg', 'FlipK186.jpg', 'FlipK170.jpg', 'FlipK257.jpg', 'K269.jpg', 'FlipK269.jpg', 'K292.jpg', 'FlipK293.jpg', 'K319.jpg', 'FlipK319.jpg', 'FlipK270.jpg', 'S159.jpg', 'FlipS165.jpg', 'S195.jpg', 'FlipS189.jpg', 'FlipS36.jpg', 'S349.jpg', 'S356.jpg', 'FlipS359.jpg', 'FlipL250.jpg', 'FlipL236.jpg', 'FlipL369.jpg', 'FlipL393.jpg', 'L405.jpg', 'L409.jpg', 'FlipL409.jpg', 'FlipL401.jpg', 'Q250.jpg', 'FlipQ253.jpg', 'FlipQ56.jpg', 'Q402.jpg', 'Q409.jpg', 'FlipQ412.jpg', 'FlipN168.jpg', 'N182.jpg', 'FlipN405.jpg', 'FlipN406.jpg', 'N419.jpg', 'FlipN426.jpg', 'FlipN415.jpg', 'FlipN416.jpg', 'FlipU230.jpg', 'U414.jpg', 'FlipU422.jpg', 'U292.jpg', 'FlipJ456.jpg']
# 2. Lower Third Molar: 178/289 (61.59%) of total
#     Filenames: ['FlipV79.jpg', 'VV91.jpg', 'VV94.jpg', 'FlipVV108.jpg', 'FlipP74.jpg', 'P75.jpg', 'P78.jpg', 'FlipP78.jpg', 'FlipP77.jpg', 'FlipPP80.jpg', 'PP83.jpg', 'FlipPP83.jpg', 'PP82.jpg', 'FlipPP82.jpg', 'PP78.jpg', 'W84.jpg', 'W92.jpg', 'FlipW92.jpg', 'W95.jpg', 'FlipW95.jpg', 'W86.jpg', 'FlipW86.jpg', 'FlipW90.jpg', 'FlipWW78.jpg', 'FlipWW79.jpg', 'WW81.jpg', 'FlipWW81.jpg', 'WW85.jpg', 'WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg', 'FlipWW82.jpg', 'WW88.jpg', 'FlipWW88.jpg', 'FlipWW84.jpg', 'H79.jpg', 'FlipH79.jpg', 'H84.jpg', 'H86.jpg', 'H88.jpg', 'H80.jpg', 'FlipH80.jpg', 'FlipH76.jpg', 'HH82.jpg', 'FlipHH82.jpg', 'HH87.jpg', 'FlipHH87.jpg', 'HH94.jpg', 'FlipHH94.jpg', 'FlipHH95.jpg', 'HH96.jpg', 'D79.jpg', 'FlipD89.jpg', 'D87.jpg', 'DD100.jpg', 'DD108.jpg', 'FlipDD115.jpg', 'DD99.jpg', 'DD98.jpg', 'D86.jpg', 'O85.jpg', 'FlipO85.jpg', 'FlipO89.jpg', 'O90.jpg', 'FlipO90.jpg', 'O93.jpg', 'O94.jpg', 'OO106.jpg', 'FlipOO111.jpg', 'FlipOO116.jpg', 'OO117.jpg', 'FlipOO101.jpg', 'G84.jpg', 'G111.jpg', 'FlipG111.jpg', 'FlipG83.jpg', 'G105.jpg', 'G103.jpg', 'G108.jpg', 'GG117.jpg', 'FlipGG120.jpg', 'GG121.jpg', 'FlipGG121.jpg', 'GG124.jpg', 'FlipGG125.jpg', 'GG129.jpg', 'GG132.jpg', 'FlipGG132.jpg', 'GG140.jpg', 'Y96.jpg', 'FlipY96.jpg', 'Y98.jpg', 'Y101.jpg', 'FlipY101.jpg', 'Y188.jpg', 'FlipY188.jpg', 'Y190.jpg', 'FlipY190.jpg', 'Y236.jpg', 'Y278.jpg', 'FlipY278.jpg', 'FlipY95.jpg', 'FlipY187.jpg', 'Y100.jpg', 'B153.jpg', 'B157.jpg', 'FlipB157.jpg', 'B166.jpg', 'FlipB166.jpg', 'B175.jpg', 'FlipB317.jpg', 'B332.jpg', 'T177.jpg', 'FlipT178.jpg', 'T181.jpg', 'FlipT192.jpg', 'FlipT198.jpg', 'FlipT163.jpg', 'T231.jpg', 'FlipT231.jpg', 'T250.jpg', 'FlipT250.jpg', 'K157.jpg', 'K176.jpg', 'K177.jpg', 'FlipK183.jpg', 'K186.jpg', 'FlipK186.jpg', 'FlipK170.jpg', 'K269.jpg', 'FlipK269.jpg', 'K292.jpg', 'FlipK293.jpg', 'FlipK326.jpg', 'FlipK270.jpg', 'S159.jpg', 'FlipS158.jpg', 'FlipS160.jpg', 'S195.jpg', 'FlipS191.jpg', 'S349.jpg', 'S356.jpg', 'FlipS359.jpg', 'L240.jpg', 'FlipL250.jpg', 'L262.jpg', 'FlipL236.jpg', 'FlipL369.jpg', 'FlipL393.jpg', 'L405.jpg', 'FlipL406.jpg', 'L409.jpg', 'FlipL409.jpg', 'FlipL401.jpg', 'FlipQ253.jpg', 'FlipQ56.jpg', 'Q402.jpg', 'Q409.jpg', 'FlipQ412.jpg', 'N158.jpg', 'FlipN167.jpg', 'FlipN168.jpg', 'N182.jpg', 'FlipN182.jpg', 'N405.jpg', 'FlipN405.jpg', 'FlipN406.jpg', 'N419.jpg', 'FlipN426.jpg', 'FlipN415.jpg', 'FlipN424.jpg', 'FlipN416.jpg', 'N408.jpg', 'FlipU298.jpg', 'FlipU230.jpg', 'U414.jpg', 'U292.jpg', 'E356.jpg']
# 3. Upper Second Molar: 176/289 (60.90%) of total
#     Filenames: ['FlipV69.jpg', 'V75.jpg', 'FlipV79.jpg', 'V68.jpg', 'V67.jpg', 'VV85.jpg', 'FlipVV85.jpg', 'VV89.jpg', 'FlipVV89.jpg', 'VV94.jpg', 'FlipVV98.jpg', 'VV100.jpg', 'FlipVV100.jpg', 'VV104.jpg', 'FlipVV104.jpg', 'FlipVV108.jpg', 'P70.jpg', 'P75.jpg', 'FlipP75.jpg', 'P76.jpg', 'FlipP77.jpg', 'FlipP82.jpg', 'FlipPP75.jpg', 'FlipPP76.jpg', 'FlipPP79.jpg', 'PP80.jpg', 'FlipPP80.jpg', 'PP83.jpg', 'FlipPP83.jpg', 'FlipPP77.jpg', 'PP82.jpg', 'FlipPP82.jpg', 'PP78.jpg', 'W84.jpg', 'FlipW91.jpg', 'W92.jpg', 'FlipW92.jpg', 'W95.jpg', 'FlipW95.jpg', 'W88.jpg', 'W86.jpg', 'W97.jpg', 'FlipW97.jpg', 'WW75.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'FlipWW79.jpg', 'WW81.jpg', 'FlipWW81.jpg', 'WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg', 'FlipWW82.jpg', 'WW88.jpg', 'FlipWW88.jpg', 'FlipW96.jpg', 'H79.jpg', 'FlipH79.jpg', 'FlipH83.jpg', 'H84.jpg', 'H86.jpg', 'H88.jpg', 'H80.jpg', 'FlipH80.jpg', 'FlipH76.jpg', 'HH87.jpg', 'FlipHH87.jpg', 'HH96.jpg', 'D79.jpg', 'FlipD79.jpg', 'D89.jpg', 'D87.jpg', 'FlipD87.jpg', 'FlipD82.jpg', 'FlipD80.jpg', 'DD100.jpg', 'FlipDD100.jpg', 'DD108.jpg', 'FlipDD108.jpg', 'DD113.jpg', 'FlipDD113.jpg', 'FlipDD115.jpg', 'DD99.jpg', 'DD98.jpg', 'O85.jpg', 'FlipO85.jpg', 'FlipO89.jpg', 'O90.jpg', 'O93.jpg', 'O94.jpg', 'OO103.jpg', 'OO106.jpg', 'OO117.jpg', 'FlipOO118.jpg', 'G84.jpg', 'G111.jpg', 'FlipG111.jpg', 'G105.jpg', 'FlipGG120.jpg', 'FlipGG121.jpg', 'FlipGG124.jpg', 'GG129.jpg', 'FlipGG129.jpg', 'FlipGG132.jpg', 'Y96.jpg', 'FlipY96.jpg', 'Y98.jpg', 'FlipY101.jpg', 'Y188.jpg', 'FlipY188.jpg', 'FlipY278.jpg', 'FlipY95.jpg', 'FlipY187.jpg', 'Y100.jpg', 'B153.jpg', 'FlipB157.jpg', 'B166.jpg', 'FlipB308.jpg', 'B332.jpg', 'T181.jpg', 'FlipT198.jpg', 'FlipT228.jpg', 'T231.jpg', 'FlipT231.jpg', 'T250.jpg', 'K157.jpg', 'K176.jpg', 'FlipK183.jpg', 'K186.jpg', 'FlipK186.jpg', 'FlipK170.jpg', 'FlipK257.jpg', 'K269.jpg', 'FlipK269.jpg', 'K292.jpg', 'FlipK293.jpg', 'K319.jpg', 'FlipK319.jpg', 'FlipK326.jpg', 'FlipS158.jpg', 'FlipS165.jpg', 'S195.jpg', 'FlipS191.jpg', 'FlipS36.jpg', 'S349.jpg', 'FlipS359.jpg', 'L240.jpg', 'FlipL250.jpg', 'L262.jpg', 'FlipL236.jpg', 'FlipL393.jpg', 'L405.jpg', 'FlipL406.jpg', 'L409.jpg', 'FlipQ253.jpg', 'FlipQ56.jpg', 'Q415.jpg', 'Q409.jpg', 'FlipQ412.jpg', 'N158.jpg', 'FlipN168.jpg', 'N182.jpg', 'FlipN182.jpg', 'N184.jpg', 'FlipN184.jpg', 'N405.jpg', 'FlipN406.jpg', 'N419.jpg', 'FlipN426.jpg', 'FlipN415.jpg', 'FlipN424.jpg', 'FlipU298.jpg', 'FlipU230.jpg', 'U414.jpg', 'U292.jpg', 'FlipJ456.jpg']
# 4. Lower First Molar: 136/289 (47.06%) of total
#     Filenames: ['V75.jpg', 'V79.jpg', 'V67.jpg', 'FlipV67.jpg', 'V88.jpg', 'VV89.jpg', 'FlipVV89.jpg', 'VV104.jpg', 'P70.jpg', 'P72.jpg', 'P74.jpg', 'P75.jpg', 'P78.jpg', 'FlipP79.jpg', 'FlipP81.jpg', 'FlipP82.jpg', 'PP70.jpg', 'PP75.jpg', 'FlipPP76.jpg', 'PP79.jpg', 'FlipPP80.jpg', 'PP83.jpg', 'FlipPP77.jpg', 'PP78.jpg', 'FlipW87.jpg', 'W91.jpg', 'FlipW91.jpg', 'FlipW92.jpg', 'W95.jpg', 'W88.jpg', 'W97.jpg', 'FlipW97.jpg', 'FlipW90.jpg', 'FlipWW75.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'WW88.jpg', 'H79.jpg', 'H83.jpg', 'H86.jpg', 'H88.jpg', 'FlipH80.jpg', 'FlipH76.jpg', 'HH82.jpg', 'FlipHH82.jpg', 'HH87.jpg', 'FlipHH87.jpg', 'FlipHH95.jpg', 'HH96.jpg', 'D79.jpg', 'D89.jpg', 'FlipD89.jpg', 'D87.jpg', 'FlipD80.jpg', 'DD100.jpg', 'FlipDD100.jpg', 'DD113.jpg', 'FlipDD113.jpg', 'DD115.jpg', 'FlipDD115.jpg', 'D86.jpg', 'O85.jpg', 'FlipO85.jpg', 'FlipO89.jpg', 'O90.jpg', 'FlipO90.jpg', 'O93.jpg', 'O94.jpg', 'FlipO94.jpg', 'O97.jpg', 'OO97.jpg', 'OO103.jpg', 'OO106.jpg', 'FlipOO111.jpg', 'FlipOO116.jpg', 'OO117.jpg', 'FlipOO112.jpg', 'FlipOO118.jpg', 'FlipOO101.jpg', 'OO98.jpg', 'G83.jpg', 'G108.jpg', 'GG117.jpg', 'FlipGG120.jpg', 'GG121.jpg', 'FlipGG121.jpg', 'GG124.jpg', 'FlipGG125.jpg', 'GG129.jpg', 'FlipGG129.jpg', 'GG132.jpg', 'FlipGG132.jpg', 'GG137.jpg', 'FlipGG138.jpg', 'GG140.jpg', 'Y96.jpg', 'Y98.jpg', 'FlipY99.jpg', 'Y101.jpg', 'Y190.jpg', 'FlipY190.jpg', 'Y236.jpg', 'FlipY95.jpg', 'Y100.jpg', 'B153.jpg', 'B162.jpg', 'FlipB166.jpg', 'FlipT198.jpg', 'T231.jpg', 'FlipT231.jpg', 'K177.jpg', 'K183.jpg', 'FlipK183.jpg', 'FlipK257.jpg', 'FlipK269.jpg', 'K292.jpg', 'K319.jpg', 'FlipK270.jpg', 'S159.jpg', 'FlipS158.jpg', 'FlipS189.jpg', 'FlipS36.jpg', 'FlipL236.jpg', 'FlipL369.jpg', 'L405.jpg', 'L409.jpg', 'Q409.jpg', 'N158.jpg', 'FlipN168.jpg', 'N182.jpg', 'FlipN416.jpg', 'FlipU230.jpg', 'U414.jpg', 'U292.jpg', 'FlipJ456.jpg']
#
        'count': count,
        'total_files': len(positive_age['filename'].unique()),
        'percentage': (count / len(positive_age['filename'].unique())) * 100,
        'filenames': name_files[name]
    })

summary_df = pd.DataFrame(summary_data)
summary_df
# Out:
#                          name  count  total_files  percentage  \
# 0          Lower Second Molar    218          289   75.432526
# 1           Lower Third Molar    178          289   61.591696
# 2          Upper Second Molar    176          289   60.899654
# 3           Lower First Molar    136          289   47.058824
# 4           Upper Third Molar    124          289   42.906574
# 5                Upper Canine    122          289   42.214533
# 6       Upper Second Premolar    116          289   40.138408
# 7        Upper First Premolar    115          289   39.792388
# 8           Upper First Molar    111          289   38.408304
# 9       Lower Second Premolar    110          289   38.062284
# 10           Mandibular angle    102          289   35.294118
# 11                    Condyle     97          289   33.564014
# 12      Upper Lateral Incisor     65          289   22.491349
# 13  Posterior border of Ramus     64          289   22.145329
# 14      Upper Central Incisor     60          289   20.761246
# 15       Lower First Premolar     45          289   15.570934
# 16               Lower Canine     13          289    4.498270
# 17      Lower Central Incisor      9          289    3.114187
# 18      Lower Lateral Incisor      8          289    2.768166
# 19                      Nasal      3          289    1.038062
#
#                                             filenames
# 0   [V69.jpg, FlipV69.jpg, V74.jpg, V75.jpg, FlipV...
# 1   [FlipV79.jpg, VV91.jpg, VV94.jpg, FlipVV108.jp...
# 2   [FlipV69.jpg, V75.jpg, FlipV79.jpg, V68.jpg, V...
# 3   [V75.jpg, V79.jpg, V67.jpg, FlipV67.jpg, V88.j...
# 4   [FlipVV85.jpg, FlipP77.jpg, P82.jpg, FlipP82.j...
# 5   [FlipV70.jpg, FlipV75.jpg, FlipV79.jpg, V88.jp...
# 6   [FlipV70.jpg, V85.jpg, V88.jpg, VV89.jpg, Flip...
# 7   [V69.jpg, FlipV70.jpg, V74.jpg, V88.jpg, VV89....
# 8   [V67.jpg, VV94.jpg, FlipVV98.jpg, P78.jpg, P82...
# 9   [FlipV74.jpg, FlipV78.jpg, V79.jpg, FlipV85.jp...
# 10  [V69.jpg, FlipV69.jpg, FlipV70.jpg, V74.jpg, F...
# 11  [FlipV78.jpg, FlipV85.jpg, FlipV67.jpg, V88.jp...
# 12  [FlipVV89.jpg, VV104.jpg, P78.jpg, FlipP78.jpg...
# 13  [V69.jpg, FlipV70.jpg, V74.jpg, FlipV74.jpg, V...
# 14  [VV104.jpg, FlipVV108.jpg, VV101.jpg, FlipP75....
# 15  [FlipV67.jpg, FlipVV104.jpg, P74.jpg, FlipP76....
# 16  [VV101.jpg, P79.jpg, FlipWW84.jpg, DD108.jpg, ...
# 17  [FlipGG121.jpg, FlipK269.jpg, FlipS359.jpg, L2...
# 18  [FlipT228.jpg, FlipK269.jpg, S159.jpg, FlipS35...
# 19          [FlipW97.jpg, FlipDD108.jpg, FlipO94.jpg]

# %%
# import os # Full
# os.makedirs("/content/gdrive/My Drive/Tooth_Shap_GPT/Deep_tooth/OPG_SHAPer/Result/Age/95_percentie/Pos_9_9")

# %%
# summary_df.to_csv('/content/gdrive/My Drive/Tooth_Shap_GPT/Deep_tooth/OPG_SHAPer/Result/Age/Positive_all_age.csv', index=False)

# %% [markdown]
# ## Negative (291 ภาพ)

# %%
negative_age = pd.read_csv (r'/content/gdrive/My Drive/Tooth_Shap_GPT/Deep_tooth/OPG_SHAPer/Result/Age/95_percentie/data/negative_age_final.csv')
negative_age = negative_age.iloc[:,1:]
print(negative_age.shape)
negative_age
# Out:
# (2181, 11)
#             ymin        xmax        ymax  confidence  class  \
# 0     318.575717  347.501520  375.691668    0.949560     13
# 1     210.917224  433.583892  276.388144    0.923084     18
# 2     377.189239  415.869944  432.946804    0.921959      6
# 3     190.380302  481.506713  277.754403    0.903446     19
# 4     295.167587  268.920413  389.243537    0.901955      3
# ...          ...         ...         ...         ...    ...
# 2176  313.911832  446.391320  409.391832    0.855322     12
# 2177  209.775011  382.026562  300.378426    0.854067     18
# 2178  306.469024  419.285968  390.668366    0.844257      6
# 2179  321.158428  469.688801  414.762481    0.825680      9
# 2180  197.901750  417.333175  311.158844    0.789516     14
#
#                        name      filename Age(year) Gender  \
# 0        Lower Second Molar       V69.jpg        7Y      F
# 1     Upper Second Premolar       V69.jpg        7Y      F
# 2     Lower Second Premolar       V69.jpg        7Y      F
# 3              Upper Canine       V69.jpg        7Y      F
# 4          Mandibular angle       V69.jpg        7Y      F
# ...                     ...           ...       ...    ...
# 2176   Lower First Premolar  FlipJ456.jpg       25Y      M
# 2177  Upper Second Premolar  FlipJ456.jpg       25Y      M
# 2178  Lower Second Premolar  FlipJ456.jpg       25Y      M
# 2179           Lower Canine  FlipJ456.jpg       25Y      M
# 2180   Upper First Premolar  FlipJ456.jpg       25Y      M
#
#                                           path_name_ori  \
# 0     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 1     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 2     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 3     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 4     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# ...                                                 ...
# 2176  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 2177  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 2178  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 2179  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 2180  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
#
#                                            path_neg_img
# 0     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 1     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 2     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 3     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 4     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# ...                                                 ...
# 2176  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 2177  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 2178  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 2179  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 2180  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
#
# [2181 rows x 11 columns]

# %%
print(len(negative_age['filename'].unique()))
negative_age['filename'].unique()
# Out:
# 291
# array(['V69.jpg', 'FlipV69.jpg', 'FlipV70.jpg', 'V74.jpg', 'FlipV74.jpg',
#        'V75.jpg', 'FlipV75.jpg', 'V78.jpg', 'FlipV78.jpg', 'V79.jpg',
#        'FlipV79.jpg', 'V85.jpg', 'FlipV85.jpg', 'V68.jpg', 'FlipV68.jpg',
#        'V67.jpg', 'FlipV67.jpg', 'V88.jpg', 'VV85.jpg', 'FlipVV85.jpg',
#        'VV88.jpg', 'FlipVV88.jpg', 'VV89.jpg', 'FlipVV89.jpg', 'VV91.jpg',
#        'VV94.jpg', 'FlipVV98.jpg', 'VV100.jpg', 'FlipVV100.jpg',
#        'VV104.jpg', 'FlipVV104.jpg', 'FlipVV108.jpg', 'VV101.jpg',
#        'FlipVV101.jpg', 'VV84.jpg', 'P70.jpg', 'P72.jpg', 'FlipP72.jpg',
#        'P74.jpg', 'FlipP74.jpg', 'P75.jpg', 'FlipP75.jpg', 'P76.jpg',
#        'FlipP76.jpg', 'P78.jpg', 'FlipP78.jpg', 'P79.jpg', 'FlipP79.jpg',
#        'FlipP81.jpg', 'P73.jpg', 'FlipP73.jpg', 'FlipP77.jpg', 'P82.jpg',
#        'FlipP82.jpg', 'PP70.jpg', 'PP75.jpg', 'FlipPP75.jpg', 'PP76.jpg',
#        'FlipPP76.jpg', 'PP79.jpg', 'FlipPP79.jpg', 'PP80.jpg',
#        'FlipPP80.jpg', 'PP83.jpg', 'FlipPP83.jpg', 'FlipPP77.jpg',
#        'PP82.jpg', 'FlipPP82.jpg', 'PP78.jpg', 'W84.jpg', 'FlipW87.jpg',
#        'W91.jpg', 'FlipW91.jpg', 'W92.jpg', 'FlipW92.jpg', 'W95.jpg',
#        'FlipW95.jpg', 'W88.jpg', 'W86.jpg', 'FlipW86.jpg', 'W97.jpg',
#        'FlipW97.jpg', 'FlipW90.jpg', 'WW75.jpg', 'FlipWW75.jpg',
#        'WW76.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'FlipWW79.jpg', 'WW81.jpg',
#        'FlipWW81.jpg', 'WW85.jpg', 'WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg',
#        'FlipWW82.jpg', 'WW88.jpg', 'FlipWW88.jpg', 'FlipW96.jpg',
#        'FlipWW84.jpg', 'FlipWW90.jpg', 'H79.jpg', 'FlipH79.jpg',
#        'H83.jpg', 'FlipH83.jpg', 'H84.jpg', 'H86.jpg', 'H88.jpg',
#        'H80.jpg', 'FlipH80.jpg', 'FlipH76.jpg', 'HH82.jpg',
#        'FlipHH82.jpg', 'HH87.jpg', 'FlipHH87.jpg', 'HH94.jpg',
#        'FlipHH94.jpg', 'FlipHH95.jpg', 'HH96.jpg', 'D79.jpg',
#        'FlipD79.jpg', 'D89.jpg', 'FlipD89.jpg', 'D87.jpg', 'FlipD87.jpg',
#        'FlipD82.jpg', 'FlipD80.jpg', 'DD100.jpg', 'FlipDD100.jpg',
#        'DD108.jpg', 'FlipDD108.jpg', 'DD113.jpg', 'FlipDD113.jpg',
#        'DD115.jpg', 'FlipDD115.jpg', 'DD99.jpg', 'DD98.jpg', 'D86.jpg',
#        'O85.jpg', 'FlipO85.jpg', 'FlipO89.jpg', 'O90.jpg', 'FlipO90.jpg',
#        'O93.jpg', 'O94.jpg', 'FlipO94.jpg', 'O97.jpg', 'FlipO99.jpg',
#        'OO97.jpg', 'OO103.jpg', 'OO106.jpg', 'FlipOO111.jpg',
#        'FlipOO116.jpg', 'OO117.jpg', 'FlipOO112.jpg', 'FlipOO118.jpg',
#        'FlipOO101.jpg', 'OO98.jpg', 'G84.jpg', 'G94.jpg', 'G111.jpg',
#        'FlipG111.jpg', 'G83.jpg', 'FlipG83.jpg', 'G105.jpg', 'G103.jpg',
#        'G108.jpg', 'GG117.jpg', 'FlipGG120.jpg', 'GG121.jpg',
#        'FlipGG121.jpg', 'GG124.jpg', 'FlipGG124.jpg', 'FlipGG125.jpg',
#        'GG129.jpg', 'FlipGG129.jpg', 'GG132.jpg', 'FlipGG132.jpg',
#        'GG137.jpg', 'FlipGG137.jpg', 'FlipGG138.jpg', 'GG140.jpg',
#        'Y96.jpg', 'FlipY96.jpg', 'Y98.jpg', 'FlipY99.jpg', 'Y101.jpg',
#        'FlipY101.jpg', 'Y188.jpg', 'FlipY188.jpg', 'Y190.jpg',
#        'FlipY190.jpg', 'Y236.jpg', 'Y278.jpg', 'FlipY278.jpg',
#        'FlipY95.jpg', 'FlipY187.jpg', 'Y100.jpg', 'B153.jpg', 'B157.jpg',
#        'FlipB157.jpg', 'B162.jpg', 'B166.jpg', 'FlipB166.jpg', 'B175.jpg',
#        'FlipB300.jpg', 'FlipB308.jpg', 'FlipB317.jpg', 'B332.jpg',
#        'T177.jpg', 'FlipT178.jpg', 'T181.jpg', 'FlipT192.jpg',
#        'FlipT198.jpg', 'FlipT163.jpg', 'FlipT228.jpg', 'T231.jpg',
#        'FlipT231.jpg', 'T250.jpg', 'FlipT250.jpg', 'K157.jpg', 'K176.jpg',
#        'K177.jpg', 'K183.jpg', 'FlipK183.jpg', 'K186.jpg', 'FlipK186.jpg',
#        'FlipK170.jpg', 'FlipK257.jpg', 'K269.jpg', 'FlipK269.jpg',
#        'K292.jpg', 'FlipK293.jpg', 'K319.jpg', 'FlipK319.jpg',
#        'FlipK326.jpg', 'FlipK270.jpg', 'S159.jpg', 'FlipS158.jpg',
#        'FlipS160.jpg', 'FlipS165.jpg', 'S195.jpg', 'FlipS189.jpg',
#        'FlipS191.jpg', 'FlipS36.jpg', 'S349.jpg', 'S356.jpg',
#        'FlipS359.jpg', 'L240.jpg', 'FlipL250.jpg', 'L262.jpg',
#        'FlipL236.jpg', 'FlipL369.jpg', 'FlipL393.jpg', 'L405.jpg',
#        'FlipL406.jpg', 'L409.jpg', 'FlipL409.jpg', 'FlipL401.jpg',
#        'Q250.jpg', 'FlipQ253.jpg', 'FlipQ56.jpg', 'Q415.jpg', 'Q402.jpg',
#        'Q409.jpg', 'FlipQ412.jpg', 'N158.jpg', 'FlipN167.jpg',
#        'FlipN168.jpg', 'N182.jpg', 'FlipN182.jpg', 'N184.jpg',
#        'FlipN184.jpg', 'N405.jpg', 'FlipN405.jpg', 'FlipN406.jpg',
#        'N419.jpg', 'FlipN426.jpg', 'FlipN415.jpg', 'FlipN424.jpg',
#        'FlipN416.jpg', 'N408.jpg', 'FlipU298.jpg', 'FlipU230.jpg',
#        'FlipU279.jpg', 'U414.jpg', 'FlipU422.jpg', 'U292.jpg', 'E356.jpg',
#        'FlipJ71.jpg', 'FlipJ456.jpg'], dtype=object)

# %%
# Sample DataFrame for demonstration
import pandas as pd

name_count_pos = {}
name_files = {}

# List of names
list_neg = negative_age['name'].tolist()
# List of filenames
filenames = negative_age['filename'].tolist()

# Iterate over each name and corresponding filename
for name, filename in zip(list_neg, filenames):
    if name in name_count_pos:
        name_count_pos[name] += 1
        name_files[name].append(filename)
    else:
        name_count_pos[name] = 1
        name_files[name] = [filename]

# Sort the name_count_pos dictionary by count of occurrences (descending order)
sorted_names = sorted(name_count_pos.items(), key=lambda x: x[1], reverse=True)

# Print a summary of all unique names and their occurrence counts
print("Unique names and their occurrences in negitive SHAP values area:")
# Print the total number of unique names in the dataset
total_unique_names = len(sorted_names)
print(f"Total Unique Names: {total_unique_names}")

for i, (name, count) in enumerate(sorted_names, start=1):
    unique_filenames = len(set(name_files[name]))  # Calculate unique filenames
    print(f"{i}. {name}: {count}/{len(negative_age['filename'].unique())} ({(count / len(negative_age['filename'].unique())):.2%}) of total")
    print(f"    Filenames: {name_files[name]}")
# Out:
# Unique names and their occurrences in negitive SHAP values area:
# Total Unique Names: 20
# 1. Lower Second Molar: 237/291 (81.44%) of total
#     Filenames: ['V69.jpg', 'FlipV69.jpg', 'V74.jpg', 'FlipV74.jpg', 'V75.jpg', 'FlipV75.jpg', 'FlipV78.jpg', 'FlipV79.jpg', 'V85.jpg', 'FlipV85.jpg', 'V68.jpg', 'FlipV68.jpg', 'V88.jpg', 'VV85.jpg', 'FlipVV85.jpg', 'VV88.jpg', 'FlipVV88.jpg', 'VV89.jpg', 'FlipVV89.jpg', 'VV91.jpg', 'VV94.jpg', 'FlipVV98.jpg', 'VV100.jpg', 'FlipVV100.jpg', 'VV104.jpg', 'FlipVV104.jpg', 'FlipVV108.jpg', 'FlipVV101.jpg', 'VV84.jpg', 'P70.jpg', 'FlipP72.jpg', 'P74.jpg', 'FlipP74.jpg', 'P75.jpg', 'FlipP75.jpg', 'P78.jpg', 'FlipP79.jpg', 'FlipP81.jpg', 'FlipP77.jpg', 'FlipP82.jpg', 'PP70.jpg', 'PP75.jpg', 'FlipPP75.jpg', 'FlipPP76.jpg', 'PP79.jpg', 'FlipPP79.jpg', 'PP80.jpg', 'FlipPP80.jpg', 'PP83.jpg', 'FlipPP83.jpg', 'FlipPP77.jpg', 'PP82.jpg', 'FlipPP82.jpg', 'PP78.jpg', 'W84.jpg', 'FlipW87.jpg', 'W91.jpg', 'FlipW91.jpg', 'FlipW92.jpg', 'W95.jpg', 'FlipW95.jpg', 'W88.jpg', 'W86.jpg', 'FlipW86.jpg', 'W97.jpg', 'FlipW97.jpg', 'FlipW90.jpg', 'WW75.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'WW81.jpg', 'FlipWW81.jpg', 'WW80.jpg', 'WW82.jpg', 'FlipWW82.jpg', 'WW88.jpg', 'FlipWW88.jpg', 'FlipW96.jpg', 'FlipWW84.jpg', 'H79.jpg', 'FlipH79.jpg', 'H83.jpg', 'FlipH83.jpg', 'H84.jpg', 'H86.jpg', 'H88.jpg', 'H80.jpg', 'FlipH80.jpg', 'FlipH76.jpg', 'HH82.jpg', 'FlipHH82.jpg', 'HH87.jpg', 'FlipHH87.jpg', 'HH94.jpg', 'FlipHH94.jpg', 'FlipHH95.jpg', 'HH96.jpg', 'D79.jpg', 'FlipD79.jpg', 'D89.jpg', 'FlipD89.jpg', 'D87.jpg', 'FlipD87.jpg', 'FlipD82.jpg', 'FlipD80.jpg', 'DD100.jpg', 'FlipDD100.jpg', 'DD108.jpg', 'FlipDD108.jpg', 'DD113.jpg', 'FlipDD113.jpg', 'DD115.jpg', 'FlipDD115.jpg', 'DD99.jpg', 'DD98.jpg', 'D86.jpg', 'O85.jpg', 'FlipO85.jpg', 'FlipO89.jpg', 'O90.jpg', 'FlipO90.jpg', 'O93.jpg', 'O94.jpg', 'O97.jpg', 'OO97.jpg', 'OO103.jpg', 'OO106.jpg', 'FlipOO111.jpg', 'FlipOO116.jpg', 'OO117.jpg', 'FlipOO112.jpg', 'FlipOO118.jpg', 'FlipOO101.jpg', 'OO98.jpg', 'G111.jpg', 'FlipG111.jpg', 'G105.jpg', 'G103.jpg', 'G108.jpg', 'GG117.jpg', 'FlipGG120.jpg', 'GG121.jpg', 'FlipGG121.jpg', 'GG124.jpg', 'FlipGG124.jpg', 'FlipGG125.jpg', 'GG129.jpg', 'FlipGG129.jpg', 'FlipGG132.jpg', 'GG137.jpg', 'FlipGG138.jpg', 'GG140.jpg', 'Y96.jpg', 'FlipY96.jpg', 'Y98.jpg', 'Y101.jpg', 'FlipY101.jpg', 'Y188.jpg', 'FlipY188.jpg', 'Y190.jpg', 'FlipY190.jpg', 'Y236.jpg', 'Y278.jpg', 'FlipY278.jpg', 'FlipY95.jpg', 'FlipY187.jpg', 'Y100.jpg', 'B153.jpg', 'B162.jpg', 'B166.jpg', 'FlipB166.jpg', 'FlipB317.jpg', 'B332.jpg', 'T177.jpg', 'FlipT178.jpg', 'FlipT198.jpg', 'FlipT163.jpg', 'FlipT228.jpg', 'T231.jpg', 'FlipT231.jpg', 'T250.jpg', 'FlipT250.jpg', 'K176.jpg', 'K177.jpg', 'K183.jpg', 'FlipK183.jpg', 'K186.jpg', 'FlipK186.jpg', 'FlipK170.jpg', 'FlipK257.jpg', 'K269.jpg', 'FlipK269.jpg', 'K292.jpg', 'FlipK293.jpg', 'K319.jpg', 'FlipK319.jpg', 'FlipK326.jpg', 'FlipK270.jpg', 'S159.jpg', 'FlipS160.jpg', 'FlipS165.jpg', 'S195.jpg', 'FlipS189.jpg', 'FlipS36.jpg', 'S349.jpg', 'S356.jpg', 'FlipS359.jpg', 'FlipL250.jpg', 'FlipL236.jpg', 'FlipL369.jpg', 'FlipL393.jpg', 'L405.jpg', 'FlipL406.jpg', 'L409.jpg', 'FlipL409.jpg', 'FlipL401.jpg', 'Q250.jpg', 'FlipQ253.jpg', 'FlipQ56.jpg', 'Q402.jpg', 'Q409.jpg', 'FlipQ412.jpg', 'FlipN168.jpg', 'N182.jpg', 'N405.jpg', 'FlipN405.jpg', 'FlipN406.jpg', 'N419.jpg', 'FlipN426.jpg', 'FlipN415.jpg', 'FlipN416.jpg', 'FlipU230.jpg', 'U414.jpg', 'FlipU422.jpg', 'U292.jpg', 'FlipJ456.jpg']
# 2. Upper Second Molar: 212/291 (72.85%) of total
#     Filenames: ['FlipV69.jpg', 'FlipV70.jpg', 'V74.jpg', 'V75.jpg', 'FlipV75.jpg', 'V78.jpg', 'FlipV79.jpg', 'V68.jpg', 'FlipV68.jpg', 'V67.jpg', 'VV85.jpg', 'FlipVV85.jpg', 'VV89.jpg', 'FlipVV89.jpg', 'VV94.jpg', 'FlipVV98.jpg', 'VV100.jpg', 'FlipVV100.jpg', 'VV104.jpg', 'FlipVV104.jpg', 'FlipVV108.jpg', 'P70.jpg', 'P72.jpg', 'FlipP72.jpg', 'P74.jpg', 'FlipP74.jpg', 'P75.jpg', 'FlipP75.jpg', 'P76.jpg', 'FlipP77.jpg', 'P82.jpg', 'FlipP82.jpg', 'PP75.jpg', 'FlipPP75.jpg', 'PP76.jpg', 'FlipPP76.jpg', 'FlipPP79.jpg', 'PP80.jpg', 'FlipPP80.jpg', 'PP83.jpg', 'FlipPP83.jpg', 'FlipPP77.jpg', 'PP82.jpg', 'FlipPP82.jpg', 'PP78.jpg', 'W84.jpg', 'FlipW87.jpg', 'FlipW91.jpg', 'W92.jpg', 'FlipW92.jpg', 'W95.jpg', 'FlipW95.jpg', 'W88.jpg', 'W86.jpg', 'FlipW86.jpg', 'W97.jpg', 'FlipW97.jpg', 'WW75.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'FlipWW79.jpg', 'WW81.jpg', 'FlipWW81.jpg', 'WW85.jpg', 'WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg', 'FlipWW82.jpg', 'WW88.jpg', 'FlipWW88.jpg', 'FlipW96.jpg', 'FlipWW90.jpg', 'H79.jpg', 'FlipH79.jpg', 'FlipH83.jpg', 'H84.jpg', 'H86.jpg', 'H88.jpg', 'H80.jpg', 'FlipH80.jpg', 'FlipH76.jpg', 'HH87.jpg', 'FlipHH87.jpg', 'HH94.jpg', 'FlipHH95.jpg', 'HH96.jpg', 'D79.jpg', 'FlipD79.jpg', 'D87.jpg', 'FlipD87.jpg', 'FlipD80.jpg', 'DD100.jpg', 'FlipDD100.jpg', 'DD108.jpg', 'FlipDD108.jpg', 'DD113.jpg', 'FlipDD113.jpg', 'FlipDD115.jpg', 'DD99.jpg', 'DD98.jpg', 'D86.jpg', 'O85.jpg', 'FlipO85.jpg', 'FlipO89.jpg', 'O90.jpg', 'O93.jpg', 'O94.jpg', 'OO97.jpg', 'OO103.jpg', 'OO106.jpg', 'FlipOO111.jpg', 'FlipOO116.jpg', 'OO117.jpg', 'FlipOO112.jpg', 'FlipOO118.jpg', 'OO98.jpg', '
/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
#
# [239 rows x 11 columns]

# %%
print(len(age_9_neg['filename'].unique()))
# Out:
# 32

# %% [markdown]
# ### all

# %%
age_9_neg['name'].value_counts()
# Out:
# name
# Upper Second Molar           27
# Lower Second Molar           26
# Upper Canine                 20
# Upper Second Premolar        20
# Lower Third Molar            20
# Lower First Molar            19
# Condyle                      15
# Upper First Premolar         15
# Upper Third Molar            14
# Upper First Molar            14
# Lower Second Premolar        14
# Upper Lateral Incisor        11
# Posterior border of Ramus     7
# Upper Central Incisor         7
# Lower First Premolar          6
# Mandibular angle              4
# Name: count, dtype: int64

# %%
name_count_neg = {}
name_files = {}
list_neg = age_9_neg['name'].tolist()
filenames = age_9_neg['filename'].tolist()
# Iterate over each list of dictionaries
for name, filename in zip(list_neg, filenames):
    if name in name_count_neg:
       name_count_neg[name] += 1
       name_files[name].append(filename)
    else:
       name_count_neg[name] = 1
       name_files[name] = [filename]

# Sort the name_count_neg dictionary by count of occurrences (descending order)
sorted_names = sorted(name_count_neg.items(), key=lambda x: x[1], reverse=True)

# Print a summary of all unique names and their occurrence counts
print("Unique names and their occurrences in negative SHAP values area:")
# Print the total number of unique names in the dataset
total_unique_names = len(sorted_names)
print(f"Total Unique Names: {total_unique_names}")

for i, (name, count) in enumerate(sorted_names, start=1):
    print(f"{i}. {name}: {count}/{len(age_9_neg['filename'].unique())} ({(count / len(age_9_neg['filename'].unique())):.2%})")#of total
# Out:
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 16
# 1. Upper Second Molar: 27/32 (84.38%)
# 2. Lower Second Molar: 26/32 (81.25%)
# 3. Upper Canine: 20/32 (62.50%)
# 4. Upper Second Premolar: 20/32 (62.50%)
# 5. Lower Third Molar: 20/32 (62.50%)
# 6. Lower First Molar: 19/32 (59.38%)
# 7. Condyle: 15/32 (46.88%)
# 8. Upper First Premolar: 15/32 (46.88%)
# 9. Upper Third Molar: 14/32 (43.75%)
# 10. Upper First Molar: 14/32 (43.75%)
# 11. Lower Second Premolar: 14/32 (43.75%)
# 12. Upper Lateral Incisor: 11/32 (34.38%)
# 13. Posterior border of Ramus: 7/32 (21.88%)
# 14. Upper Central Incisor: 7/32 (21.88%)
# 15. Lower First Premolar: 6/32 (18.75%)
# 16. Mandibular angle: 4/32 (12.50%)

# %%
# Optional: Create a DataFrame to keep all the information together
summary_Neg_9 = []
for name, count in sorted_names:
    summary_Neg_9.append({
        'name': name,
        'count': count,
        'total_files': len(age_9_neg['filename'].unique()),
        'percentage_files': f"{(count / len(age_9_neg['filename'].unique())) * 100 :.2f}%",
        'filenames': name_files[name]
    })

summary_neg_9_df = pd.DataFrame(summary_Neg_9)
summary_neg_9_df
# Out:
#                          name  count  total_files percentage_files  \
# 0          Upper Second Molar     27           32           84.38%
# 1          Lower Second Molar     26           32           81.25%
# 2                Upper Canine     20           32           62.50%
# 3       Upper Second Premolar     20           32           62.50%
# 4           Lower Third Molar     20           32           62.50%
# 5           Lower First Molar     19           32           59.38%
# 6                     Condyle     15           32           46.88%
# 7        Upper First Premolar     15           32           46.88%
# 8           Upper Third Molar     14           32           43.75%
# 9           Upper First Molar     14           32           43.75%
# 10      Lower Second Premolar     14           32           43.75%
# 11      Upper Lateral Incisor     11           32           34.38%
# 12  Posterior border of Ramus      7           32           21.88%
# 13      Upper Central Incisor      7           32           21.88%
# 14       Lower First Premolar      6           32           18.75%
# 15           Mandibular angle      4           32           12.50%
#
#                                             filenames
# 0   [W84.jpg, FlipW87.jpg, FlipW91.jpg, W92.jpg, F...
# 1   [W84.jpg, FlipW87.jpg, W91.jpg, FlipW91.jpg, F...
# 2   [W84.jpg, W95.jpg, FlipW95.jpg, W86.jpg, W97.j...
# 3   [W84.jpg, W92.jpg, FlipW92.jpg, FlipW95.jpg, W...
# 4   [W84.jpg, W92.jpg, FlipW92.jpg, W95.jpg, FlipW...
# 5   [FlipW87.jpg, FlipW91.jpg, FlipW92.jpg, W95.jp...
# 6   [W84.jpg, FlipW87.jpg, W91.jpg, FlipW91.jpg, F...
# 7   [W95.jpg, W86.jpg, WW75.jpg, FlipWW75.jpg, Fli...
# 8   [FlipW87.jpg, FlipW95.jpg, W86.jpg, FlipW86.jp...
# 9   [FlipW91.jpg, FlipW92.jpg, FlipW95.jpg, W88.jp...
# 10  [FlipW91.jpg, W92.jpg, FlipW92.jpg, W95.jpg, W...
# 11  [FlipW92.jpg, W95.jpg, FlipW90.jpg, FlipWW78.j...
# 12  [FlipW87.jpg, W95.jpg, FlipWW75.jpg, FlipWW79....
# 13  [W86.jpg, WW80.jpg, FlipWW80.jpg, WW82.jpg, Fl...
# 14  [W95.jpg, FlipW97.jpg, WW75.jpg, WW76.jpg, Fli...
# 15    [W84.jpg, FlipWW78.jpg, WW80.jpg, FlipWW80.jpg]

# %%
# import os
# os.makedirs("/content/gdrive/My Drive/Tooth_Shap_GPT/Deep_tooth/OPG_SHAPer/Result/Age/95_percentie/Neg_9")

# %%
summary_neg_9_df.to_csv('/content/gdrive/My Drive/Tooth_Shap_GPT/Deep_tooth/OPG_SHAPer/Result/Age/95_percentie/Neg_9/Negative_9_years.csv', index=False)

# %%
age_9_neg['name'].unique()
# Out:
# array(['Lower Second Molar', 'Upper Second Molar', 'Upper Canine',
#        'Upper Second Premolar', 'Condyle', 'Mandibular angle',
#        'Lower Third Molar', 'Lower First Molar',
#        'Posterior border of Ramus', 'Upper Third Molar',
#        'Upper First Molar', 'Lower Second Premolar',
#        'Upper Lateral Incisor', 'Lower First Premolar',
#        'Upper First Premolar', 'Upper Central Incisor'], dtype=object)

# %%
percentage = summary_neg_9_df['percentage_files'].tolist()
# Convert to a list of integers
summary_neg_9_df['percentage_float'] = [float(p.replace('%', '')) for p in percentage]

# %%
table = summary_neg_9_df[summary_neg_9_df['percentage_float']>=50.00]
table
# Out:
#                     name  count  total_files percentage_files  \
# 0     Upper Second Molar     27           32           84.38%
# 1     Lower Second Molar     26           32           81.25%
# 2           Upper Canine     20           32           62.50%
# 3  Upper Second Premolar     20           32           62.50%
# 4      Lower Third Molar     20           32           62.50%
# 5      Lower First Molar     19           32           59.38%
#
#                                            filenames  percentage_float
# 0  [W84.jpg, FlipW87.jpg, FlipW91.jpg, W92.jpg, F...             84.38
# 1  [W84.jpg, FlipW87.jpg, W91.jpg, FlipW91.jpg, F...             81.25
# 2  [W84.jpg, W95.jpg, FlipW95.jpg, W86.jpg, W97.j...             62.50
# 3  [W84.jpg, W92.jpg, FlipW92.jpg, FlipW95.jpg, W...             62.50
# 4  [W84.jpg, W92.jpg, FlipW92.jpg, W95.jpg, FlipW...             62.50
# 5  [FlipW87.jpg, FlipW91.jpg, FlipW92.jpg, W95.jp...             59.38

# %%
table = table.iloc[:,:-1]

# %%
table.to_csv('/content/gdrive/My Drive/Tooth_Shap_GPT/Deep_tooth/OPG_SHAPer/Result/Age/95_percentie/Neg_9/Negative_9_years(>=50%).csv', index=False)

# %% [markdown]
# ### 2 with combinations (125/93 rows)

# %%
from itertools import combinations

# List of names
names = [
    'Lower Second Molar', 'Upper Second Premolar', 'Lower Second Premolar',
    'Upper Canine', 'Mandibular angle', 'Upper First Premolar',
    'Upper Lateral Incisor', 'Posterior border of Ramus', 'Upper Second Molar',
    'Lower First Molar', 'Lower First Premolar', 'Condyle', 'Upper First Molar',
    'Lower Third Molar', 'Lower Canine', 'Upper Central Incisor',
    'Upper Third Molar', 'Nasal'
]

# Get all combinations of names with length 2
pairs_of_names = list(combinations(names, 2))
print(pairs_of_names)
# Out:
# [('Lower Second Molar', 'Upper Second Premolar'), ('Lower Second Molar', 'Lower Second Premolar'), ('Lower Second Molar', 'Upper Canine'), ('Lower Second Molar', 'Mandibular angle'), ('Lower Second Molar', 'Upper First Premolar'), ('Lower Second Molar', 'Upper Lateral Incisor'), ('Lower Second Molar', 'Posterior border of Ramus'), ('Lower Second Molar', 'Upper Second Molar'), ('Lower Second Molar', 'Lower First Molar'), ('Lower Second Molar', 'Lower First Premolar'), ('Lower Second Molar', 'Condyle'), ('Lower Second Molar', 'Upper First Molar'), ('Lower Second Molar', 'Lower Third Molar'), ('Lower Second Molar', 'Lower Canine'), ('Lower Second Molar', 'Upper Central Incisor'), ('Lower Second Molar', 'Upper
# %%
len(pairs_of_names)
# Out:
# 153

# %%
import pandas as pd

# Dictionary to store results for each pair
pair_results = {}

for name1, name2 in pairs_of_names:
    # Identify filenames that contain name1
    A = set(age_9_neg[age_9_neg['name'] == name1]['filename'])

    # Identify filenames that contain name2
    B = set(age_9_neg[age_9_neg['name'] == name2]['filename'])

    # Find the intersection of the two sets to get filenames that contain both name1 and name2
    common_filenames = A.intersection(B)

    # Filter the DataFrame to include only the common filenames
    filtered_filenames = age_9_neg[age_9_neg['filename'].isin(common_filenames)]

    # Filter the DataFrame to include only the name1 or name2
    filtered_region = filtered_filenames[filtered_filenames['name'].isin([name1, name2])]

    # Dictionary to store name counts and associated filenames
    name_count_neg = {}
    name_files = {}

    # List of names
    list_neg = filtered_region['name'].tolist()
    # List of filenames
    filenames = filtered_region['filename'].tolist()

    # Iterate over each name and corresponding filename
    for name, filename in zip(list_neg, filenames):
        if name in name_count_neg:
            name_count_neg[name] += 1
            name_files[name].append(filename)
        else:
            name_count_neg[name] = 1
            name_files[name] = [filename]

    # Sort the name_count_neg dictionary by count of occurrences (descending order)
    sorted_names = sorted(name_count_neg.items(), key=lambda x: x[1], reverse=True)

    # Store the results in the dictionary
    pair_results[(name1, name2)] = {
        'sorted_names': sorted_names,
        'name_files': name_files
    }

    # Print a summary for this pair
    print(f"Pair: {name1} and {name2}")
    print("Unique names and their occurrences in negative SHAP values area:")
    total_unique_names = len(sorted_names)
    print(f"Total Unique Names: {total_unique_names}")

    for i, (name, count) in enumerate(sorted_names, start=1):
        unique_filenames = len(set(name_files[name]))  # Calculate unique filenames
        print(f"{i}. {name}: {count}/{len(filtered_region['filename'].unique())} ({(count / len(filtered_region['filename'].unique())):.2%}) of total")
        print(f"    Filenames: {name_files[name]}")

    print("Filenames with the same name:")
    for name, filenames in name_files.items():
        if len(set(filenames)) >= 1:  # Only consider names that appear in more than one filename
            print(f"{name}: {', '.join(filenames)}")
# Out:
# Pair: Lower Second Molar and Upper Second Premolar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 2
# 1. Lower Second Molar: 16/16 (100.00%) of total
#     Filenames: ['W84.jpg', 'FlipW92.jpg', 'FlipW95.jpg', 'W88.jpg', 'W86.jpg', 'W97.jpg', 'FlipW97.jpg', 'FlipW90.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'WW81.jpg', 'WW82.jpg', 'FlipWW82.jpg', 'FlipW96.jpg', 'FlipWW84.jpg']
# 2. Upper Second Premolar: 16/16 (100.00%) of total
#     Filenames: ['W84.jpg', 'FlipW92.jpg', 'FlipW95.jpg', 'W88.jpg', 'W86.jpg', 'W97.jpg', 'FlipW97.jpg', 'FlipW90.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'WW81.jpg', 'WW82.jpg', 'FlipWW82.jpg', 'FlipW96.jpg', 'FlipWW84.jpg']
# Filenames with the same name:
# Lower Second Molar: W84.jpg, FlipW92.jpg, FlipW95.jpg, W88.jpg, W86.jpg, W97.jpg, FlipW97.jpg, FlipW90.jpg, WW76.jpg, FlipWW78.jpg, WW79.jpg, WW81.jpg, WW82.jpg, FlipWW82.jpg, FlipW96.jpg, FlipWW84.jpg
# Upper Second Premolar: W84.jpg, FlipW92.jpg, FlipW95.jpg, W88.jpg, W86.jpg, W97.jpg, FlipW97.jpg, FlipW90.jpg, WW76.jpg, FlipWW78.jpg, WW79.jpg, WW81.jpg, WW82.jpg, FlipWW82.jpg, FlipW96.jpg, FlipWW84.jpg
# Pair: Lower Second Molar and Lower Second Premolar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 2
# 1. Lower Second Molar: 11/11 (100.00%) of total
#     Filenames: ['FlipW91.jpg', 'FlipW92.jpg', 'W95.jpg', 'W88.jpg', 'W86.jpg', 'FlipW97.jpg', 'FlipW90.jpg', 'WW75.jpg', 'WW76.jpg', 'WW81.jpg', 'WW88.jpg']
# 2. Lower Second Premolar: 11/11 (100.00%) of total
#     Filenames: ['FlipW91.jpg', 'FlipW92.jpg', 'W95.jpg', 'W88.jpg', 'W86.jpg', 'FlipW97.jpg', 'FlipW90.jpg', 'WW75.jpg', 'WW76.jpg', 'WW81.jpg', 'WW88.jpg']
# Filenames with the same name:
# Lower Second Molar: FlipW91.jpg, FlipW92.jpg, W95.jpg, W88.jpg, W86.jpg, FlipW97.jpg, FlipW90.jpg, WW75.jpg, WW76.jpg, WW81.jpg, WW88.jpg
# Lower Second Premolar: FlipW91.jpg, FlipW92.jpg, W95.jpg, W88.jpg, W86.jpg, FlipW97.jpg, FlipW90.jpg, WW75.jpg, WW76.jpg, WW81.jpg, WW88.jpg
# Pair: Lower Second Molar and Upper Canine
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 2
# 1. Lower Second Molar: 17/17 (100.00%) of total
#     Filenames: ['W84.jpg', 'W95.jpg', 'FlipW95.jpg', 'W86.jpg', 'W97.jpg', 'FlipW97.jpg', 'FlipW90.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'WW81.jpg', 'FlipWW81.jpg', 'WW80.jpg', 'WW82.jpg', 'FlipWW82.jpg', 'WW88.jpg', 'FlipWW88.jpg', 'FlipWW84.jpg']
# 2. Upper Canine: 17/17 (100.00%) of total
#     Filenames: ['W84.jpg', 'W95.jpg', 'FlipW95.jpg', 'W86.jpg', 'W97.jpg', 'FlipW97.jpg', 'FlipW90.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'WW81.jpg', 'FlipWW81.jpg', 'WW80.jpg', 'WW82.jpg', 'FlipWW82.jpg', 'WW88.jpg', 'FlipWW88.jpg', 'FlipWW84.jpg']
# Filenames with the same name:
# Lower Second Molar: W84.jpg, W95.jpg, FlipW95.jpg, W86.jpg, W97.jpg, FlipW97.jpg, FlipW90.jpg, FlipWW78.jpg, WW79.jpg, WW81.jpg, FlipWW81.jpg, WW80.jpg, WW82.jpg, FlipWW82.jpg, WW88.jpg, FlipWW88.jpg, FlipWW84.jpg
# Upper Canine: W84.jpg, W95.jpg, FlipW95.jpg, W86.jpg, W97.jpg, FlipW97.jpg, FlipW90.jpg, FlipWW78.jpg, WW79.jpg, WW81.jpg, FlipWW81.jpg, WW80.jpg, WW82.jpg, FlipWW82.jpg, WW88.jpg, FlipWW88.jpg, FlipWW84.jpg
# Pair: Lower Second Molar and Mandibular angle
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 2
# 1. Lower Second Molar: 3/3 (100.00%) of total
#     Filenames: ['W84.jpg', 'FlipWW78.jpg', 'WW80.jpg']
# 2. Mandibular angle: 3/3 (100.00%) of total
#     Filenames: ['W84.jpg', 'FlipWW78.jpg', 'WW80.jpg']
# Filenames with the same name:
# Lower Second Molar: W84.jpg, FlipWW78.jpg, WW80.jpg
# Mandibular angle: W84.jpg, FlipWW78.jpg, WW80.jpg
# Pair: Lower Second Molar and Upper First Premolar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 2
# 1. Lower Second Molar: 10/10 (100.00%) of total
#     Filenames: ['W95.jpg', 'W86.jpg', 'WW75.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'WW81.jpg', 'FlipWW82.jpg', 'FlipWW88.jpg', 'FlipW96.jpg', 'FlipWW84.jpg']
# 2. Upper First Premolar: 10/10 (100.00%) of total
#     Filenames: ['W95.jpg', 'W86.jpg', 'WW75.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'WW81.jpg', 'FlipWW82.jpg', 'FlipWW88.jpg', 'FlipW96.jpg', 'FlipWW84.jpg']
# Filenames with the same name:
# Lower Second Molar: W95.jpg, W86.jpg, WW75.jpg, FlipWW78.jpg, WW79.jpg, WW81.jpg, FlipWW82.jpg, FlipWW88.jpg, FlipW96.jpg, FlipWW84.jpg
# Upper First Premolar: W95.jpg, W86.jpg, WW75.jpg, FlipWW78.jpg, WW79.jpg, WW81.jpg, FlipWW82.jpg, FlipWW88.jpg, FlipW96.jpg, FlipWW84.jpg
# Pair: Lower Second Molar and Upper Lateral Incisor
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 2
# 1. Lower Second Molar: 9/9 (100.00%) of total
#     Filenames: ['FlipW92.jpg', 'W95.jpg', 'FlipW90.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'WW82.jpg', 'FlipWW82.jpg', 'FlipW96.jpg', 'FlipWW84.jpg']
# 2. Upper Lateral Incisor: 9/9 (100.00%) of total
#     Filenames: ['FlipW92.jpg', 'W95.jpg', 'FlipW90.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'WW82.jpg', 'FlipWW82.jpg', 'FlipW96.jpg', 'FlipWW84.jpg']
# Filenames with the same name:
# Lower Second Molar: FlipW92.jpg, W95.jpg, FlipW90.jpg, FlipWW78.jpg, WW79.jpg, WW82.jpg, FlipWW82.jpg, FlipW96.jpg, FlipWW84.jpg
# Upper Lateral Incisor: FlipW92.jpg, W95.jpg, FlipW90.jpg, FlipWW78.jpg, WW79.jpg, WW82.jpg, FlipWW82.jpg, FlipW96.jpg, FlipWW84.jpg
# Pair: Lower Second Molar and Posterior border of Ramus
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 2
# 1. Lower Second Molar: 5/5 (100.00%) of total
#     Filenames: ['FlipW87.jpg', 'W95.jpg', 'FlipWW81.jpg', 'FlipWW88.jpg', 'FlipW96.jpg']
# 2. Posterior border of Ramus: 5/5 (100.00%) of total
#     Filenames: ['FlipW87.jpg', 'W95.jpg', 'FlipWW81.jpg', 'FlipWW88.jpg', 'FlipW96.jpg']
# Filenames with the same name:
# Lower Second Molar: FlipW87.jpg, W95.jpg, FlipWW81.jpg, FlipWW88.jpg, FlipW96.jpg
# Posterior border of Ramus: FlipW87.jpg, W95.jpg, FlipWW81.jpg, FlipWW88.jpg, FlipW96.jpg
# Pair: Lower Second Molar and Upper Second Molar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 2
# 1. Lower Second Molar: 22/22 (100.00%) of total
#     Filenames: ['W84.jpg', 'FlipW87.jpg', 'FlipW91.jpg', 'FlipW92.jpg', 'W95.jpg', 'FlipW95.jpg', 'W88.jpg', 'W86.jpg', 'FlipW86.jpg', 'W97.jpg', 'FlipW97.jpg', 'WW75.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'WW81.jpg', 'FlipWW81.jpg', 'WW80.jpg', 'WW82.jpg', 'FlipWW82.jpg', 'WW88.jpg', 'FlipWW88.jpg', 'FlipW96.jpg']
# 2. Upper Second Molar: 22/22 (100.00%) of total
#     Filenames: ['W84.jpg', 'FlipW87.jpg', 'FlipW91.jpg', 'FlipW92.jpg', 'W95.jpg', 'FlipW95.jpg', 'W88.jpg', 'W86.jpg', 'FlipW86.jpg', 'W97.jpg', 'FlipW97.jpg', 'WW75.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'WW81.jpg', 'FlipWW81.jpg', 'WW80.jpg', 'WW82.jpg', 'FlipWW82.jpg', 'WW88.jpg', 'FlipWW88.jpg', 'FlipW96.jpg']
# Filenames with the same name:
# Lower Second Molar: W84.jpg, FlipW87.jpg, FlipW91.jpg, FlipW92.jpg, W95.jpg, FlipW95.jpg,
molar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 2
# 1. Lower First Molar: 9/9 (100.00%) of total
#     Filenames: ['FlipW91.jpg', 'FlipW92.jpg', 'W88.jpg', 'FlipW97.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'WW82.jpg', 'FlipWW82.jpg']
# 2. Upper First Molar: 9/9 (100.00%) of total
#     Filenames: ['FlipW91.jpg', 'FlipW92.jpg', 'W88.jpg', 'FlipW97.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'WW82.jpg', 'FlipWW82.jpg']
# Filenames with the same name:
# Lower First Molar: FlipW91.jpg, FlipW92.jpg, W88.jpg, FlipW97.jpg, WW76.jpg, FlipWW78.jpg, WW79.jpg, WW82.jpg, FlipWW82.jpg
# Upper First Molar: FlipW91.jpg, FlipW92.jpg, W88.jpg, FlipW97.jpg, WW76.jpg, FlipWW78.jpg, WW79.jpg, WW82.jpg, FlipWW82.jpg
# Pair: Lower First Molar and Lower Third Molar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 2
# 1. Lower First Molar: 9/9 (100.00%) of total
#     Filenames: ['FlipW92.jpg', 'W95.jpg', 'FlipW90.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW81.jpg', 'FlipWW82.jpg', 'WW88.jpg', 'FlipWW88.jpg']
# 2. Lower Third Molar: 9/9 (100.00%) of total
#     Filenames: ['FlipW92.jpg', 'W95.jpg', 'FlipW90.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW81.jpg', 'FlipWW82.jpg', 'WW88.jpg', 'FlipWW88.jpg']
# Filenames with the same name:
# Lower First Molar: FlipW92.jpg, W95.jpg, FlipW90.jpg, WW76.jpg, FlipWW78.jpg, WW81.jpg, FlipWW82.jpg, WW88.jpg, FlipWW88.jpg
# Lower Third Molar: FlipW92.jpg, W95.jpg, FlipW90.jpg, WW76.jpg, FlipWW78.jpg, WW81.jpg, FlipWW82.jpg, WW88.jpg, FlipWW88.jpg
# Pair: Lower First Molar and Lower Canine
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower First Molar and Upper Central Incisor
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 2
# 1. Lower First Molar: 4/4 (100.00%) of total
#     Filenames: ['WW82.jpg', 'FlipWW82.jpg', 'WW88.jpg', 'FlipW96.jpg']
# 2. Upper Central Incisor: 4/4 (100.00%) of total
#     Filenames: ['WW82.jpg', 'FlipWW82.jpg', 'WW88.jpg', 'FlipW96.jpg']
# Filenames with the same name:
# Lower First Molar: WW82.jpg, FlipWW82.jpg, WW88.jpg, FlipW96.jpg
# Upper Central Incisor: WW82.jpg, FlipWW82.jpg, WW88.jpg, FlipW96.jpg
# Pair: Lower First Molar and Upper Third Molar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 2
# 1. Lower First Molar: 7/7 (100.00%) of total
#     Filenames: ['FlipW87.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW81.jpg', 'WW82.jpg', 'WW88.jpg', 'FlipWW88.jpg']
# 2. Upper Third Molar: 7/7 (100.00%) of total
#     Filenames: ['FlipW87.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW81.jpg', 'WW82.jpg', 'WW88.jpg', 'FlipWW88.jpg']
# Filenames with the same name:
# Lower First Molar: FlipW87.jpg, WW76.jpg, FlipWW78.jpg, WW81.jpg, WW82.jpg, WW88.jpg, FlipWW88.jpg
# Upper Third Molar: FlipW87.jpg, WW76.jpg, FlipWW78.jpg, WW81.jpg, WW82.jpg, WW88.jpg, FlipWW88.jpg
# Pair: Lower First Molar and Nasal
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower First Premolar and Condyle
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 2
# 1. Lower First Premolar: 3/3 (100.00%) of total
#     Filenames: ['FlipW97.jpg', 'WW76.jpg', 'FlipWW84.jpg']
# 2. Condyle: 3/3 (100.00%) of total
#     Filenames: ['FlipW97.jpg', 'WW76.jpg', 'FlipWW84.jpg']
# Filenames with the same name:
# Lower First Premolar: FlipW97.jpg, WW76.jpg, FlipWW84.jpg
# Condyle: FlipW97.jpg, WW76.jpg, FlipWW84.jpg
# Pair: Lower First Premolar and Upper First Molar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 2
# 1. Lower First Premolar: 4/4 (100.00%) of total
#     Filenames: ['FlipW97.jpg', 'WW76.jpg', 'FlipWW82.jpg', 'FlipWW84.jpg']
# 2. Upper First Molar: 4/4 (100.00%) of total
#     Filenames: ['FlipW97.jpg', 'WW76.jpg', 'FlipWW82.jpg', 'FlipWW84.jpg']
# Filenames with the same name:
# Lower First Premolar: FlipW97.jpg, WW76.jpg, FlipWW82.jpg, FlipWW84.jpg
# Upper First Molar: FlipW97.jpg, WW76.jpg, FlipWW82.jpg, FlipWW84.jpg
# Pair: Lower First Premolar and Lower Third Molar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 2
# 1. Lower First Premolar: 4/4 (100.00%) of total
#     Filenames: ['W95.jpg', 'WW76.jpg', 'FlipWW82.jpg', 'FlipWW84.jpg']
# 2. Lower Third Molar: 4/4 (100.00%) of total
#     Filenames: ['W95.jpg', 'WW76.jpg', 'FlipWW82.jpg', 'FlipWW84.jpg']
# Filenames with the same name:
# Lower First Premolar: W95.jpg, WW76.jpg, FlipWW82.jpg, FlipWW84.jpg
# Lower Third Molar: W95.jpg, WW76.jpg, FlipWW82.jpg, FlipWW84.jpg
# Pair: Lower First Premolar and Lower Canine
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower First Premolar and Upper Central Incisor
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 2
# 1. Upper Central Incisor: 1/1 (100.00%) of total
#     Filenames: ['FlipWW82.jpg']
# 2. Lower First Premolar: 1/1 (100.00%) of total
#     Filenames: ['FlipWW82.jpg']
# Filenames with the same name:
# Upper Central Incisor: FlipWW82.jpg
# Lower First Premolar: FlipWW82.jpg
# Pair: Lower First Premolar and Upper Third Molar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 2
# 1. Lower First Premolar: 2/2 (100.00%) of total
#     Filenames: ['WW75.jpg', 'WW76.jpg']
# 2. Upper Third Molar: 2/2 (100.00%) of total
#     Filenames: ['WW75.jpg', 'WW76.jpg']
# Filenames with the same name:
# Lower First Premolar: WW75.jpg, WW76.jpg
# Upper Third Molar: WW75.jpg, WW76.jpg
# Pair: Lower First Premolar and Nasal
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Condyle and Upper First Molar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 2
# 1. Upper First Molar: 8/8 (100.00%) of total
#     Filenames: ['FlipW91.jpg', 'FlipW95.jpg', 'W88.jpg', 'FlipW97.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'FlipWW84.jpg']
# 2. Condyle: 8/8 (100.00%) of total
#     Filenames: ['FlipW91.jpg', 'FlipW95.jpg', 'W88.jpg', 'FlipW97.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'FlipWW84.jpg']
# Filenames with the same name:
# Upper First Molar: FlipW91.jpg, FlipW95.jpg, W88.jpg, FlipW97.jpg, WW76.jpg, FlipWW78.jpg, WW79.jpg, FlipWW84.jpg
# Condyle: FlipW91.jpg, FlipW95.jpg, W88.jpg, FlipW97.jpg, WW76.jpg, FlipWW78.jpg, WW79.jpg, FlipWW84.jpg
# Pair: Condyle and Lower Third Molar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 2
# 1. Condyle: 6/6 (100.00%) of total
#     Filenames: ['W84.jpg', 'FlipW95.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW85.jpg', 'FlipWW84.jpg']
# 2. Lower Third Molar: 6/6 (100.00%) of total
#     Filenames: ['W84.jpg', 'FlipW95.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW85.jpg', 'FlipWW84.jpg']
# Filenames with the same name:
# Condyle: W84.jpg, FlipW95.jpg, WW76.jpg, FlipWW78.jpg, WW85.jpg, FlipWW84.jpg
# Lower Third Molar: W84.jpg, FlipW95.jpg, WW76.jpg, FlipWW78.jpg, WW85.jpg, FlipWW84.jpg
# Pair: Condyle and Lower Canine
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Condyle and Upper Central Incisor
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Condyle and Upper Third Molar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 2
# 1. Condyle: 5/5 (100.00%) of total
#     Filenames: ['FlipW87.jpg', 'FlipW95.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW85.jpg']
# 2. Upper Third Molar: 5/5 (100.00%) of total
#     Filenames: ['FlipW87.jpg', 'FlipW95.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW85.jpg']
# Filenames with the same name:
# Condyle: FlipW87.jpg, FlipW95.jpg, WW76.jpg, FlipWW78.jpg, WW85.jpg
# Upper Third Molar: FlipW87.jpg, FlipW95.jpg, WW76.jpg, FlipWW78.jpg, WW85.jpg
# Pair: Condyle and Nasal
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper First Molar and Lower Third Molar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 2
# 1. Upper First Molar: 9/9 (100.00%) of total
#     Filenames: ['FlipW92.jpg', 'FlipW95.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'FlipWW79.jpg', 'FlipWW81.jpg', 'FlipWW80.jpg', 'FlipWW82.jpg', 'FlipWW84.jpg']
# 2. Lower Third Molar: 9/9 (100.00%) of total
#     Filenames: ['FlipW92.jpg', 'FlipW95.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'FlipWW79.jpg', 'FlipWW81.jpg', 'FlipWW80.jpg', 'FlipWW82.jpg', 'FlipWW84.jpg']
# Filenames with the same name:
# Upper First Molar: FlipW92.jpg, FlipW95.jpg, WW76.jpg, FlipWW78.jpg, FlipWW79.jpg, FlipWW81.jpg, FlipWW80.jpg, FlipWW82.jpg, FlipWW84.jpg
# Lower Third Molar: FlipW92.jpg, FlipW95.jpg, WW76.jpg, FlipWW78.jpg, FlipWW79.jpg, FlipWW81.jpg, FlipWW80.jpg, FlipWW82.jpg, FlipWW84.jpg
# Pair: Upper First Molar and Lower Canine
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper First Molar and Upper Central Incisor
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 2
# 1. Upper First Molar: 3/3 (100.00%) of total
#     Filenames: ['FlipWW80.jpg', 'WW82.jpg', 'FlipWW82.jpg']
# 2. Upper Central Incisor: 3/3 (100.00%) of total
#     Filenames: ['FlipWW80.jpg', 'WW82.jpg', 'FlipWW82.jpg']
# Filenames with the same name:
# Upper First Molar: FlipWW80.jpg, WW82.jpg, FlipWW82.jpg
# Upper Central Incisor: FlipWW80.jpg, WW82.jpg, FlipWW82.jpg
# Pair: Upper First Molar and Upper Third Molar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 2
# 1. Upper First Molar: 5/5 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'FlipWW80.jpg', 'WW82.jpg']
# 2. Upper Third Molar: 5/5 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'FlipWW80.jpg', 'WW82.jpg']
# Filenames with the same name:
# Upper First Molar: FlipW95.jpg, WW76.jpg, FlipWW78.jpg, FlipWW80.jpg, WW82.jpg
# Upper Third Molar: FlipW95.jpg, WW76.jpg, FlipWW78.jpg, FlipWW80.jpg, WW82.jpg
# Pair: Upper First Molar and Nasal
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Third Molar and Lower Canine
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Third Molar and Upper Central Incisor
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 2
# 1. Lower Third Molar: 5/5 (100.00%) of total
#     Filenames: ['W86.jpg', 'WW80.jpg', 'FlipWW80.jpg', 'FlipWW82.jpg', 'WW88.jpg']
# 2. Upper Central Incisor: 5/5 (100.00%) of total
#     Filenames: ['W86.jpg', 'WW80.jpg', 'FlipWW80.jpg', 'FlipWW82.jpg', 'WW88.jpg']
# Filenames with the same name:
# Lower Third Molar: W86.jpg, WW80.jpg, FlipWW80.jpg, FlipWW82.jpg, WW88.jpg
# Upper Central Incisor: W86.jpg, WW80.jpg, FlipWW80.jpg, FlipWW82.jpg, WW88.jpg
# Pair: Lower Third Molar and Upper Third Molar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 2
# 1. Lower Third Molar: 11/11 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'W86.jpg', 'FlipW86.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW81.jpg', 'WW85.jpg', 'WW80.jpg', 'FlipWW80.jpg', 'WW88.jpg', 'FlipWW88.jpg']
# 2. Upper Third Molar: 11/11 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'W86.jpg', 'FlipW86.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW81.jpg', 'WW85.jpg', 'WW80.jpg', 'FlipWW80.jpg', 'WW88.jpg', 'FlipWW88.jpg']
# Filenames with the same name:
# Lower Third Molar: FlipW95.jpg, W86.jpg, FlipW86.jpg, WW76.jpg, FlipWW78.jpg, WW81.jpg, WW85.jpg, WW80.jpg, FlipWW80.jpg, WW88.jpg, FlipWW88.jpg
# Upper Third Molar: FlipW95.jpg, W86.jpg, FlipW86.jpg, WW76.jpg, FlipWW78.jpg, WW81.jpg, WW85.jpg, WW80.jpg, FlipWW80.jpg, WW88.jpg, FlipWW88.jpg
# Pair: Lower Third Molar and Nasal
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Canine and Upper Central Incisor
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Canine and Upper Third Molar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Canine and Nasal
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper Central Incisor and Upper Third Molar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 2
# 1. Upper Third Molar: 5/5 (100.00%) of total
#     Filenames: ['W86.jpg', 'WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg', 'WW88.jpg']
# 2. Upper Central Incisor: 5/5 (100.00%) of total
#     Filenames: ['W86.jpg', 'WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg', 'WW88.jpg']
# Filenames with the same name:
# Upper Third Molar: W86.jpg, WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg
# Upper Central Incisor: W86.jpg, WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg
# Pair: Upper Central Incisor and Nasal
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper Third Molar and Nasal
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:

# %%
# Optional: Create a DataFrame to keep all the information together
age_neg = []
for (name1, name2), result in pair_results.items():
    for name, count in result['sorted_names']:
      if name in name1:
        age_neg.append({
            'name': name,
            'pair': name2, #'pair': f"{name1} and {name2}"
            'count': count,
            'total_1': len(age_9_neg[age_9_neg['name']== name1]),
            'percentage_1':  f"{(count / len(age_9_neg[age_9_neg['name']== name1])) * 100 :.2f}%",
            'total_2': len(age_9_neg[age_9_neg['name']== name2]),
            'percentage_2':  f"{(count / len(age_9_neg[age_9_neg['name']== name2])) * 100 :.2f}%",
            'total_files': len(age_9_neg['filename'].unique()),
            'percentage_files':  f"{(count / len(age_9_neg['filename'].unique())) * 100 :.2f}%",
            'filenames': result['name_files'][name]
        })

neg_2 = pd.DataFrame(age_neg)
neg_2
# Out:
#                       name                   pair  count  total_1  \
# 0       Lower Second Molar  Upper Second Premolar     16       26
# 1       Lower Second Molar  Lower Second Premolar     11       26
# 2       Lower Second Molar           Upper Canine     17       26
# 3       Lower Second Molar       Mandibular angle      3       26
# 4       Lower Second Molar   Upper First Premolar     10       26
# ..                     ...                    ...    ...      ...
# 111      Upper First Molar  Upper Central Incisor      3       14
# 112      Upper First Molar      Upper Third Molar      5       14
# 113      Lower Third Molar  Upper Central Incisor      5       20
# 114      Lower Third Molar      Upper Third Molar     11       20
# 115  Upper Central Incisor      Upper Third Molar      5        7
#
#     percentage_1  total_2 percentage_2  total_files percentage_files  \
# 0         61.54%       20       80.00%           32           50.00%
# 1         42.31%       14       78.57%           32           34.38%
# 2         65.38%       20       85.00%           32           53.12%
# 3         11.54%        4       75.00%           32            9.38%
# 4         38.46%       15       66.67%           32           31.25%
# ..           ...      ...          ...          ...              ...
# 111       21.43%        7       42.86%           32            9.38%
# 112       35.71%       14       35.71%           32           15.62%
# 113       25.00%        7       71.43%           32           15.62%
# 114       55.00%       14       78.57%           32           34.38%
# 115       71.43%       14       35.71%           32           15.62%
#
#                                              filenames
# 0    [W84.jpg, FlipW92.jpg, FlipW95.jpg, W88.jpg, W...
# 1    [FlipW91.jpg, FlipW92.jpg, W95.jpg, W88.jpg, W...
# 2    [W84.jpg, W95.jpg, FlipW95.jpg, W86.jpg, W97.j...
# 3                    [W84.jpg, FlipWW78.jpg, WW80.jpg]
# 4    [W95.jpg, W86.jpg, WW75.jpg, FlipWW78.jpg, WW7...
# ..                                                 ...
# 111             [FlipWW80.jpg, WW82.jpg, FlipWW82.jpg]
# 112  [FlipW95.jpg, WW76.jpg, FlipWW78.jpg, FlipWW80...
# 113  [W86.jpg, WW80.jpg, FlipWW80.jpg, FlipWW82.jpg...
# 114  [FlipW95.jpg, W86.jpg, FlipW86.jpg, WW76.jpg, ...
# 115  [W86.jpg, WW80.jpg, FlipWW80.jpg, WW82.jpg, WW...
#
# [116 rows x 10 columns]

# %%
percentage = neg_2['percentage_files'].tolist()
# Convert to a list of integers
neg_2['percentage_float'] = [float(p.replace('%', '')) for p in percentage]

# %%
neg_2
# Out:
#                       name                   pair  count  total_1  \
# 0       Lower Second Molar  Upper Second Premolar     16       26
# 1       Lower Second Molar  Lower Second Premolar     11       26
# 2       Lower Second Molar           Upper Canine     17       26
# 3       Lower Second Molar       Mandibular angle      3       26
# 4       Lower Second Molar   Upper First Premolar     10       26
# ..                     ...                    ...    ...      ...
# 111      Upper First Molar  Upper Central Incisor      3       14
# 112      Upper First Molar      Upper Third Molar      5       14
# 113      Lower Third Molar  Upper Central Incisor      5       20
# 114      Lower Third Molar      Upper Third Molar     11       20
# 115  Upper Central Incisor      Upper Third Molar      5        7
#
#     percentage_1  total_2 percentage_2  total_files percentage_files  \
# 0         61.54%       20       80.00%           32           50.00%
# 1         42.31%       14       78.57%           32           34.38%
# 2         65.38%       20       85.00%           32           53.12%
# 3         11.54%        4       75.00%           32            9.38%
# 4         38.46%       15       66.67%           32           31.25%
# ..           ...      ...          ...          ...              ...
# 111       21.43%        7       42.86%           32            9.38%
# 112       35.71%       14       35.71%           32           15.62%
# 113       25.00%        7       71.43%           32           15.62%
# 114       55.00%       14       78.57%           32           34.38%
# 115       71.43%       14       35.71%           32           15.62%
#
#                                              filenames  percentage_float
# 0    [W84.jpg, FlipW92.jpg, FlipW95.jpg, W88.jpg, W...             50.00
# 1    [FlipW91.jpg, FlipW92.jpg, W95.jpg, W88.jpg, W...             34.38
# 2    [W84.jpg, W95.jpg, FlipW95.jpg, W86.jpg, W97.j...             53.12
# 3                    [W84.jpg, FlipWW78.jpg, WW80.jpg]              9.38
# 4    [W95.jpg, W86.jpg, WW75.jpg, FlipWW78.jpg, WW7...             31.25
# ..                                                 ...               ...
# 111             [FlipWW80.jpg, WW82.jpg, FlipWW82.jpg]              9.38
# 112  [FlipW95.jpg, WW76.jpg, FlipWW78.jpg, FlipWW80...             15.62
# 113  [W86.jpg, WW80.jpg, FlipWW80.jpg, FlipWW82.jpg...             15.62
# 114  [FlipW95.jpg, W86.jpg, FlipW86.jpg, WW76.jpg, ...             34.38
# 115  [W86.jpg, WW80.jpg, FlipWW80.jpg, WW82.jpg, WW...             15.62
#
# [116 rows x 11 columns]

# %%
neg_2_sort =  neg_2.sort_values(by='percentage_float', ascending=False)

# %%
neg_2_sort
# Out:
#                           name                   pair  count  total_1  \
# 7           Lower Second Molar     Upper Second Molar     22       26
# 45                Upper Canine     Upper Second Molar     18       20
# 2           Lower Second Molar           Upper Canine     17       26
# 21       Upper Second Premolar     Upper Second Molar     17       20
# 93          Upper Second Molar      Lower Third Molar     17       27
# ..                         ...                    ...    ...      ...
# 105       Lower First Premolar  Upper Central Incisor      1        6
# 56            Mandibular angle      Lower First Molar      1        4
# 83   Posterior border of Ramus   Lower First Premolar      1        7
# 54            Mandibular angle  Upper Lateral Incisor      1        4
# 87   Posterior border of Ramus  Upper Central Incisor      1        7
#
#     percentage_1  total_2 percentage_2  total_files percentage_files  \
# 7         84.62%       27       81.48%           32           68.75%
# 45        90.00%       27       66.67%           32           56.25%
# 2         65.38%       20       85.00%           32           53.12%
# 21        85.00%       27       62.96%           32           53.12%
# 93        62.96%       20       85.00%           32           53.12%
# ..           ...      ...          ...          ...              ...
# 105       16.67%        7       14.29%           32            3.12%
# 56        25.00%       19        5.26%           32            3.12%
# 83        14.29%        6       16.67%           32            3.12%
# 54        25.00%       11        9.09%           32            3.12%
# 87        14.29%        7       14.29%           32            3.12%
#
#                                              filenames  percentage_float
# 7    [W84.jpg, FlipW87.jpg, FlipW91.jpg, FlipW92.jp...             68.75
# 45   [W84.jpg, W95.jpg, FlipW95.jpg, W86.jpg, W97.j...             56.25
# 2    [W84.jpg, W95.jpg, FlipW95.jpg, W86.jpg, W97.j...             53.12
# 21   [W84.jpg, W92.jpg, FlipW92.jpg, FlipW95.jpg, W...             53.12
# 93   [W84.jpg, W92.jpg, FlipW92.jpg, W95.jpg, FlipW...             53.12
# ..                                                 ...               ...
# 105                                     [FlipWW82.jpg]              3.12
# 56                                      [FlipWW78.jpg]              3.12
# 83                                           [W95.jpg]              3.12
# 54                                      [FlipWW78.jpg]              3.12
# 87                                       [FlipW96.jpg]              3.12
#
# [116 rows x 11 columns]

# %%
table = neg_2_sort.reset_index()
table = table.iloc[:,1:]
table
# Out:
#                           name                   pair  count  total_1  \
# 0           Lower Second Molar     Upper Second Molar     22       26
# 1                 Upper Canine     Upper Second Molar     18       20
# 2           Lower Second Molar           Upper Canine     17       26
# 3        Upper Second Premolar     Upper Second Molar     17       20
# 4           Upper Second Molar      Lower Third Molar     17       27
# ..                         ...                    ...    ...      ...
# 111       Lower First Premolar  Upper Central Incisor      1        6
# 112           Mandibular angle      Lower First Molar      1        4
# 113  Posterior border of Ramus   Lower First Premolar      1        7
# 114           Mandibular angle  Upper Lateral Incisor      1        4
# 115  Posterior border of Ramus  Upper Central Incisor      1        7
#
#     percentage_1  total_2 percentage_2  total_files percentage_files  \
# 0         84.62%       27       81.48%           32           68.75%
# 1         90.00%       27       66.67%           32           56.25%
# 2         65.38%       20       85.00%           32           53.12%
# 3         85.00%       27       62.96%           32           53.12%
# 4         62.96%       20       85.00%           32           53.12%
# ..           ...      ...          ...          ...              ...
# 111       16.67%        7       14.29%           32            3.12%
# 112       25.00%       19        5.26%           32            3.12%
# 113       14.29%        6       16.67%           32            3.12%
# 114       25.00%       11        9.09%           32            3.12%
# 115       14.29%        7       14.29%           32            3.12%
#
#                                              filenames  percentage_float
# 0    [W84.jpg, FlipW87.jpg, FlipW91.jpg, FlipW92.jp...             68.75
# 1    [W84.jpg, W95.jpg, FlipW95.jpg, W86.jpg, W97.j...             56.25
# 2    [W84.jpg, W95.jpg, FlipW95.jpg, W86.jpg, W97.j...             53.12
# 3    [W84.jpg, W92.jpg, FlipW92.jpg, FlipW95.jpg, W...             53.12
# 4    [W84.jpg, W92.jpg, FlipW92.jpg, W95.jpg, FlipW...             53.12
# ..                                                 ...               ...
# 111                                     [FlipWW82.jpg]              3.12
# 112                                     [FlipWW78.jpg]              3.12
# 113                                          [W95.jpg]              3.12
# 114                                     [FlipWW78.jpg]              3.12
# 115                                      [FlipW96.jpg]              3.12
#
# [116 rows x 11 columns]

# %%
table.to_csv('/content/gdrive/My Drive/Tooth_Shap_GPT/Deep_tooth/OPG_SHAPer/Result/Age/95_percentie/Neg_9/(2)ALL_.csv', index=False)

# %%
table[table['percentage_float']>=50.00]
# Out:
#                     name                   pair  count  total_1 percentage_1  \
# 0     Lower Second Molar     Upper Second Molar     22       26       84.62%
# 1           Upper Canine     Upper Second Molar     18       20       90.00%
# 2     Lower Second Molar           Upper Canine     17       26       65.38%
# 3  Upper Second Premolar     Upper Second Molar     17       20       85.00%
# 4     Upper Second Molar      Lower Third Molar     17       27       62.96%
# 5     Lower Second Molar      Lower First Molar     17       26       65.38%
# 6     Lower Second Molar  Upper Second Premolar     16       26       61.54%
# 7     Lower Second Molar      Lower Third Molar     16       26       61.54%
# 8     Upper Second Molar      Lower First Molar     16       27       59.26%
#
#    total_2 percentage_2  total_files percentage_files  \
# 0       27       81.48%           32           68.75%
# 1       27       66.67%           32           56.25%
# 2       20       85.00%           32           53.12%
# 3       27       62.96%           32           53.12%
# 4       20       85.00%           32           53.12%
# 5       19       89.47%           32           53.12%
# 6       20       80.00%           32           50.00%
# 7       20       80.00%           32           50.00%
# 8       19       84.21%           32           50.00%
#
#                                            filenames  percentage_float
# 0  [W84.jpg, FlipW87.jpg, FlipW91.jpg, FlipW92.jp...             68.75
# 1  [W84.jpg, W95.jpg, FlipW95.jpg, W86.jpg, W97.j...             56.25
# 2  [W84.jpg, W95.jpg, FlipW95.jpg, W86.jpg, W97.j...             53.12
# 3  [W84.jpg, W92.jpg, FlipW92.jpg, FlipW95.jpg, W...             53.12
# 4  [W84.jpg, W92.jpg, FlipW92.jpg, W95.jpg, FlipW...             53.12
# 5  [FlipW87.jpg, FlipW91.jpg, FlipW92.jpg, W95.jp...             53.12
# 6  [W84.jpg, FlipW92.jpg, FlipW95.jpg, W88.jpg, W...             50.00
# 7  [W84.jpg, FlipW92.jpg, W95.jpg, FlipW95.jpg, W...             50.00
# 8  [FlipW87.jpg, FlipW91.jpg, FlipW92.jpg, W95.jp...             50.00

# %%
table = table[table['percentage_float']>=50.00]
table
# Out:
#                     name                   pair  count  total_1 percentage_1  \
# 0     Lower Second Molar     Upper Second Molar     22       26       84.62%
# 1           Upper Canine     Upper Second Molar     18       20       90.00%
# 2     Lower Second Molar           Upper Canine     17       26       65.38%
# 3  Upper Second Premolar     Upper Second Molar     17       20       85.00%
# 4     Upper Second Molar      Lower Third Molar     17       27       62.96%
# 5     Lower Second Molar      Lower First Molar     17       26       65.38%
# 6     Lower Second Molar  Upper Second Premolar     16       26       61.54%
# 7     Lower Second Molar      Lower Third Molar     16       26       61.54%
# 8     Upper Second Molar      Lower First Molar     16       27       59.26%
#
#    total_2 percentage_2  total_files percentage_files  \
# 0       27       81.48%           32           68.75%
# 1       27       66.67%           32           56.25%
# 2       20       85.00%           32           53.12%
# 3       27       62.96%           32           53.12%
# 4       20       85.00%           32           53.12%
# 5       19       89.47%           32           53.12%
# 6       20       80.00%           32           50.00%
# 7       20       80.00%           32           50.00%
# 8       19       84.21%           32           50.00%
#
#                                            filenames  percentage_float
# 0  [W84.jpg, FlipW87.jpg, FlipW91.jpg, FlipW92.jp...             68.75
# 1  [W84.jpg, W95.jpg, FlipW95.jpg, W86.jpg, W97.j...             56.25
# 2  [W84.jpg, W95.jpg, FlipW95.jpg, W86.jpg, W97.j...             53.12
# 3  [W84.jpg, W92.jpg, FlipW92.jpg, FlipW95.jpg, W...             53.12
# 4  [W84.jpg, W92.jpg, FlipW92.jpg, W95.jpg, FlipW...             53.12
# 5  [FlipW87.jpg, FlipW91.jpg, FlipW92.jpg, W95.jp...             53.12
# 6  [W84.jpg, FlipW92.jpg, FlipW95.jpg, W88.jpg, W...             50.00
# 7  [W84.jpg, FlipW92.jpg, W95.jpg, FlipW95.jpg, W...             50.00
# 8  [FlipW87.jpg, FlipW91.jpg, FlipW92.jpg, W95.jp...             50.00

# %%
table = table.iloc[:,:-1]

# %%
table
# Out:
#                     name                   pair  count  total_1 percentage_1  \
# 0     Lower Second Molar     Upper Second Molar     22       26       84.62%
# 1           Upper Canine     Upper Second Molar     18       20       90.00%
# 2     Lower Second Molar           Upper Canine     17       26       65.38%
# 3  Upper Second Premolar     Upper Second Molar     17       20       85.00%
# 4     Upper Second Molar      Lower Third Molar     17       27       62.96%
# 5     Lower Second Molar      Lower First Molar     17       26       65.38%
# 6     Lower Second Molar  Upper Second Premolar     16       26       61.54%
# 7     Lower Second Molar      Lower Third Molar     16       26       61.54%
# 8     Upper Second Molar      Lower First Molar     16       27       59.26%
#
#    total_2 percentage_2  total_files percentage_files  \
# 0       27       81.48%           32           68.75%
# 1       27       66.67%           32           56.25%
# 2       20       85.00%           32           53.12%
# 3       27       62.96%           32           53.12%
# 4       20       85.00%           32           53.12%
# 5       19       89.47%           32           53.12%
# 6       20       80.00%           32           50.00%
# 7       20       80.00%           32           50.00%
# 8       19       84.21%           32           50.00%
#
#                                            filenames
# 0  [W84.jpg, FlipW87.jpg, FlipW91.jpg, FlipW92.jp...
# 1  [W84.jpg, W95.jpg, FlipW95.jpg, W86.jpg, W97.j...
# 2  [W84.jpg, W95.jpg, FlipW95.jpg, W86.jpg, W97.j...
# 3  [W84.jpg, W92.jpg, FlipW92.jpg, FlipW95.jpg, W...
# 4  [W84.jpg, W92.jpg, FlipW92.jpg, W95.jpg, FlipW...
# 5  [FlipW87.jpg, FlipW91.jpg, FlipW92.jpg, W95.jp...
# 6  [W84.jpg, FlipW92.jpg, FlipW95.jpg, W88.jpg, W...
# 7  [W84.jpg, FlipW92.jpg, W95.jpg, FlipW95.jpg, W...
# 8  [FlipW87.jpg, FlipW91.jpg, FlipW92.jpg, W95.jp...

# %%
table.to_csv('/content/gdrive/My Drive/Tooth_Shap_GPT/Deep_tooth/OPG_SHAPer/Result/Age/95_percentie/Neg_9/(2)ALL_(>=50%).csv', index=False)

# %% [markdown]
# ### 3 with combinations (472/99 rows)

# %%
from itertools import combinations

# List of names
names = [
    'Lower Second Molar', 'Upper Second Premolar', 'Lower Second Premolar',
    'Upper Canine', 'Mandibular angle', 'Upper First Premolar',
    'Upper Lateral Incisor', 'Posterior border of Ramus', 'Upper Second Molar',
    'Lower First Molar', 'Lower First Premolar', 'Condyle', 'Upper First Molar',
    'Lower Third Molar', 'Lower Canine', 'Upper Central Incisor',
    'Upper Third Molar', 'Nasal'
]

# Get all combinations of names with length 2
pairs_of_names = list(combinations(names, 3))
print(pairs_of_names)
# Out:
# [('Lower Second Molar', 'Upper Second Premolar', 'Lower Second Premolar'), ('Lower Second Molar', 'Upper Second Premolar', 'Upper Canine'), ('Lower Second Molar', 'Upper Second Premolar', 'Mandibular angle'), ('Lower Second Molar', 'Upper Second Premolar', 'Upper First Premolar'), ('Lower Second Molar', 'Upper Second Premolar', 'Upper Lateral Incisor'), ('Lower Second Molar', 'Upper Second Premolar', 'Posterior border of Ramus'), ('Lower Second Molar', 'Upper Second Premolar', 'Upper Second Molar'), ('Lower Second Molar', 'Upper Second Premolar', 'Lower First Molar'), ('Lower Second Molar', 'Upper Second Premolar', 'Lower First Premolar'), ('Lower Second Molar', 'Upper Second Premolar', 'Condyle'), ('Lower Second Molar', 'Upper Second Premolar', 'Upper First Molar'), ('Lower Second Molar', 'Upper Second Premolar', 'Lower Third Molar'), ('Lower Second Molar', 'Upper Second Premolar', 'Lower Canine'), ('Lower Second Molar', 'Upper Second Premolar', 'Upper Central Incisor'), ('Lower Second Molar', 'Upper Second Premolar', 'Upper Third Molar'), ('Lower Second Molar', 'Upper Second Premolar', 'Nasal'), ('Lower Second Molar', 'Lower Second Premolar', 'Upper Canine'), ('Lower Second Molar', 'Lower Second Premolar', 'Mandibular angle'), ('Lower Second Molar', 'Lower Second Premolar', 'Upper First Premolar'), ('Lower Second Molar', 'Lower Second Premolar', 'Upper Lateral Incisor'), ('Lower Second Molar', 'Lower Second Premolar', 'Posterior border of Ramus'), ('Lower Second Molar', 'Lower Second Premolar', 'Upper Second Molar'), ('Lower Second Molar', 'Lower Second Premolar', 'Lower First Molar'), ('Lower Second Molar', 'Lower Second Premolar', 'Lower First Premolar'), ('Lower Second Molar', 'Lower Second Premolar', 'Condyle'), ('Lower Second Molar', 'Lower Second Premolar', 'Upper First Molar'), ('Lower Second Molar', 'Lower Second Premolar', 'Lower Third Molar'), ('Lower Second Molar', 'Lower Second Premolar', 'Lower Canine'), ('Lower Second Molar', 'Lower Second Premolar', 'Upper Central Incisor'), ('Lower Second Molar', 'Lower Second Premolar', 'Upper Third Molar'), ('Lower Second Molar', 'Lower Second Premolar', 'Nasal'), ('Lower Second Molar', 'Upper Canine', 'Mandibular angle'), ('Lower Second Molar', 'Upper Canine', 'Upper First Premolar'), ('Lower Second Molar', 'Upper Canine', 'Upper Lateral Incisor'), ('Lower Second Molar', 'Upper Canine', 'Posterior border of Ramus'), ('Lower Second Molar', 'Upper Canine', 'Upper Second Molar'), ('Lower Second Molar', 'Upper Canine', 'Lower First Molar'), ('Lower Second Molar', 'Upper Canine', 'Lower First Premolar'), ('Lower Second Molar', 'Upper Canine', 'Condyle'), ('Lower Second Molar', 'Upper Canine', 'Upper First Molar'), ('Lower Second Molar', 'Upper Canine', 'Lower Third Molar'), ('Lower Second Molar', 'Upper Canine', 'Lower Canine'), ('Lower Second Molar', 'Upper Canine', 'Upper Central Incisor'), ('Lower Second Molar', 'Upper Canine', 'Upper Third Molar'), ('Lower Second Molar', 'Upper Canine', 'Nasal'), ('Lower Second Molar', 'Mandibular angle', 'Upper First Premolar'), ('Lower Second Molar', 'Mandibular angle', 'Upper Lateral Incisor'), ('Lower Second Molar', 'Mandibular angle', 'Posterior border of Ramus'), ('Lower Second Molar', 'Mandibular angle', 'Upper Second Molar'), ('Lower Second Molar', 'Mandibular angle', 'Lower First Molar'), ('Lower Second Molar', 'Mandibular angle', 'Lower First Premolar'), ('Lower Second Molar', 'Mandibular angle', 'Condyle'), ('Lower Second Molar', 'Mandibular angle', 'Upper First Molar'), ('Lower Second Molar', 'Mandibular angle', 'Lower Third Molar'), ('Lower Second Molar', 'Mandibular angle', 'Lower Canine'), ('Lower Second Molar', 'Mandibular angle', 'Upper Central Incisor'), ('Lower Second Molar', 'Mandibular angle', 'Upper Third Molar'), ('Lower Second Molar', 'Mandibular angle', 'Nasal'), ('Lower Second Molar', 'Upper First Premolar', 'Upper Lateral Incisor'), ('Lower Second Molar', 'Upper First Premolar', 'Posterior border of Ramus'), ('Low ...

# %%
len(pairs_of_names)
# Out:
# 816

# %%
import pandas as pd

# Dictionary to store results for each pair
pair_results = {}

for name1, name2, name3 in pairs_of_names:
    # Identify filenames that contain name1
    A = set(age_9_neg[age_9_neg['name'] == name1]['filename'])

    # Identify filenames that contain name2
    B = set(age_9_neg[age_9_neg['name'] == name2]['filename'])

    # Identify filenames that contain name3
    C = set(age_9_neg[age_9_neg['name'] == name3]['filename'])

    # Find the intersection of the three sets to get filenames that contain name1, name2, and name3
    common_filenames = A.intersection(B).intersection(C)

    # Filter the DataFrame to include only the common filenames
    filtered_filenames = age_9_neg[age_9_neg['filename'].isin(common_filenames)]

    # Filter the DataFrame to include only name1, name2, or name3
    filtered_region = filtered_filenames[filtered_filenames['name'].isin([name1, name2, name3])]

    # Dictionary to store name counts and associated filenames
    name_count_neg = {}
    name_files = {}

    # List of names
    list_neg = filtered_region['name'].tolist()
    # List of filenames
    filenames = filtered_region['filename'].tolist()

    # Iterate over each name and corresponding filename
    for name, filename in zip(list_neg, filenames):
        if name in name_count_neg:
            name_count_neg[name] += 1
            name_files[name].append(filename)
        else:
            name_count_neg[name] = 1
            name_files[name] = [filename]

    # Sort the name_count_neg dictionary by count of occurrences (descending order)
    sorted_names = sorted(name_count_neg.items(), key=lambda x: x[1], reverse=True)

    # Store the results in the dictionary
    pair_results[(name1, name2, name3)] = {
        'sorted_names': sorted_names,
        'name_files': name_files
    }

    # Print a summary for this pair
    print(f"Pair: {name1}, {name2} and {name3}")
    print("Unique names and their occurrences in negative SHAP values area:")
    total_unique_names = len(sorted_names)
    print(f"Total Unique Names: {total_unique_names}")

    for i, (name, count) in enumerate(sorted_names, start=1):
        unique_filenames = len(set(name_files[name]))  # Calculate unique filenames
        print(f"{i}. {name}: {count}/{len(filtered_region['filename'].unique())} ({(count / len(filtered_region['filename'].unique())):.2%}) of total")
        print(f"    Filenames: {name_files[name]}")

    print("Filenames with the same name:")
    for name, filenames in name_files.items():
        if len(set(filenames)) >= 1:  # Only consider names that appear in more than one filename
            print(f"{name}: {', '.join(filenames)}")
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
# Total Unique Names: 3
# 1. Upper Second Premolar: 6/6 (100.00%) of total
#     Filenames: ['W84.jpg', 'FlipW95.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW85.jpg', 'FlipWW84.jpg']
# 2. Condyle: 6/6 (100.00%) of total
#     Filenames: ['W84.jpg', 'FlipW95.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW85.jpg', 'FlipWW84.jpg']
# 3. Lower Third Molar: 6/6 (100.00%) of total
#     Filenames: ['W84.jpg', 'FlipW95.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW85.jpg', 'FlipWW84.jpg']
# Filenames with the same name:
# Upper Second Premolar: W84.jpg, FlipW95.jpg, WW76.jpg, FlipWW78.jpg, WW85.jpg, FlipWW84.jpg
# Condyle: W84.jpg, FlipW95.jpg, WW76.jpg, FlipWW78.jpg, WW85.jpg, FlipWW84.jpg
# Lower Third Molar: W84.jpg, FlipW95.jpg, WW76.jpg, FlipWW78.jpg, WW85.jpg, FlipWW84.jpg
# Pair: Upper Second Premolar, Condyle and Lower Canine
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper Second Premolar, Condyle and Upper Central Incisor
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper Second Premolar, Condyle and Upper Third Molar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 3
# 1. Upper Second Premolar: 4/4 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW85.jpg']
# 2. Condyle: 4/4 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW85.jpg']
# 3. Upper Third Molar: 4/4 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW85.jpg']
# Filenames with the same name:
# Upper Second Premolar: FlipW95.jpg, WW76.jpg, FlipWW78.jpg, WW85.jpg
# Condyle: FlipW95.jpg, WW76.jpg, FlipWW78.jpg, WW85.jpg
# Upper Third Molar: FlipW95.jpg, WW76.jpg, FlipWW78.jpg, WW85.jpg
# Pair: Upper Second Premolar, Condyle and Nasal
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper Second Premolar, Upper First Molar and Lower Third Molar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 3
# 1. Upper First Molar: 7/7 (100.00%) of total
#     Filenames: ['FlipW92.jpg', 'FlipW95.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'FlipWW79.jpg', 'FlipWW82.jpg', 'FlipWW84.jpg']
# 2. Upper Second Premolar: 7/7 (100.00%) of total
#     Filenames: ['FlipW92.jpg', 'FlipW95.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'FlipWW79.jpg', 'FlipWW82.jpg', 'FlipWW84.jpg']
# 3. Lower Third Molar: 7/7 (100.00%) of total
#     Filenames: ['FlipW92.jpg', 'FlipW95.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'FlipWW79.jpg', 'FlipWW82.jpg', 'FlipWW84.jpg']
# Filenames with the same name:
# Upper First Molar: FlipW92.jpg, FlipW95.jpg, WW76.jpg, FlipWW78.jpg, FlipWW79.jpg, FlipWW82.jpg, FlipWW84.jpg
# Upper Second Premolar: FlipW92.jpg, FlipW95.jpg, WW76.jpg, FlipWW78.jpg, FlipWW79.jpg, FlipWW82.jpg, FlipWW84.jpg
# Lower Third Molar: FlipW92.jpg, FlipW95.jpg, WW76.jpg, FlipWW78.jpg, FlipWW79.jpg, FlipWW82.jpg, FlipWW84.jpg
# Pair: Upper Second Premolar, Upper First Molar and Lower Canine
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper Second Premolar, Upper First Molar and Upper Central Incisor
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 3
# 1. Upper First Molar: 2/2 (100.00%) of total
#     Filenames: ['WW82.jpg', 'FlipWW82.jpg']
# 2. Upper Central Incisor: 2/2 (100.00%) of total
#     Filenames: ['WW82.jpg', 'FlipWW82.jpg']
# 3. Upper Second Premolar: 2/2 (100.00%) of total
#     Filenames: ['WW82.jpg', 'FlipWW82.jpg']
# Filenames with the same name:
# Upper First Molar: WW82.jpg, FlipWW82.jpg
# Upper Central Incisor: WW82.jpg, FlipWW82.jpg
# Upper Second Premolar: WW82.jpg, FlipWW82.jpg
# Pair: Upper Second Premolar, Upper First Molar and Upper Third Molar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 3
# 1. Upper Second Premolar: 4/4 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW82.jpg']
# 2. Upper First Molar: 4/4 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW82.jpg']
# 3. Upper Third Molar: 4/4 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW82.jpg']
# Filenames with the same name:
# Upper Second Premolar: FlipW95.jpg, WW76.jpg, FlipWW78.jpg, WW82.jpg
# Upper First Molar: FlipW95.jpg, WW76.jpg, FlipWW78.jpg, WW82.jpg
# Upper Third Molar: FlipW95.jpg, WW76.jpg, FlipWW78.jpg, WW82.jpg
# Pair: Upper Second Premolar, Upper First Molar and Nasal
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper Second Premolar, Lower Third Molar and Lower Canine
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper Second Premolar, Lower Third Molar and Upper Central Incisor
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 3
# 1. Upper Second Premolar: 2/2 (100.00%) of total
#     Filenames: ['W86.jpg', 'FlipWW82.jpg']
# 2. Lower Third Molar: 2/2 (100.00%) of total
#     Filenames: ['W86.jpg', 'FlipWW82.jpg']
# 3. Upper Central Incisor: 2/2 (100.00%) of total
#     Filenames: ['W86.jpg', 'FlipWW82.jpg']
# Filenames with the same name:
# Upper Second Premolar: W86.jpg, FlipWW82.jpg
# Lower Third Molar: W86.jpg, FlipWW82.jpg
# Upper Central Incisor: W86.jpg, FlipWW82.jpg
# Pair: Upper Second Premolar, Lower Third Molar and Upper Third Molar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 3
# 1. Lower Third Molar: 6/6 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'W86.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW81.jpg', 'WW85.jpg']
# 2. Upper Second Premolar: 6/6 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'W86.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW81.jpg', 'WW85.jpg']
# 3. Upper Third Molar: 6/6 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'W86.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW81.jpg', 'WW85.jpg']
# Filenames with the same name:
# Lower Third Molar: FlipW95.jpg, W86.jpg, WW76.jpg, FlipWW78.jpg, WW81.jpg, WW85.jpg
# Upper Second Premolar: FlipW95.jpg, W86.jpg, WW76.jpg, FlipWW78.jpg, WW81.jpg, WW85.jpg
# Upper Third Molar: FlipW95.jpg, W86.jpg, WW76.jpg, FlipWW78.jpg, WW81.jpg, WW85.jpg
# Pair: Upper Second Premolar, Lower Third Molar and Nasal
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper Second Premolar, Lower Canine and Upper Central Incisor
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper Second Premolar, Lower Canine and Upper Third Molar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper Second Premolar, Lower Canine and Nasal
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper Second Premolar, Upper Central Incisor and Upper Third Molar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 3
# 1. Upper Second Premolar: 2/2 (100.00%) of total
#     Filenames: ['W86.jpg', 'WW82.jpg']
# 2. Upper Third Molar: 2/2 (100.00%) of total
#     Filenames: ['W86.jpg', 'WW82.jpg']
# 3. Upper Central Incisor: 2/2 (100.00%) of total
#     Filenames: ['W86.jpg', 'WW82.jpg']
# Filenames with the same name:
# Upper Second Premolar: W86.jpg, WW82.jpg
# Upper Third Molar: W86.jpg, WW82.jpg
# Upper Central Incisor: W86.jpg, WW82.jpg
# Pair: Upper Second Premolar, Upper Central Incisor and Nasal
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper Second Premolar, Upper Third Molar and Nasal
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Second Premolar, Upper Canine and Mandibular angle
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Second Premolar, Upper Canine and Upper First Premolar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 3
# 1. Lower Second Premolar: 3/3 (100.00%) of total
#     Filenames: ['W95.jpg', 'W86.jpg', 'WW81.jpg']
# 2. Upper Canine: 3/3 (100.00%) of total
#     Filenames: ['W95.jpg', 'W86.jpg', 'WW81.jpg']
# 3. Upper First Premolar: 3/3 (100.00%) of total
#     Filenames: ['W95.jpg', 'W86.jpg', 'WW81.jpg']
# Filenames with the same name:
# Lower Second Premolar: W95.jpg, W86.jpg, WW81.jpg
# Upper Canine: W95.jpg, W86.jpg, WW81.jpg
# Upper First Premolar: W95.jpg, W86.jpg, WW81.jpg
# Pair: Lower Second Premolar, Upper Canine and Upper Lateral Incisor
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 3
# 1. Lower Second Premolar: 2/2 (100.00%) of total
#     Filenames: ['W95.jpg', 'FlipW90.jpg']
# 2. Upper Canine: 2/2 (100.00%) of total
#     Filenames: ['W95.jpg', 'FlipW90.jpg']
# 3. Upper Lateral Incisor: 2/2 (100.00%) of total
#     Filenames: ['W95.jpg', 'FlipW90.jpg']
# Filenames with the same name:
# Lower Second Premolar: W95.jpg, FlipW90.jpg
# Upper Canine: W95.jpg, FlipW90.jpg
# Upper Lateral Incisor: W95.jpg, FlipW90.jpg
# Pair: Lower Second Premolar, Upper Canine and Posterior border of Ramus
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 3
# 1. Lower Second Premolar: 1/1 (100.00%) of total
#     Filenames: ['W95.jpg']
# 2. Upper Canine: 1/1 (100.00%) of total
#     Filenames: ['W95.jpg']
# 3. Posterior border of Ramus: 1/1 (100.00%) of total
#     Filenames: ['W95.jpg']
# Filenames with the same name:
# Lower Second Premolar: W95.jpg
# Upper Canine: W95.jpg
# Posterior border of Ramus: W95.jpg
# Pair: Lower Second Premolar, Upper Canine and Upper Second Molar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 3
# 1. Upper Second Molar: 5/5 (100.00%) of total
#     Filenames: ['W95.jpg', 'W86.jpg', 'FlipW97.jpg', 'WW81.jpg', 'WW88.jpg']
# 2. Lower Second Premolar: 5/5 (100.00%) of total
#     Filenames: ['W95.jpg', 'W86.jpg', 'FlipW97.jpg', 'WW81.jpg', 'WW88.jpg']
# 3. Upper Canine: 5/5 (100.00%) of total
#     Filenames: ['W95.jpg', 'W86.jpg', 'FlipW97.jpg', 'WW81.jpg', 'WW88.jpg']
# Filenames with the same name:
# Upper Second Molar: W95.jpg, W86.jpg, FlipW97.jpg, WW81.jpg, WW88.jpg
# Lower Second Premolar: W95.jpg, W86.jpg, FlipW97.jpg, WW81.jpg, WW88.jpg
# Upper Canine: W95.jpg, W86.jpg, FlipW97.jpg, WW81.jpg, WW88.jpg
# Pair: Lower Second Premolar, Upper Canine and Lower First Molar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 3
# 1. Lower First Molar: 5/5 (100.00%) of total
#     Filenames: ['W95.jpg', 'FlipW97.jpg', 'FlipW90.jpg', 'WW81.jpg', 'WW88.jpg']
# 2. Lower Second Premolar: 5/5 (100.00%) of total
#     Filenames: ['W95.jpg', 'FlipW97.jpg', 'FlipW90.jpg', 'WW81.jpg', 'WW88.jpg']
# 3. Upper Canine: 5/5 (100.00%) of total
#     Filenames: ['W95.jpg', 'FlipW97.jpg', 'FlipW90.jpg', 'WW81.jpg', 'WW88.jpg']
# Filenames with the same name:
# Lower First Molar: W95.jpg, FlipW97.jpg, FlipW90.jpg, WW81.jpg, WW88.jpg
# Lower Second Premolar: W95.jpg, FlipW97.jpg, FlipW90.jpg, WW81.jpg, WW88.jpg
# Upper Canine: W95.jpg, FlipW97.jpg, FlipW90.jpg, WW81.jpg, WW88.jpg
# Pair: Lower Second Premolar, Upper Canine and Lower First Premolar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 3
# 1. Lower First Premolar: 2/2 (100.00%) of total
#     Filenames: ['W95.jpg', 'FlipW97.jpg']
# 2. Lower Second Premolar: 2/2 (100.00%) of total
#     Filenames: ['W95.jpg', 'FlipW97.jpg']
# 3. Upper Canine: 2/2 (100.00%) of total
#     Filenames: ['W95.jpg', 'FlipW97.jpg']
# Filenames with the same name:
# Lower First Premolar: W95.jpg, FlipW97.jpg
# Lower Second Premolar: W95.jpg, FlipW97.jpg
# Upper Canine: W95.jpg, FlipW97.jpg
# Pair: Lower Second Premolar, Upper Canine and Condyle
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 3
# 1. Upper Canine: 1/1 (100.00%) of total
#     Filenames: ['FlipW97.jpg']
# 2. Lower Second Premolar: 1/1 (100.00%) of total
#     Filenames: ['FlipW97.jpg']
# 3. Condyle: 1/1 (100.00%) of total
#     Filenames: ['FlipW97.jpg']
# Filenames with the same name:
# Upper Canine: FlipW97.jpg
# Lower Second Premolar: FlipW97.jpg
# Condyle: FlipW97.jpg
# Pair: Lower Second Premolar, Upper Canine and Upper First Molar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 3
# 1. Upper Canine: 1/1 (100.00%) of total
#     Filenames: ['FlipW97.jpg']
# 2. Lower Second Premolar: 1/1 (100.00%) of total
#     Filenames: ['FlipW97.jpg']
# 3. Upper First Molar: 1/1 (100.00%) of total
#     Filenames: ['FlipW97.jpg']
# Filenames with the same name:
# Upper Canine: FlipW97.jpg
# Lower Second Premolar: FlipW97.jpg
# Upper First Molar: FlipW97.jpg
# Pair: Lower Second Premolar, Upper Canine and Lower Third Molar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 3
# 1. Lower Second Premolar: 5/5 (100.00%) of total
#     Filenames: ['W95.jpg', 'W86.jpg', 'FlipW90.jpg', 'WW81.jpg', 'WW88.jpg']
# 2. Lower Third Molar: 5/5 (100.00%) of total
#     Filenames: ['W95.jpg', 'W86.jpg', 'FlipW90.jpg', 'WW81.jpg', 'WW88.jpg']
# 3. Upper Canine: 5/5 (100.00%) of total
#     Filenames: ['W95.jpg', 'W86.jpg', 'FlipW90.jpg', 'WW81.jpg', 'WW88.jpg']
# Filenames with the same name:
# Lower Second Premolar: W95.jpg, W86.jpg, FlipW90.jpg, WW81.jpg, WW88.jpg
# Lower Third Molar: W95.jpg, W86.jpg, FlipW90.jpg, WW81.jpg, WW88.jpg
# Upper Canine: W95.jpg, W86.jpg, FlipW90.jpg, WW81.jpg, WW88.jpg
# Pair: Lower Second Premolar, Upper Canine and Lower Canine
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Second Premolar, Upper Canine and Upper Central Incisor
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 3
# 1. Lower Second Premolar: 2/2 (100.00%) of total
#     Filenames: ['W86.jpg', 'WW88.jpg']
# 2. Upper Canine: 2/2 (100.00%) of total
#     Filenames: ['W86.jpg', 'WW88.jpg']
# 3. Upper Central Incisor: 2/2 (100.00%) of total
#     Filenames: ['W86.jpg', 'WW88.jpg']
# Filenames with the same name:
# Lower Second Premolar: W86.jp
Upper Central Incisor and Nasal
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper First Molar, Upper Third Molar and Nasal
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Third Molar, Lower Canine and Upper Central Incisor
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Third Molar, Lower Canine and Upper Third Molar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Third Molar, Lower Canine and Nasal
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Third Molar, Upper Central Incisor and Upper Third Molar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 3
# 1. Lower Third Molar: 4/4 (100.00%) of total
#     Filenames: ['W86.jpg', 'WW80.jpg', 'FlipWW80.jpg', 'WW88.jpg']
# 2. Upper Third Molar: 4/4 (100.00%) of total
#     Filenames: ['W86.jpg', 'WW80.jpg', 'FlipWW80.jpg', 'WW88.jpg']
# 3. Upper Central Incisor: 4/4 (100.00%) of total
#     Filenames: ['W86.jpg', 'WW80.jpg', 'FlipWW80.jpg', 'WW88.jpg']
# Filenames with the same name:
# Lower Third Molar: W86.jpg, WW80.jpg, FlipWW80.jpg, WW88.jpg
# Upper Third Molar: W86.jpg, WW80.jpg, FlipWW80.jpg, WW88.jpg
# Upper Central Incisor: W86.jpg, WW80.jpg, FlipWW80.jpg, WW88.jpg
# Pair: Lower Third Molar, Upper Central Incisor and Nasal
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Third Molar, Upper Third Molar and Nasal
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Canine, Upper Central Incisor and Upper Third Molar
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Canine, Upper Central Incisor and Nasal
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Canine, Upper Third Molar and Nasal
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper Central Incisor, Upper Third Molar and Nasal
# Unique names and their occurrences in negative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:

# %%
# Optional: Create a DataFrame to keep all the information together
age_neg = []
for (name1, name2, name3), result in pair_results.items():
    for name, count in result['sorted_names']:
      if name in name1 and name2 in name2:
        age_neg.append({
            'name': name,
            'second': name2, #'pair': f"{name1} and {name2}"
            'third': name3,
            'count': count,
            'total_1': len(age_9_neg[age_9_neg['name']== name1]),
            'percentage_1':  f"{(count / len(age_9_neg[age_9_neg['name']== name1])) * 100 :.2f}%",
            'total_2': len(age_9_neg[age_9_neg['name']== name2]),
            'percentage_2':  f"{(count / len(age_9_neg[age_9_neg['name']== name2])) * 100 :.2f}%",
            'total_3': len(age_9_neg[age_9_neg['name']== name3]),
            'percentage_3':  f"{(count / len(age_9_neg[age_9_neg['name']== name3])) * 100 :.2f}%",
            'total_files': len(age_9_neg['filename'].unique()),
            'percentage_files':  f"{(count / len(age_9_neg['filename'].unique())) * 100 :.2f}%",
            'filenames': result['name_files'][name]
        })

neg_3 = pd.DataFrame(age_neg)
neg_3
# Out:
#                    name                 second                  third  count  \
# 0    Lower Second Molar  Upper Second Premolar  Lower Second Premolar      7
# 1    Lower Second Molar  Upper Second Premolar           Upper Canine     12
# 2    Lower Second Molar  Upper Second Premolar       Mandibular angle      2
# 3    Lower Second Molar  Upper Second Premolar   Upper First Premolar      7
# 4    Lower Second Molar  Upper Second Premolar  Upper Lateral Incisor      8
# ..                  ...                    ...                    ...    ...
# 468             Condyle      Lower Third Molar      Upper Third Molar      4
# 469   Upper First Molar      Lower Third Molar  Upper Central Incisor      2
# 470   Upper First Molar      Lower Third Molar      Upper Third Molar      4
# 471   Upper First Molar  Upper Central Incisor      Upper Third Molar      2
# 472   Lower Third Molar  Upper Central Incisor      Upper Third Molar      4
#
#      total_1 percentage_1  total_2 percentage_2  total_3 percentage_3  \
# 0         26       26.92%       20       35.00%       14       50.00%
# 1         26       46.15%       20       60.00%       20       60.00%
# 2         26        7.69%       20       10.00%        4       50.00%
# 3         26       26.92%       20       35.00%       15       46.67%
# 4         26       30.77%       20       40.00%       11       72.73%
# ..       ...          ...      ...          ...      ...          ...
# 468       15       26.67%       20       20.00%       14       28.57%
# 469       14       14.29%       20       10.00%        7       28.57%
# 470       14       28.57%       20       20.00%       14       28.57%
# 471       14       14.29%        7       28.57%       14       14.29%
# 472       20       20.00%        7       57.14%       14       28.57%
#
#      total_files percentage_files  \
# 0             32           21.88%
# 1             32           37.50%
# 2             32            6.25%
# 3             32           21.88%
# 4             32           25.00%
# ..           ...              ...
# 468           32           12.50%
# 469           32            6.25%
# 470           32           12.50%
# 471           32            6.25%
# 472           32           12.50%
#
#                                              filenames
# 0    [FlipW92.jpg, W88.jpg, W86.jpg, FlipW97.jpg, F...
# 1    [W84.jpg, FlipW95.jpg, W86.jpg, W97.jpg, FlipW...
# 2                              [W84.jpg, FlipWW78.jpg]
# 3    [W86.jpg, FlipWW78.jpg, WW79.jpg, WW81.jpg, Fl...
# 4    [FlipW92.jpg, FlipW90.jpg, FlipWW78.jpg, WW79....
# ..                                                 ...
# 468    [FlipW95.jpg, WW76.jpg, FlipWW78.jpg, WW85.jpg]
# 469                       [FlipWW80.jpg, FlipWW82.jpg]
# 470  [FlipW95.jpg, WW76.jpg, FlipWW78.jpg, FlipWW80...
# 471                           [FlipWW80.jpg, WW82.jpg]
# 472        [W86.jpg, WW80.jpg, FlipWW80.jpg, WW88.jpg]
#
# [473 rows x 13 columns]

# %%
percentage = neg_3['percentage_files'].tolist()
# Convert to a list of integers
neg_3['percentage_float'] = [float(p.replace('%', '')) for p in percentage]

# %%
neg_3
# Out:
#                    name                 second                  third  count  \
# 0    Lower Second Molar  Upper Second Premolar  Lower Second Premolar      7
# 1    Lower Second Molar  Upper Second Premolar           Upper Canine     12
# 2    Lower Second Molar  Upper Second Premolar       Mandibular angle      2
# 3    Lower Second Molar  Upper Second Premolar   Upper First Premolar      7
# 4    Lower Second Molar  Upper Second Premolar  Upper Lateral Incisor      8
# ..                  ...                    ...                    ...    ...
# 468             Condyle      Lower Third Molar      Upper Third Molar      4
# 469   Upper First Molar      Lower Third Molar  Upper Central Incisor      2
# 470   Upper First Molar      Lower Third Molar      Upper Third Molar      4
# 471   Upper First Molar  Upper Central Incisor      Upper Third Molar      2
# 472   Lower Third Molar  Upper Central Incisor      Upper Third Molar      4
#
#      total_1 percentage_1  total_2 percentage_2  total_3 percentage_3  \
# 0         26       26.92%       20       35.00%       14       50.00%
# 1         26       46.15%       20       60.00%       20       60.00%
# 2         26        7.69%       20       10.00%        4       50.00%
# 3         26       26.92%       20       35.00%       15       46.67%
# 4         26       30.77%       20       40.00%       11       72.73%
# ..       ...          ...      ...          ...      ...          ...
# 468       15       26.67%       20       20.00%       14       28.57%
# 469       14       14.29%       20       10.00%        7       28.57%
# 470       14       28.57%       20       20.00%       14       28.57%
# 471       14       14.29%        7       28.57%       14       14.29%
# 472       20       20.00%        7       57.14%       14       28.57%
#
#      total_files percentage_files  \
# 0             32           21.88%
# 1             32           37.50%
# 2             32            6.25%
# 3             32           21.88%
# 4             32           25.00%
# ..           ...              ...
# 468           32           12.50%
# 469           32            6.25%
# 470           32           12.50%
# 471           32            6.25%
# 472           32           12.50%
#
#                                              filenames  percentage_float
# 0    [FlipW92.jpg, W88.jpg, W86.jpg, FlipW97.jpg, F...             21.88
# 1    [W84.jpg, FlipW95.jpg, W86.jpg, W97.jpg, FlipW...             37.50
# 2                              [W84.jpg, FlipWW78.jpg]              6.25
# 3    [W86.jpg, FlipWW78.jpg, WW79.jpg, WW81.jpg, Fl...             21.88
# 4    [FlipW92.jpg, FlipW90.jpg, FlipWW78.jpg, WW79....             25.00
# ..                                                 ...               ...
# 468    [FlipW95.jpg, WW76.jpg, FlipWW78.jpg, WW85.jpg]             12.50
# 469                       [FlipWW80.jpg, FlipWW82.jpg]              6.25
# 470  [FlipW95.jpg, WW76.jpg, FlipWW78.jpg, FlipWW80...             12.50
# 471                           [FlipWW80.jpg, WW82.jpg]              6.25
# 472        [W86.jpg, WW80.jpg, FlipWW80.jpg, WW88.jpg]             12.50
#
# [473 rows x 14 columns]

# %%
neg_3_sort =  neg_3.sort_values(by='percentage_float', ascending=False)

# %%
neg_3_sort
# Out:
#                       name                     second  \
# 74      Lower Second Molar         Upper Second Molar
# 30      Lower Second Molar               Upper Canine
# 35      Lower Second Molar               Upper Canine
# 78      Lower Second Molar         Upper Second Molar
# 277           Upper Canine         Upper Second Molar
# ..                     ...                        ...
# 272           Upper Canine  Posterior border of Ramus
# 115  Upper Second Premolar               Upper Canine
# 110  Upper Second Premolar      Lower Second Premolar
# 366   Upper First Premolar       Lower First Premolar
# 325       Mandibular angle                    Condyle
#
#                          third  count  total_1 percentage_1  total_2  \
# 74           Lower First Molar     15       26       57.69%       27
# 30          Upper Second Molar     15       26       57.69%       20
# 35           Lower Third Molar     13       26       50.00%       20
# 78           Lower Third Molar     13       26       50.00%       27
# 277          Lower Third Molar     13       20       65.00%       27
# ..                         ...    ...      ...          ...      ...
# 272          Upper Third Molar      1       20        5.00%        7
# 115  Posterior border of Ramus      1       20        5.00%       20
# 110      Upper Central Incisor      1       20        5.00%       14
# 366          Upper Third Molar      1       15        6.67%        6
# 325          Upper Third Molar      1        4       25.00%       15
#
#     percentage_2  total_3 percentage_3  total_files percentage_files  \
# 74        55.56%       19       78.95%           32           46.88%
# 30        75.00%       27       55.56%           32           46.88%
# 35        65.00%       20       65.00%           32           40.62%
# 78        48.15%       20       65.00%           32           40.62%
# 277       48.15%       20       65.00%           32           40.62%
# ..           ...      ...          ...          ...              ...
# 272       14.29%       14        7.14%           32            3.12%
# 115        5.00%        7       14.29%           32            3.12%
# 110        7.14%        7       14.29%           32            3.12%
# 366       16.67%       14        7.14%           32            3.12%
# 325        6.67%       14        7.14%           32            3.12%
#
#                                              filenames  percentage_float
# 74   [FlipW87.jpg, FlipW91.jpg, FlipW92.jpg, W95.jp...             46.88
# 30   [W84.jpg, W95.jpg, FlipW95.jpg, W86.jpg, W97.j...             46.88
# 35   [W84.jpg, W95.jpg, FlipW95.jpg, W86.jpg, FlipW...             40.62
# 78   [W84.jpg, FlipW92.jpg, W95.jpg, FlipW95.jpg, W...             40.62
# 277  [W84.jpg, W95.jpg, FlipW95.jpg, W86.jpg, FlipW...             40.62
# ..                                                 ...               ...
# 272                                     [FlipWW88.jpg]              3.12
# 115                                     [FlipWW79.jpg]              3.12
# 110                                          [W86.jpg]              3.12
# 366                                         [WW75.jpg]              3.12
# 325                                     [FlipWW78.jpg]              3.12
#
# [473 rows x 14 columns]

# %%
table = neg_3_sort.reset_index()
table = table.iloc[:,1:]
table
# Out:
#                       name                     second  \
# 0       Lower Second Molar         Upper Second Molar
# 1       Lower Second Molar               Upper Canine
# 2       Lower Second Molar               Upper Canine
# 3       Lower Second Molar         Upper Second Molar
# 4             Upper Canine         Upper Second Molar
# ..                     ...                        ...
# 468           Upper Canine  Posterior border of Ramus
# 469  Upper Second Premolar               Upper Canine
# 470  Upper Second Premolar      Lower Second Premolar
# 471   Upper First Premolar       Lower First Premolar
# 472       Mandibular angle                    Condyle
#
#                          third  count  total_1 percentage_1  total_2  \
# 0            Lower First Molar     15       26       57.69%       27
# 1           Upper Second Molar     15       26       57.69%       20
# 2            Lower Third Molar     13       26       50.00%       20
# 3            Lower Third Molar     13       26       50.00%       27
# 4            Lower Third Molar     13       20       65.00%       27
# ..                         ...    ...      ...          ...      ...
# 468          Upper Third Molar      1       20        5.00%        7
# 469  Posterior border of Ramus      1       20        5.00%       20
# 470      Upper Central Incisor      1       20        5.00%       14
# 471          Upper Third Molar      1       15        6.67%        6
# 472          Upper Third Molar      1        4       25.00%       15
#
#     percentage_2  total_3 percentage_3  total_files percentage_files  \
# 0         55.56%       19       78.95%           32           46.88%
# 1         75.00%       27       55.56%           32           46.88%
# 2         65.00%       20       65.00%           32           40.62%
# 3         48.15%       20       65.00%           32           40.62%
# 4         48.15%       20       65.00%           32           40.62%
# ..           ...      ...          ...          ...              ...
# 468       14.29%       14        7.14%           32            3.12%
# 469        5.00%        7       14.29%           32            3.12%
# 470        7.14%        7       14.29%           32            3.12%
# 471       16.67%       14        7.14%           32            3.12%
# 472        6.67%       14        7.14%           32            3.12%
#
#                                              filenames  percentage_float
# 0    [FlipW87.jpg, FlipW91.jpg, FlipW92.jpg, W95.jp...             46.88
# 1    [W84.jpg, W95.jpg, FlipW95.jpg, W86.jpg, W97.j...             46.88
# 2    [W84.jpg, W95.jpg, FlipW95.jpg, W86.jpg, FlipW...             40.62
# 3    [W84.jpg, FlipW92.jpg, W95.jpg, FlipW95.jpg, W...             40.62
# 4    [W84.jpg, W95.jpg, FlipW95.jpg, W86.jpg, FlipW...             40.62
# ..                                                 ...               ...
# 468                                     [FlipWW88.jpg]              3.12
# 469                                     [FlipWW79.jpg]              3.12
# 470                                          [W86.jpg]              3.12
# 471                                         [WW75.jpg]              3.12
# 472                                     [FlipWW78.jpg]              3.12
#
# [473 rows x 14 columns]

# %%
table.to_csv('/content/gdrive/My Drive/Tooth_Shap_GPT/Deep_tooth/OPG_SHAPer/Result/Age/95_percentie/Neg_9/(3)ALL_.csv', index=False)

# %%
table[table['percentage_float']>=50.00]
# Out:
# Empty DataFrame
# Columns: [name, second, third, count, total_1, percentage_1, total_2, percentage_2, total_3, percentage_3, total_files, percentage_files, filenames, percentage_float]
# Index: []

# %%
# table = table[table['percentage_float']>=50.00]
# table

# %%
table = table.iloc[:10,] #top 10
table
# Out:
#                     name                 second               third  count  \
# 0     Lower Second Molar     Upper Second Molar   Lower First Molar     15
# 1     Lower Second Molar           Upper Canine  Upper Second Molar     15
# 2     Lower Second Molar           Upper Canine   Lower Third Molar     13
# 3     Lower Second Molar     Upper Second Molar   Lower Third Molar     13
# 4           Upper Canine     Upper Second Molar   Lower Third Molar     13
# 5     Lower Second Molar  Upper Second Premolar  Upper Second Molar     13
# 6     Lower Second Molar  Upper Second Premolar        Upper Canine     12
# 7  Upper Second Premolar           Upper Canine  Upper Second Molar     12
# 8     Lower Second Molar  Upper Second Premolar   Lower First Molar     12
# 9  Upper Second Premolar     Upper Second Molar   Lower First Molar     11
#
#    total_1 percentage_1  total_2 percentage_2  total_3 percentage_3  \
# 0       26       57.69%       27       55.56%       19       78.95%
# 1       26       57.69%       20       75.00%       27       55.56%
# 2       26       50.00%       20       65.00%       20       65.00%
# 3       26       50.00%       27       48.15%       20       65.00%
# 4       20       65.00%       27       48.15%       20       65.00%
# 5       26       50.00%       20       65.00%       27       48.15%
# 6       26       46.15%       20       60.00%       20       60.00%
# 7       20       60.00%       20       60.00%       27       44.44%
# 8       26       46.15%       20       60.00%       19       63.16%
# 9       20       55.00%       27       40.74%       19       57.89%
#
#    total_files percentage_files  \
# 0           32           46.88%
# 1           32           46.88%
# 2           32           40.62%
# 3           32           40.62%
# 4           32           40.62%
# 5           32           40.62%
# 6           32           37.50%
# 7           32           37.50%
# 8           32           37.50%
# 9           32           34.38%
#
#                                            filenames  percentage_float
# 0  [FlipW87.jpg, FlipW91.jpg, FlipW92.jpg, W95.jp...             46.88
# 1  [W84.jpg, W95.jpg, FlipW95.jpg, W86.jpg, W97.j...             46.88
# 2  [W84.jpg, W95.jpg, FlipW95.jpg, W86.jpg, FlipW...             40.62
# 3  [W84.jpg, FlipW92.jpg, W95.jpg, FlipW95.jpg, W...             40.62
# 4  [W84.jpg, W95.jpg, FlipW95.jpg, W86.jpg, FlipW...             40.62
# 5  [W84.jpg, FlipW92.jpg, FlipW95.jpg, W88.jpg, W...             40.62
# 6  [W84.jpg, FlipW95.jpg, W86.jpg, W97.jpg, FlipW...             37.50
# 7  [W84.jpg, FlipW95.jpg, W86.jpg, W97.jpg, FlipW...             37.50
# 8  [FlipW92.jpg, W88.jpg, W97.jpg, FlipW97.jpg, F...             37.50
# 9  [FlipW92.jpg, W88.jpg, W97.jpg, FlipW97.jpg
\
# 0     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 1     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 2     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 3     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 4     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# ...                                                 ...
# 1867  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 1868  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 1869  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 1870  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 1871  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
#
#                                            path_pos_img
# 0     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 1     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 2     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 3     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 4     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# ...                                                 ...
# 1867  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 1868  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 1869  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 1870  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 1871  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
#
# [1872 rows x 11 columns]

# %%
age_9_pos = positive_age[positive_age['Age(year)'].isin(['9Y'])]
age_9_pos
# Out:
#            ymin        xmax        ymax  confidence  class  \
# 320  313.472261  324.973350  386.081792    0.920765   13.0
# 321  210.907343  357.728915  275.321159    0.917743    8.0
# 322  201.387962  469.904908  304.437682    0.917683   19.0
# 323  226.646582  419.960785  299.903411    0.908246   18.0
# 324  245.443670  487.908048  348.676604    0.898586    1.0
# ..          ...         ...         ...         ...    ...
# 515  225.891081  170.470292  291.354437    0.801950   16.0
# 516  309.142106  273.710152  347.838774    0.695592   11.0
# 517  191.617750  483.048079  283.075282    0.914809   19.0
# 518  225.881062  521.134876  331.727289    0.911990   17.0
# 519  119.620420  221.159682  182.852495    0.850940    0.0
#
#                           name      filename Age(year) Gender  \
# 320         Lower Second Molar       W84.jpg        9Y      F
# 321         Upper Second Molar       W84.jpg        9Y      F
# 322               Upper Canine       W84.jpg        9Y      F
# 323      Upper Second Premolar       W84.jpg        9Y      F
# 324      Upper Lateral Incisor       W84.jpg        9Y      F
# ..                         ...           ...       ...    ...
# 515  Posterior border of Ramus  FlipWW84.jpg        9Y      M
# 516          Lower Third Molar  FlipWW84.jpg        9Y      M
# 517               Upper Canine  FlipWW90.jpg        9Y      M
# 518      Upper Central Incisor  FlipWW90.jpg        9Y      M
# 519                    Condyle  FlipWW90.jpg        9Y      M
#
#                                          path_name_ori  \
# 320  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 321  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 322  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 323  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 324  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# ..                                                 ...
# 515  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 516  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 517  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 518  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 519  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
#
#                                           path_pos_img
# 320  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 321  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 322  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 323  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 324  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# ..                                                 ...
# 515  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 516  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 517  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 518  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
# 519  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...
#
# [200 rows x 11 columns]

# %%
print(len(age_9_pos['filename'].unique()))
# Out:
# 32

# %% [markdown]
# ### all

# %%
age_9_pos['name'].value_counts()
# Out:
# name
# Lower Second Molar           24
# Upper Second Molar           23
# Lower Third Molar            20
# Upper Canine                 15
# Condyle                      15
# Lower First Molar            14
# Upper First Molar            13
# Upper Third Molar            12
# Upper Second Premolar        11
# Lower Second Premolar        11
# Upper First Premolar         10
# Upper Lateral Incisor         7
# Posterior border of Ramus     7
# Upper Central Incisor         7
# Mandibular angle              6
# Lower First Premolar          3
# Nasal                         1
# Lower Canine                  1
# Name: count, dtype: int64

# %%
name_count_pos = {}
name_files = {}
list_pos = age_9_pos['name'].tolist()
filenames = age_9_pos['filename'].tolist()
# Iterate over each list of dictionaries
for name, filename in zip(list_pos, filenames):
    if name in name_count_pos:
       name_count_pos[name] += 1
       name_files[name].append(filename)
    else:
       name_count_pos[name] = 1
       name_files[name] = [filename]

# Sort the name_count_pos dictionary by count of occurrences (descending order)
sorted_names = sorted(name_count_pos.items(), key=lambda x: x[1], reverse=True)

# Print a summary of all unique names and their occurrence counts
print("Unique names and their occurrences in posative SHAP values area:")
# Print the total number of unique names in the dataset
total_unique_names = len(sorted_names)
print(f"Total Unique Names: {total_unique_names}")

for i, (name, count) in enumerate(sorted_names, start=1):
    print(f"{i}. {name}: {count}/{len(age_9_pos['filename'].unique())} ({(count / len(age_9_pos['filename'].unique())):.2%})")#of total
# Out:
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 18
# 1. Lower Second Molar: 24/32 (75.00%)
# 2. Upper Second Molar: 23/32 (71.88%)
# 3. Lower Third Molar: 20/32 (62.50%)
# 4. Upper Canine: 15/32 (46.88%)
# 5. Condyle: 15/32 (46.88%)
# 6. Lower First Molar: 14/32 (43.75%)
# 7. Upper First Molar: 13/32 (40.62%)
# 8. Upper Third Molar: 12/32 (37.50%)
# 9. Upper Second Premolar: 11/32 (34.38%)
# 10. Lower Second Premolar: 11/32 (34.38%)
# 11. Upper First Premolar: 10/32 (31.25%)
# 12. Upper Lateral Incisor: 7/32 (21.88%)
# 13. Posterior border of Ramus: 7/32 (21.88%)
# 14. Upper Central Incisor: 7/32 (21.88%)
# 15. Mandibular angle: 6/32 (18.75%)
# 16. Lower First Premolar: 3/32 (9.38%)
# 17. Nasal: 1/32 (3.12%)
# 18. Lower Canine: 1/32 (3.12%)

# %%
# Optional: Create a DataFrame to keep all the information together
summary_pos_9 = []
for name, count in sorted_names:
    summary_pos_9.append({
        'name': name,
        'count': count,
        'total_files': len(age_9_pos['filename'].unique()),
        'percentage_files': f"{(count / len(age_9_pos['filename'].unique())) * 100 :.2f}%",
        'filenames': name_files[name]
    })

summary_pos_9_df = pd.DataFrame(summary_pos_9)
summary_pos_9_df
# Out:
#                          name  count  total_files percentage_files  \
# 0          Lower Second Molar     24           32           75.00%
# 1          Upper Second Molar     23           32           71.88%
# 2           Lower Third Molar     20           32           62.50%
# 3                Upper Canine     15           32           46.88%
# 4                     Condyle     15           32           46.88%
# 5           Lower First Molar     14           32           43.75%
# 6           Upper First Molar     13           32           40.62%
# 7           Upper Third Molar     12           32           37.50%
# 8       Upper Second Premolar     11           32           34.38%
# 9       Lower Second Premolar     11           32           34.38%
# 10       Upper First Premolar     10           32           31.25%
# 11      Upper Lateral Incisor      7           32           21.88%
# 12  Posterior border of Ramus      7           32           21.88%
# 13      Upper Central Incisor      7           32           21.88%
# 14           Mandibular angle      6           32           18.75%
# 15       Lower First Premolar      3           32            9.38%
# 16                      Nasal      1           32            3.12%
# 17               Lower Canine      1           32            3.12%
#
#                                             filenames
# 0   [W84.jpg, FlipW87.jpg, W91.jpg, FlipW91.jpg, F...
# 1   [W84.jpg, FlipW91.jpg, W92.jpg, FlipW92.jpg, W...
# 2   [W84.jpg, W92.jpg, FlipW92.jpg, W95.jpg, FlipW...
# 3   [W84.jpg, W95.jpg, FlipW95.jpg, FlipW97.jpg, F...
# 4   [W84.jpg, FlipW87.jpg, W91.jpg, FlipW91.jpg, F...
# 5   [FlipW87.jpg, W91.jpg, FlipW91.jpg, FlipW92.jp...
# 6   [FlipW91.jpg, FlipW95.jpg, W88.jpg, FlipW97.jp...
# 7   [FlipW95.jpg, W86.jpg, FlipW86.jpg, WW75.jpg, ...
# 8   [W84.jpg, FlipW95.jpg, FlipW97.jpg, FlipW90.jp...
# 9   [FlipW92.jpg, W95.jpg, W88.jpg, FlipW97.jpg, F...
# 10  [W95.jpg, W86.jpg, WW75.jpg, FlipWW75.jpg, Fli...
# 11  [W84.jpg, FlipW92.jpg, W95.jpg, FlipWW78.jpg, ...
# 12  [FlipW92.jpg, W95.jpg, FlipWW79.jpg, FlipWW81....
# 13  [WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg, F...
# 14  [W84.jpg, FlipWW78.jpg, WW79.jpg, FlipWW79.jpg...
# 15                  [W95.jpg, WW76.jpg, FlipWW84.jpg]
# 16                                      [FlipW97.jpg]
# 17                                     [FlipWW84.jpg]

# %%
# import os
# os.makedirs("/content/gdrive/My Drive/Tooth_Shap_GPT/Deep_tooth/OPG_SHAPer/Result/Age/95_percentie/Pos_9")

# %%
summary_pos_9_df.to_csv('/content/gdrive/My Drive/Tooth_Shap_GPT/Deep_tooth/OPG_SHAPer/Result/Age/95_percentie/Pos_9/Positive_9_years.csv', index=False)

# %%
age_9_pos['name'].unique()
# Out:
# array(['Lower Second Molar', 'Upper Second Molar', 'Upper Canine',
#        'Upper Second Premolar', 'Upper Lateral Incisor', 'Condyle',
#        'Mandibular angle', 'Lower Third Molar', 'Lower First Molar',
#        'Upper First Molar', 'Lower Second Premolar',
#        'Posterior border of Ramus', 'Lower First Premolar',
#        'Upper First Premolar', 'Upper Third Molar', 'Nasal',
#        'Upper Central Incisor', 'Lower Canine'], dtype=object)

# %%
percentage = summary_pos_9_df['percentage_files'].tolist()
# Convert to a list of integers
summary_pos_9_df['percentage_float'] = [float(p.replace('%', '')) for p in percentage]

# %%
table = summary_pos_9_df[summary_pos_9_df['percentage_float']>=50.00]
table
# Out:
#                  name  count  total_files percentage_files  \
# 0  Lower Second Molar     24           32           75.00%
# 1  Upper Second Molar     23           32           71.88%
# 2   Lower Third Molar     20           32           62.50%
#
#                                            filenames  percentage_float
# 0  [W84.jpg, FlipW87.jpg, W91.jpg, FlipW91.jpg, F...             75.00
# 1  [W84.jpg, FlipW91.jpg, W92.jpg, FlipW92.jpg, W...             71.88
# 2  [W84.jpg, W92.jpg, FlipW92.jpg, W95.jpg, FlipW...             62.50

# %%
table = table.iloc[:,:-1]

# %%
table.to_csv('/content/gdrive/My Drive/Tooth_Shap_GPT/Deep_tooth/OPG_SHAPer/Result/Age/95_percentie/Pos_9/Positive_9_years(>=50%).csv', index=False)

# %% [markdown]
# ### 2 with combinations (19/93 rows)

# %%
from itertools import combinations

# List of names
names = [
    'Lower Second Molar', 'Upper Second Premolar', 'Lower Second Premolar',
    'Upper Canine', 'Mandibular angle', 'Upper First Premolar',
    'Upper Lateral Incisor', 'Posterior border of Ramus', 'Upper Second Molar',
    'Lower First Molar', 'Lower First Premolar', 'Condyle', 'Upper First Molar',
    'Lower Third Molar', 'Lower Canine', 'Upper Central Incisor',
    'Upper Third Molar', 'Nasal'
]

# Get all combinations of names with length 2
pairs_of_names = list(combinations(names, 2))
print(pairs_of_names)
# Out:
# [('Lower Second Molar', 'Upper Second Premolar'), ('Lower Second Molar', 'Lower Second Premolar'), ('Lower Second Molar', 'Upper Canine'), ('Lower Second Molar', 'Mandibular angle'), ('Lower Second Molar', 'Upper First Premolar'), ('Lower Second Molar', 'Upper Lateral Incisor'), ('Lower Second Molar', 'Posterior border of Ramus'), ('Lower Second Molar', 'Upper Second Molar'), ('Lower Second Molar', 'Lower First Molar'), ('Lower Second Molar', 'Lower First Premolar'), ('Lower Second Molar', 'Condyle'), ('Lower Second Molar', 'Upper First Molar'), ('Lower Second Molar', 'Lower Third Molar'), ('Lower Second Molar', 'Lower Canine'), ('Lower Second Molar', 'Upper Central Incisor'), ('Lower Second Molar', 'Upper Third Molar'), ('Lower Second Molar', 'Nasal'), ('Upper Second Premolar', 'Lower Second Premolar'), ('Upper Second Premolar', 'Upper Canine'), ('Upper Second Premolar', 'Mandibular angle'), ('Upper Second Premolar', 'Upper First Premolar'), ('Upper Second Premolar', 'Upper Lateral Incisor'), ('Upper Second Premolar', 'Posterior border of Ramus'), ('Upper Second Premolar', 'Upper Second Molar'), ('Upper Second Premolar', 'Lower First Molar'), ('Upper Second Premolar', 'Lower First Premolar'), ('Upper Second Premolar', 'Condyle'), ('Upper Second Premolar', 'Upper First Molar'), ('Upper Second Premolar', 'Lower Third Molar'), ('Upper Second Premolar', 'Lower Canine'), ('Upper Second Premolar', 'Upper Central Incisor'), ('Upper Second Premolar', 'Upper Third Molar'), ('Upper Second Premolar', 'Nasal'), ('Lower Second Premolar', 'Upper Canine'), ('Lower Second Premolar', 'Mandibular angle'), ('Lower Second Premolar', 'Upper First Premolar'), ('Lower Second Premolar', 'Upper Lateral Incisor'), ('Lower Second Premolar', 'Posterior border of Ramus'), ('Lower Second Premolar', 'Upper Second Molar'), ('Lower Second Premolar', 'Lower First Molar'), ('Lower Second Premolar', 'Lower First Premolar'), ('Lower Second Premolar', 'Condyle'), ('Lower Second Premolar', 'Upper First Molar'), ('Lower Second Premolar', 'Lower Third Molar'), ('Lower Second Premolar', 'Lower Canine'), ('Lower Second Premolar', 'Upper Central Incisor'), ('Lower Second Premolar', 'Upper Third Molar'), ('Lower Second Premolar', 'Nasal'), ('Upper Canine', 'Mandibular angle'), ('Upper Canine', 'Upper First Premolar'), ('Upper Canine', 'Upper Lateral Incisor'), ('Upper Canine', 'Posterior border of Ramus'), ('Upper Canine', 'Upper Second Molar'), ('Upper Canine', 'Lower First Molar'), ('Upper Canine', 'Lower First Premolar'), ('Upper Canine', 'Condyle'), ('Upper Canine', 'Upper First Molar'), ('Upper Canine', 'Lower Third Molar'), ('Upper Canine', 'Lower Canine'), ('Upper Canine', 'Upper Central Incisor'), ('Upper Canine', 'Upper Third Molar'), ('Upper Canine', 'Nasal'), ('Mandibular angle', 'Upper First Premolar'), ('Mandibular angle', 'Upper Lateral Incisor'), ('Mandibular angle', 'Posterior border of Ramus'), ('Mandibular angle', 'Upper Second Molar'), ('Mandibular angle', 'Lower First Molar'), ('Mandibular angle', 'Lower First Premolar'), ('Mandibular angle', 'Condyle'), ('Mandibular angle', 'Upper First Molar'), ('Mandibular angle', 'Lower Third Molar'), ('Mandibular angle', 'Lower Canine'), ('Mandibular angle', 'Upper Central Incisor'), ('Mandibular angle', 'Upper Third Molar'), ('Mandibular angle', 'Nasal'), ('Upper First Premolar', 'Upper Lateral Incisor'), ('Upper First Premolar', 'Posterior border of Ramus'), ('Upper First Premolar', 'Upper Second Molar'), ('Upper First Premolar', 'Lower First Molar'), ('Upper First Premolar', 'Lower First Premolar'), ('Upper First Premolar', 'Condyle'), ('Upper First Premolar', 'Upper First Molar'), ('Upper First Premolar', 'Lower Third Molar'), ('Upper First Premolar', 'Lower Canine'), ('Upper First Premolar', 'Upper Central Incisor'), ('Upper First Premolar', 'Upper Third Molar'), ('Upper First Premolar', 'Nasal'), ('Upper Lateral Incisor', 'Posterior border of Ramus'), ('Upper Lateral Incisor', 'Upper Second Molar'), ('Uppe ...

# %%
len(pairs_of_names)
# Out:
# 153

# %%
import pandas as pd

# Dictionary to store results for each pair
pair_results = {}

for name1, name2 in pairs_of_names:
    # Identify filenames that contain name1
    A = set(age_9_pos[age_9_pos['name'] == name1]['filename'])

    # Identify filenames that contain name2
    B = set(age_9_pos[age_9_pos['name'] == name2]['filename'])

    # Find the intersection of the two sets to get filenames that contain both name1 and name2
    common_filenames = A.intersection(B)

    # Filter the DataFrame to include only the common filenames
    filtered_filenames = age_9_pos[age_9_pos['filename'].isin(common_filenames)]

    # Filter the DataFrame to include only the name1 or name2
    filtered_region = filtered_filenames[filtered_filenames['name'].isin([name1, name2])]

    # Dictionary to store name counts and associated filenames
    name_count_pos = {}
    name_files = {}

    # List of names
    list_pos = filtered_region['name'].tolist()
    # List of filenames
    filenames = filtered_region['filename'].tolist()

    # Iterate over each name and corresponding filename
    for name, filename in zip(list_pos, filenames):
        if name in name_count_pos:
            name_count_pos[name] += 1
            name_files[name].append(filename)
        else:
            name_count_pos[name] = 1
            name_files[name] = [filename]

    # Sort the name_count_pos dictionary by count of occurrences (descending order)
    sorted_names = sorted(name_count_pos.items(), key=lambda x: x[1], reverse=True)

    # Store the results in the dictionary
    pair_results[(name1, name2)] = {
        'sorted_names': sorted_names,
        'name_files': name_files
    }

    # Print a summary for this pair
    print(f"Pair: {name1} and {name2}")
    print("Unique names and their occurrences in posative SHAP values area:")
    total_unique_names = len(sorted_names)
    print(f"Total Unique Names: {total_unique_names}")

    for i, (name, count) in enumerate(sorted_names, start=1):
        unique_filenames = len(set(name_files[name]))  # Calculate unique filenames
        print(f"{i}. {name}: {count}/{len(filtered_region['filename'].unique())} ({(count / len(filtered_region['filename'].unique())):.2%}) of total")
        print(f"    Filenames: {name_files[name]}")

    print("Filenames with the same name:")
    for name, filenames in name_files.items():
        if len(set(filenames)) >= 1:  # Only consider names that appear in more than one filename
            print(f"{name}: {', '.join(filenames)}")
# Out:
# Pair: Lower Second Molar and Upper Second Premolar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower Second Molar: 9/9 (100.00%) of total
#     Filenames: ['W84.jpg', 'FlipW97.jpg', 'FlipW90.jpg', 'WW76.jpg', 'WW79.jpg', 'WW81.jpg', 'WW82.jpg', 'FlipWW82.jpg', 'FlipWW84.jpg']
# 2. Upper Second Premolar: 9/9 (100.00%) of total
#     Filenames: ['W84.jpg', 'FlipW97.jpg', 'FlipW90.jpg', 'WW76.jpg', 'WW79.jpg', 'WW81.jpg', 'WW82.jpg', 'FlipWW82.jpg', 'FlipWW84.jpg']
# Filenames with the same name:
# Lower Second Molar: W84.jpg, FlipW97.jpg, FlipW90.jpg, WW76.jpg, WW79.jpg, WW81.jpg, WW82.jpg, FlipWW82.jpg, FlipWW84.jpg
# Upper Second Premolar: W84.jpg, FlipW97.jpg, FlipW90.jpg, WW76.jpg, WW79.jpg, WW81.jpg, WW82.jpg, FlipWW82.jpg, FlipWW84.jpg
# Pair: Lower Second Molar and Lower Second Premolar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower Second Molar: 9/9 (100.00%) of total
#     Filenames: ['FlipW92.jpg', 'W95.jpg', 'W88.jpg', 'FlipW97.jpg', 'FlipW90.jpg', 'WW75.jpg', 'WW76.jpg', 'WW81.jpg', 'WW88.jpg']
# 2. Lower Second Premolar: 9/9 (100.00%) of total
#     Filenames: ['FlipW92.jpg', 'W95.jpg', 'W88.jpg', 'FlipW97.jpg', 'FlipW90.jpg', 'WW75.jpg', 'WW76.jpg', 'WW81.jpg', 'WW88.jpg']
# Filenames with the same name:
# Lower Second Molar: FlipW92.jpg, W95.jpg, W88.jpg, FlipW97.jpg, FlipW90.jpg, WW75.jpg, WW76.jpg, WW81.jpg, WW88.jpg
# Lower Second Premolar: FlipW92.jpg, W95.jpg, W88.jpg, FlipW97.jpg, FlipW90.jpg, WW75.jpg, WW76.jpg, WW81.jpg, WW88.jpg
# Pair: Lower Second Molar and Upper Canine
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower Second Molar: 11/11 (100.00%) of total
#     Filenames: ['W84.jpg', 'W95.jpg', 'FlipW97.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'WW81.jpg', 'FlipWW81.jpg', 'WW80.jpg', 'WW82.jpg', 'FlipWW82.jpg', 'FlipWW84.jpg']
# 2. Upper Canine: 11/11 (100.00%) of total
#     Filenames: ['W84.jpg', 'W95.jpg', 'FlipW97.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'WW81.jpg', 'FlipWW81.jpg', 'WW80.jpg', 'WW82.jpg', 'FlipWW82.jpg', 'FlipWW84.jpg']
# Filenames with the same name:
# Lower Second Molar: W84.jpg, W95.jpg, FlipW97.jpg, FlipWW78.jpg, WW79.jpg, WW81.jpg, FlipWW81.jpg, WW80.jpg, WW82.jpg, FlipWW82.jpg, FlipWW84.jpg
# Upper Canine: W84.jpg, W95.jpg, FlipW97.jpg, FlipWW78.jpg, WW79.jpg, WW81.jpg, FlipWW81.jpg, WW80.jpg, WW82.jpg, FlipWW82.jpg, FlipWW84.jpg
# Pair: Lower Second Molar and Mandibular angle
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower Second Molar: 5/5 (100.00%) of total
#     Filenames: ['W84.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'WW80.jpg', 'WW88.jpg']
# 2. Mandibular angle: 5/5 (100.00%) of total
#     Filenames: ['W84.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'WW80.jpg', 'WW88.jpg']
# Filenames with the same name:
# Lower Second Molar: W84.jpg, FlipWW78.jpg, WW79.jpg, WW80.jpg, WW88.jpg
# Mandibular angle: W84.jpg, FlipWW78.jpg, WW79.jpg, WW80.jpg, WW88.jpg
# Pair: Lower Second Molar and Upper First Premolar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower Second Molar: 6/6 (100.00%) of total
#     Filenames: ['W95.jpg', 'W86.jpg', 'WW75.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'WW81.jpg']
# 2. Upper First Premolar: 6/6 (100.00%) of total
#     Filenames: ['W95.jpg', 'W86.jpg', 'WW75.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'WW81.jpg']
# Filenames with the same name:
# Lower Second Molar: W95.jpg, W86.jpg, WW75.jpg, FlipWW78.jpg, WW79.jpg, WW81.jpg
# Upper First Premolar: W95.jpg, W86.jpg, WW75.jpg, FlipWW78.jpg, WW79.jpg, WW81.jpg
# Pair: Lower Second Molar and Upper Lateral Incisor
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower Second Molar: 6/6 (100.00%) of total
#     Filenames: ['W84.jpg', 'FlipW92.jpg', 'W95.jpg', 'FlipWW78.jpg', 'WW82.jpg', 'FlipWW84.jpg']
# 2. Upper Lateral Incisor: 6/6 (100.00%) of total
#     Filenames: ['W84.jpg', 'FlipW92.jpg', 'W95.jpg', 'FlipWW78.jpg', 'WW82.jpg', 'FlipWW84.jpg']
# Filenames with the same name:
# Lower Second Molar: W84.jpg, FlipW92.jpg, W95.jpg, FlipWW78.jpg, WW82.jpg, FlipWW84.jpg
# Upper Lateral Incisor: W84.jpg, FlipW92.jpg, W95.jpg, FlipWW78.jpg, WW82.jpg, FlipWW84.jpg
# Pair: Lower Second Molar and Posterior border of Ramus
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower Second Molar: 5/5 (100.00%) of total
#     Filenames: ['FlipW92.jpg', 'W95.jpg', 'FlipWW81.jpg', 'FlipWW88.jpg', 'FlipWW84.jpg']
# 2. Posterior border of Ramus: 5/5 (100.00%) of total
#     Filenames: ['FlipW92.jpg', 'W95.jpg', 'FlipWW81.jpg', 'FlipWW88.jpg', 'FlipWW84.jpg']
# Filenames with the same name:
# Lower Second Molar: FlipW92.jpg, W95.jpg, FlipWW81.jpg, FlipWW88.jpg, FlipWW84.jpg
# Posterior border of Ramus: FlipW92.jpg, W95.jpg, FlipWW81.jpg, FlipWW88.jpg, FlipWW84.jpg
# Pair: Lower Second Molar and Upper Second Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower Second Molar: 18/18 (100.00%) of total
#     Filenames: ['W84.jpg', 'FlipW91.jpg', 'FlipW92.jpg', 'W95.jpg', 'W88.jpg', 'W86.jpg', 'W97.jpg', 'FlipW97.jpg', 'WW75.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'WW81.jpg', 'FlipWW81.jpg', 'WW80.jpg', 'WW82.jpg', 'FlipWW82.jpg', 'WW88.jpg', 'FlipWW88.jpg']
# 2. Upper Second Molar: 18/18 (100.00%) of total
#     Filenames: ['W84.jpg', 'FlipW91.jpg', 'FlipW92.jpg', 'W95.jpg', 'W88.jpg', 'W86.jpg', 'W97.jpg', 'FlipW97.jpg', 'WW75.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'WW81.jpg', 'FlipWW81.jpg', 'WW80.jpg', 'WW82.jpg', 'FlipWW82.jpg', 'WW88.jpg', 'FlipWW88.jpg']
# Filenames with the same name:
# Lower Second Molar: W84.jpg, FlipW91.jpg, FlipW92.jpg, W95.jpg, W88.jpg, W86.jpg, W97.jpg, FlipW97.jpg, WW75.jpg, FlipWW78.jpg, WW79.jpg, WW81.jpg, FlipWW81.jpg, WW80.jpg, WW82.jpg, FlipWW82.jpg, WW88.jpg, FlipWW88.jpg
# Upper Second Molar: W84.jpg, FlipW91.jpg, FlipW92.jpg, W95.jpg, W88.jpg, W86.jpg, W97.jpg, FlipW97.jpg, WW75.jpg, FlipWW78.jpg, WW79.jpg, WW81.jpg, FlipWW81.jpg, WW80.jpg, WW82.jpg, FlipWW82.jpg, WW88.jpg, FlipWW88.jpg
# Pair: Lower Second Molar and Lower First Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower Second Molar: 13/13 (100.00%) of total
#     Filenames: ['FlipW87.jpg', 'W91.jpg', 'FlipW91.jpg', 'FlipW92.jpg', 'W95.jpg', 'W88.jpg', 'W97.jpg', 'FlipW97.jpg', 'FlipW90.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'WW88.jpg']
# 2. Lower First Molar: 13/13 (100.00%) of total
#     Filenames: ['FlipW87.jpg', 'W91.jpg', 'FlipW91.jpg', 'FlipW92.jpg', 'W95.jpg', 'W88.jpg', 'W97.jpg', 'FlipW97.jpg', 'FlipW90.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'WW88.jpg']
# Filenames with the same name:
# Lower Second Molar: FlipW87.jpg, W91.jpg, FlipW91.jpg, FlipW92.jpg, W95.jpg, W88.jpg, W97.jpg, FlipW97.jpg, FlipW90.jpg, WW76.jpg, FlipWW78.jpg, WW79.jpg, WW88.jpg
# Lower First Molar: FlipW87.jpg, W91.jpg, FlipW91.jpg, FlipW92.jpg, W95.jpg, W88.jpg, W97.jpg, FlipW97.jpg, FlipW90.jpg, WW76.jpg, FlipWW78.jpg, WW79.jpg, WW88.jpg
# Pair: Lower Second Molar and Lower First Premolar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower Second Molar: 3/3 (100.00%) of total
#     Filenames: ['W95.jpg', 'WW76.jpg', 'FlipWW84.jpg']
# 2. Lower First Premolar: 3/3 (100.00%) of total
#     Filenames: ['W95.jpg', 'WW76.jpg', 'FlipWW84.jpg']
# Filenames with the same name:
# Lower Second Molar: W95.jpg, WW76.jpg, FlipWW84.jpg
# Lower First Premolar: W95.jpg, WW76.jpg, FlipWW84.jpg
# Pair: Lower Second Molar and Condyle
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower Second Molar: 11/11 (100.00%) of total
#     Filenames: ['W84.jpg', 'FlipW87.jpg', 'W91.jpg', 'FlipW91.jpg', 'W88.jpg', 'W97.jpg', 'FlipW97.jpg', 'FlipW90.jpg', 'WW76.jpg', 'WW79.jpg', 'FlipWW84.jpg']
# 2. Condyle: 11/11 (100.00%) of total
#     Filenames: ['W84.jpg', 'FlipW87.jpg', 'W91.jpg', 'FlipW91.jpg', 'W88.jpg', 'W97.jpg', 'FlipW97.jpg', 'FlipW90.jpg', 'WW76.jpg', 'WW79.jpg', 'FlipWW84.jpg']
# Filenames with the same name:
# Lower Second Molar: W84.jpg, FlipW87.jpg, W91.jpg, FlipW91.jpg, W88.jpg, W97.jpg, FlipW97.jpg, FlipW90.jpg, WW76.jpg, WW79.jpg, FlipWW84.jpg
# Condyle: W84.jpg, FlipW87.jpg, W91.jpg, FlipW91.jpg, W88.jpg, W97.jpg, FlipW97.jpg, FlipW90.jpg, WW76.jpg, WW79.jpg, FlipWW84.jpg
# Pair: Lower Second Molar and Upper First Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower Second Molar: 10/10 (100.00%) of total
#     Filenames: ['FlipW91.jpg', 'W88.jpg', 'FlipW97.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'WW80.jpg', 'WW82.jpg', 'FlipWW82.jpg', 'WW88.jpg']
# 2. Upper First Molar: 10/10 (100.00%) of total
#     Filenames: ['FlipW91.jpg', 'W88.jpg', 'FlipW97.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'WW80.jpg', 'WW82.jpg', 'FlipWW82.jpg', 'WW88.jpg']
# Filenames with the same name:
# Lower Second Molar: FlipW91.jpg, W88.jpg, FlipW97.jpg, WW76.jpg, FlipWW78.jpg, WW79.jpg, WW80.jpg, WW82.jpg, FlipWW82.jpg, WW88.jpg
# Upper First Molar: FlipW91.jpg, W88.jpg, FlipW97.jpg, WW76.jpg, FlipWW78.jpg, WW79.jpg, WW80.jpg, WW82.jpg, FlipWW82.jpg, WW88.jpg
# Pair: Lower Second Molar and Lower Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower Second Molar: 15/15 (100.00%) of total
#     Filenames: ['W84.jpg', 'FlipW92.jpg', 'W95.jpg', 'W86.jpg', 'FlipW86.jpg', 'FlipW90.jpg', 'FlipWW78.jpg', 'WW81.jpg', 'FlipWW81.jpg', 'WW80.jpg', 'WW82.jpg', 'FlipWW82.jpg', 'WW88.jpg', 'FlipWW88.jpg', 'FlipWW84.jpg']
# 2. Lower Third Molar: 15/15 (100.00%) of total
#     Filenames: ['W84.jpg', 'FlipW92.jpg', 'W95.jpg', 'W86.jpg', 'FlipW86.jpg', 'FlipW90.jpg', 'FlipWW78.jpg', 'WW81.jpg', 'FlipWW81.jpg', 'WW80.jpg', 'WW82.jpg', 'FlipWW82.jpg', 'WW88.jpg', 'FlipWW88.jpg', 'FlipWW84.jpg']
# Filenames with the same name:
# Lower Second Molar: W84.jpg, FlipW92.jpg, W95.jpg, W86.jpg, FlipW86.jpg, FlipW90.jpg, FlipWW78.jpg, WW81.jpg, FlipWW81.jpg, WW80.jpg, WW82.jpg, FlipWW82.jpg, WW88.jpg, FlipWW88.jpg, FlipWW84.jpg
# Lower Third Molar: W84.jpg, FlipW92.jpg, W95.jpg, W86.jpg, FlipW86.jpg, FlipW90.jpg, FlipWW78.jpg, WW81.jpg, FlipWW81.jpg, WW80.jpg, WW82.jpg, FlipWW82.jpg, WW88.jpg, FlipWW88.jpg, FlipWW84.jpg
# Pair: Lower Second Molar and Lower Canine
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower Second Molar: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# 2. Lower Canine: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# Filenames with the same name:
# Lower Second Molar: FlipWW84.jpg
# Lower Canine: FlipWW84.jpg
# Pair: Lower Second Molar and Upper Central Incisor
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Upper Central Incisor: 4/4 (100.00%) of total
#     Filenames: ['WW80.jpg', 'WW82.jpg', 'WW88.jpg', 'FlipWW84.jpg']
# 2. Lower Second Molar: 4/4 (100.00%) of total
#     Filenames: ['WW80.jpg', 'WW82.jpg', 'WW88.jpg', 'FlipWW84.jpg']
# Filenames with the same name:
# Upper Central Incisor: WW80.jpg, WW82.jpg, WW88.jpg, FlipWW84.jpg
# Lower Second Molar: WW80.jpg, WW82.jpg, WW88.jpg, FlipWW84.jpg
# Pair: Lower Second Molar and Upper Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower Second Molar:
jpg', 'FlipW97.jpg', 'FlipW90.jpg', 'FlipWW75.jpg', 'WW76.jpg', 'WW79.jpg']
# Filenames with the same name:
# Lower First Molar: FlipW87.jpg, W91.jpg, FlipW91.jpg, W88.jpg, W97.jpg, FlipW97.jpg, FlipW90.jpg, FlipWW75.jpg, WW76.jpg, WW79.jpg
# Condyle: FlipW87.jpg, W91.jpg, FlipW91.jpg, W88.jpg, W97.jpg, FlipW97.jpg, FlipW90.jpg, FlipWW75.jpg, WW76.jpg, WW79.jpg
# Pair: Lower First Molar and Upper First Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower First Molar: 7/7 (100.00%) of total
#     Filenames: ['FlipW91.jpg', 'W88.jpg', 'FlipW97.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'WW88.jpg']
# 2. Upper First Molar: 7/7 (100.00%) of total
#     Filenames: ['FlipW91.jpg', 'W88.jpg', 'FlipW97.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW79.jpg', 'WW88.jpg']
# Filenames with the same name:
# Lower First Molar: FlipW91.jpg, W88.jpg, FlipW97.jpg, WW76.jpg, FlipWW78.jpg, WW79.jpg, WW88.jpg
# Upper First Molar: FlipW91.jpg, W88.jpg, FlipW97.jpg, WW76.jpg, FlipWW78.jpg, WW79.jpg, WW88.jpg
# Pair: Lower First Molar and Lower Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower First Molar: 5/5 (100.00%) of total
#     Filenames: ['FlipW92.jpg', 'W95.jpg', 'FlipW90.jpg', 'FlipWW78.jpg', 'WW88.jpg']
# 2. Lower Third Molar: 5/5 (100.00%) of total
#     Filenames: ['FlipW92.jpg', 'W95.jpg', 'FlipW90.jpg', 'FlipWW78.jpg', 'WW88.jpg']
# Filenames with the same name:
# Lower First Molar: FlipW92.jpg, W95.jpg, FlipW90.jpg, FlipWW78.jpg, WW88.jpg
# Lower Third Molar: FlipW92.jpg, W95.jpg, FlipW90.jpg, FlipWW78.jpg, WW88.jpg
# Pair: Lower First Molar and Lower Canine
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower First Molar and Upper Central Incisor
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower First Molar: 1/1 (100.00%) of total
#     Filenames: ['WW88.jpg']
# 2. Upper Central Incisor: 1/1 (100.00%) of total
#     Filenames: ['WW88.jpg']
# Filenames with the same name:
# Lower First Molar: WW88.jpg
# Upper Central Incisor: WW88.jpg
# Pair: Lower First Molar and Upper Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower First Molar: 3/3 (100.00%) of total
#     Filenames: ['WW76.jpg', 'FlipWW78.jpg', 'WW88.jpg']
# 2. Upper Third Molar: 3/3 (100.00%) of total
#     Filenames: ['WW76.jpg', 'FlipWW78.jpg', 'WW88.jpg']
# Filenames with the same name:
# Lower First Molar: WW76.jpg, FlipWW78.jpg, WW88.jpg
# Upper Third Molar: WW76.jpg, FlipWW78.jpg, WW88.jpg
# Pair: Lower First Molar and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower First Molar: 1/1 (100.00%) of total
#     Filenames: ['FlipW97.jpg']
# 2. Nasal: 1/1 (100.00%) of total
#     Filenames: ['FlipW97.jpg']
# Filenames with the same name:
# Lower First Molar: FlipW97.jpg
# Nasal: FlipW97.jpg
# Pair: Lower First Premolar and Condyle
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower First Premolar: 2/2 (100.00%) of total
#     Filenames: ['WW76.jpg', 'FlipWW84.jpg']
# 2. Condyle: 2/2 (100.00%) of total
#     Filenames: ['WW76.jpg', 'FlipWW84.jpg']
# Filenames with the same name:
# Lower First Premolar: WW76.jpg, FlipWW84.jpg
# Condyle: WW76.jpg, FlipWW84.jpg
# Pair: Lower First Premolar and Upper First Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Upper First Molar: 1/1 (100.00%) of total
#     Filenames: ['WW76.jpg']
# 2. Lower First Premolar: 1/1 (100.00%) of total
#     Filenames: ['WW76.jpg']
# Filenames with the same name:
# Upper First Molar: WW76.jpg
# Lower First Premolar: WW76.jpg
# Pair: Lower First Premolar and Lower Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower First Premolar: 2/2 (100.00%) of total
#     Filenames: ['W95.jpg', 'FlipWW84.jpg']
# 2. Lower Third Molar: 2/2 (100.00%) of total
#     Filenames: ['W95.jpg', 'FlipWW84.jpg']
# Filenames with the same name:
# Lower First Premolar: W95.jpg, FlipWW84.jpg
# Lower Third Molar: W95.jpg, FlipWW84.jpg
# Pair: Lower First Premolar and Lower Canine
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower First Premolar: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# 2. Lower Canine: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# Filenames with the same name:
# Lower First Premolar: FlipWW84.jpg
# Lower Canine: FlipWW84.jpg
# Pair: Lower First Premolar and Upper Central Incisor
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower First Premolar: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# 2. Upper Central Incisor: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# Filenames with the same name:
# Lower First Premolar: FlipWW84.jpg
# Upper Central Incisor: FlipWW84.jpg
# Pair: Lower First Premolar and Upper Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower First Premolar: 1/1 (100.00%) of total
#     Filenames: ['WW76.jpg']
# 2. Upper Third Molar: 1/1 (100.00%) of total
#     Filenames: ['WW76.jpg']
# Filenames with the same name:
# Lower First Premolar: WW76.jpg
# Upper Third Molar: WW76.jpg
# Pair: Lower First Premolar and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Condyle and Upper First Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Upper First Molar: 6/6 (100.00%) of total
#     Filenames: ['FlipW91.jpg', 'FlipW95.jpg', 'W88.jpg', 'FlipW97.jpg', 'WW76.jpg', 'WW79.jpg']
# 2. Condyle: 6/6 (100.00%) of total
#     Filenames: ['FlipW91.jpg', 'FlipW95.jpg', 'W88.jpg', 'FlipW97.jpg', 'WW76.jpg', 'WW79.jpg']
# Filenames with the same name:
# Upper First Molar: FlipW91.jpg, FlipW95.jpg, W88.jpg, FlipW97.jpg, WW76.jpg, WW79.jpg
# Condyle: FlipW91.jpg, FlipW95.jpg, W88.jpg, FlipW97.jpg, WW76.jpg, WW79.jpg
# Pair: Condyle and Lower Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Condyle: 5/5 (100.00%) of total
#     Filenames: ['W84.jpg', 'FlipW95.jpg', 'FlipW90.jpg', 'WW85.jpg', 'FlipWW84.jpg']
# 2. Lower Third Molar: 5/5 (100.00%) of total
#     Filenames: ['W84.jpg', 'FlipW95.jpg', 'FlipW90.jpg', 'WW85.jpg', 'FlipWW84.jpg']
# Filenames with the same name:
# Condyle: W84.jpg, FlipW95.jpg, FlipW90.jpg, WW85.jpg, FlipWW84.jpg
# Lower Third Molar: W84.jpg, FlipW95.jpg, FlipW90.jpg, WW85.jpg, FlipWW84.jpg
# Pair: Condyle and Lower Canine
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Condyle: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# 2. Lower Canine: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# Filenames with the same name:
# Condyle: FlipWW84.jpg
# Lower Canine: FlipWW84.jpg
# Pair: Condyle and Upper Central Incisor
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Condyle: 2/2 (100.00%) of total
#     Filenames: ['FlipWW84.jpg', 'FlipWW90.jpg']
# 2. Upper Central Incisor: 2/2 (100.00%) of total
#     Filenames: ['FlipWW84.jpg', 'FlipWW90.jpg']
# Filenames with the same name:
# Condyle: FlipWW84.jpg, FlipWW90.jpg
# Upper Central Incisor: FlipWW84.jpg, FlipWW90.jpg
# Pair: Condyle and Upper Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Condyle: 3/3 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'WW76.jpg', 'WW85.jpg']
# 2. Upper Third Molar: 3/3 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'WW76.jpg', 'WW85.jpg']
# Filenames with the same name:
# Condyle: FlipW95.jpg, WW76.jpg, WW85.jpg
# Upper Third Molar: FlipW95.jpg, WW76.jpg, WW85.jpg
# Pair: Condyle and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Nasal: 1/1 (100.00%) of total
#     Filenames: ['FlipW97.jpg']
# 2. Condyle: 1/1 (100.00%) of total
#     Filenames: ['FlipW97.jpg']
# Filenames with the same name:
# Nasal: FlipW97.jpg
# Condyle: FlipW97.jpg
# Pair: Upper First Molar and Lower Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower Third Molar: 8/8 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'FlipWW78.jpg', 'FlipWW79.jpg', 'WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg', 'FlipWW82.jpg', 'WW88.jpg']
# 2. Upper First Molar: 8/8 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'FlipWW78.jpg', 'FlipWW79.jpg', 'WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg', 'FlipWW82.jpg', 'WW88.jpg']
# Filenames with the same name:
# Lower Third Molar: FlipW95.jpg, FlipWW78.jpg, FlipWW79.jpg, WW80.jpg, FlipWW80.jpg, WW82.jpg, FlipWW82.jpg, WW88.jpg
# Upper First Molar: FlipW95.jpg, FlipWW78.jpg, FlipWW79.jpg, WW80.jpg, FlipWW80.jpg, WW82.jpg, FlipWW82.jpg, WW88.jpg
# Pair: Upper First Molar and Lower Canine
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper First Molar and Upper Central Incisor
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Upper First Molar: 4/4 (100.00%) of total
#     Filenames: ['WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg', 'WW88.jpg']
# 2. Upper Central Incisor: 4/4 (100.00%) of total
#     Filenames: ['WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg', 'WW88.jpg']
# Filenames with the same name:
# Upper First Molar: WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg
# Upper Central Incisor: WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg
# Pair: Upper First Molar and Upper Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Upper First Molar: 7/7 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg', 'WW88.jpg']
# 2. Upper Third Molar: 7/7 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'WW76.jpg', 'FlipWW78.jpg', 'WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg', 'WW88.jpg']
# Filenames with the same name:
# Upper First Molar: FlipW95.jpg, WW76.jpg, FlipWW78.jpg, WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg
# Upper Third Molar: FlipW95.jpg, WW76.jpg, FlipWW78.jpg, WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg
# Pair: Upper First Molar and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Upper First Molar: 1/1 (100.00%) of total
#     Filenames: ['FlipW97.jpg']
# 2. Nasal: 1/1 (100.00%) of total
#     Filenames: ['FlipW97.jpg']
# Filenames with the same name:
# Upper First Molar: FlipW97.jpg
# Nasal: FlipW97.jpg
# Pair: Lower Third Molar and Lower Canine
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower Canine: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# 2. Lower Third Molar: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# Filenames with the same name:
# Lower Canine: FlipWW84.jpg
# Lower Third Molar: FlipWW84.jpg
# Pair: Lower Third Molar and Upper Central Incisor
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower Third Molar: 5/5 (100.00%) of total
#     Filenames: ['WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg', 'WW88.jpg', 'FlipWW84.jpg']
# 2. Upper Central Incisor: 5/5 (100.00%) of total
#     Filenames: ['WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg', 'WW88.jpg', 'FlipWW84.jpg']
# Filenames with the same name:
# Lower Third Molar: WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg, FlipWW84.jpg
# Upper Central Incisor: WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg, FlipWW84.jpg
# Pair: Lower Third Molar and Upper Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower Third Molar: 10/10 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'W86.jpg', 'FlipW86.jpg', 'FlipWW78.jpg', 'WW85.jpg', 'WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg', 'WW88.jpg', 'FlipWW88.jpg']
# 2. Upper Third Molar: 10/10 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'W86.jpg', 'FlipW86.jpg', 'FlipWW78.jpg', 'WW85.jpg', 'WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg', 'WW88.jpg', 'FlipWW88.jpg']
# Filenames with the same name:
# Lower Third Molar: FlipW95.jpg, W86.jpg, FlipW86.jpg, FlipWW78.jpg, WW85.jpg, WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg, FlipWW88.jpg
# Upper Third Molar: FlipW95.jpg, W86.jpg, FlipW86.jpg, FlipWW78.jpg, WW85.jpg, WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg, FlipWW88.jpg
# Pair: Lower Third Molar and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Canine and Upper Central Incisor
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Lower Canine: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# 2. Upper Central Incisor: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# Filenames with the same name:
# Lower Canine: FlipWW84.jpg
# Upper Central Incisor: FlipWW84.jpg
# Pair: Lower Canine and Upper Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Canine and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper Central Incisor and Upper Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 2
# 1. Upper Central Incisor: 4/4 (100.00%) of total
#     Filenames: ['WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg', 'WW88.jpg']
# 2. Upper Third Molar: 4/4 (100.00%) of total
#     Filenames: ['WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg', 'WW88.jpg']
# Filenames with the same name:
# Upper Central Incisor: WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg
# Upper Third Molar: WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg
# Pair: Upper Central Incisor and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper Third Molar and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:

# %%
# Optional: Create a DataFrame to keep all the information together
age_pos = []
for (name1, name2), result in pair_results.items():
    for name, count in result['sorted_names']:
      if name in name1:
        age_pos.append({
            'name': name,
            'pair': name2, #'pair': f"{name1} and {name2}"
            'count': count,
            'total_1': len(age_9_pos[age_9_pos['name']== name1]),
            'percentage_1':  f"{(count / len(age_9_pos[age_9_pos['name']== name1])) * 100 :.2f}%",
            'total_2': len(age_9_pos[age_9_pos['name']== name2]),
            'percentage_2':  f"{(count / len(age_9_pos[age_9_pos['name']== name2])) * 100 :.2f}%",
            'total_files': len(age_9_pos['filename'].unique()),
            'percentage_files':  f"{(count / len(age_9_pos['filename'].unique())) * 100 :.2f}%",
            'filenames': result['name_files'][name]
        })

pos_2 = pd.DataFrame(age_pos)
pos_2
# Out:
#                       name                   pair  count  total_1  \
# 0       Lower Second Molar  Upper Second Premolar      9       24
# 1       Lower Second Molar  Lower Second Premolar      9       24
# 2       Lower Second Molar           Upper Canine     11       24
# 3       Lower Second Molar       Mandibular angle      5       24
# 4       Lower Second Molar   Upper First Premolar      6       24
# ..                     ...                    ...    ...      ...
# 131      Lower Third Molar           Lower Canine      1       20
# 132      Lower Third Molar  Upper Central Incisor      5       20
# 133      Lower Third Molar      Upper Third Molar     10       20
# 134           Lower Canine  Upper Central Incisor      1        1
# 135  Upper Central Incisor      Upper Third Molar      4        7
#
#     percentage_1  total_2 percentage_2  total_files percentage_files  \
# 0         37.50%       11       81.82%           32           28.12%
# 1         37.50%       11       81.82%           32           28.12%
# 2         45.83%       15       73.33%           32           34.38%
# 3         20.83%        6       83.33%           32           15.62%
# 4         25.00%       10       60.00%           32           18.75%
# ..           ...      ...          ...          ...              ...
# 131        5.00%        1      100.00%           32            3.12%
# 132       25.00%        7       71.43%           32           15.62%
# 133       50.00%       12       83.33%           32           31.25%
# 134      100.00%        7       14.29%           32            3.12%
# 135       57.14%       12       33.33%           32           12.50%
#
#                                              filenames
# 0    [W84.jpg, FlipW97.jpg, FlipW90.jpg, WW76.jpg, ...
# 1    [FlipW92.jpg, W95.jpg, W88.jpg, FlipW97.jpg, F...
# 2    [W84.jpg, W95.jpg, FlipW97.jpg, FlipWW78.jpg, ...
# 3    [W84.jpg, FlipWW78.jpg, WW79.jpg, WW80.jpg, WW...
# 4    [W95.jpg, W86.jpg, WW75.jpg, FlipWW78.jpg, WW7...
# ..                                                 ...
# 131                                     [FlipWW84.jpg]
# 132  [WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg, F...
# 133  [FlipW95.jpg, W86.jpg, FlipW86.jpg, FlipWW78.j...
# 134                                     [FlipWW84.jpg]
# 135       [WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg]
#
# [136 rows x 10 columns]

# %%
percentage = pos_2['percentage_files'].tolist()
# Convert to a list of integers
pos_2['percentage_float'] = [float(p.replace('%', '')) for p in percentage]

# %%
pos_2
# Out:
#                       name                   pair  count  total_1  \
# 0       Lower Second Molar  Upper Second Premolar      9       24
# 1       Lower Second Molar  Lower Second Premolar      9       24
# 2       Lower Second Molar           Upper Canine     11       24
# 3       Lower Second Molar       Mandibular angle      5       24
# 4       Lower Second Molar   Upper First Premolar      6       24
# ..                     ...                    ...    ...      ...
# 131      Lower Third Molar           Lower Canine      1       20
# 132      Lower Third Molar  Upper Central Incisor      5       20
# 133      Lower Third Molar      Upper Third Molar     10       20
# 134           Lower Canine  Upper Central Incisor      1        1
# 135  Upper Central Incisor      Upper Third Molar      4        7
#
#     percentage_1  total_2 percentage_2  total_files percentage_files  \
# 0         37.50%       11       81.82%           32           28.12%
# 1         37.50%       11       81.82%           32           28.12%
# 2         45.83%       15       73.33%           32           34.38%
# 3         20.83%        6       83.33%           32           15.62%
# 4         25.00%       10       60.00%           32           18.75%
# ..           ...      ...          ...          ...              ...
# 131        5.00%        1      100.00%           32            3.12%
# 132       25.00%        7       71.43%           32           15.62%
# 133       50.00%       12       83.33%           32           31.25%
# 134      100.00%        7       14.29%           32            3.12%
# 135       57.14%       12       33.33%           32           12.50%
#
#                                              filenames  percentage_float
# 0    [W84.jpg, FlipW97.jpg, FlipW90.jpg, WW76.jpg, ...             28.12
# 1    [FlipW92.jpg, W95.jpg, W88.jpg, FlipW97.jpg, F...             28.12
# 2    [W84.jpg, W95.jpg, FlipW97.jpg, FlipWW78.jpg, ...             34.38
# 3    [W84.jpg, FlipWW78.jpg, WW79.jpg, WW80.jpg, WW...             15.62
# 4    [W95.jpg, W86.jpg, WW75.jpg, FlipWW78.jpg, WW7...             18.75
# ..                                                 ...               ...
# 131                                     [FlipWW84.jpg]              3.12
# 132  [WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg, F...             15.62
# 133  [FlipW95.jpg, W86.jpg, FlipW86.jpg, FlipWW78.j...             31.25
# 134                                     [FlipWW84.jpg]              3.12
# 135       [WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg]             12.50
#
# [136 rows x 11 columns]

# %%
pos_2_sort =  pos_2.sort_values(by='percentage_float', ascending=False)

# %%
pos_2_sort
# Out:
#                           name                  pair  count  total_1  \
# 7           Lower Second Molar    Upper Second Molar     18       24
# 104         Upper Second Molar     Lower Third Molar     16       23
# 12          Lower Second Molar     Lower Third Molar     15       24
# 8           Lower Second Molar     Lower First Molar     13       24
# 51                Upper Canine    Upper Second Molar     13       15
# ..                         ...                   ...    ...      ...
# 32       Upper Second Premolar                 Nasal      1       11
# 29       Upper Second Premolar          Lower Canine      1       11
# 99   Posterior border of Ramus     Upper Third Molar      1        7
# 94   Posterior border of Ramus               Condyle      1        7
# 101         Upper Second Molar  Lower First Premolar      1       23
#
#     percentage_1  total_2 percentage_2  total_files percentage_files  \
# 7         75.00%       23       78.26%           32           56.25%
# 104       69.57%       20       80.00%           32           50.00%
# 12        62.50%       20       75.00%           32           46.88%
# 8         54.17%       14       92.86%           32           40.62%
# 51        86.67%       23       56.52%           32           40.62%
# ..           ...      ...          ...          ...              ...
# 32         9.09%        1      100.00%           32            3.12%
# 29         9.09%        1      100.00%           32            3.12%
# 99        14.29%       12        8.33%           32            3.12%
# 94        14.29%       15        6.67%           32            3.12%
# 101        4.35%        3       33.33%           32            3.12%
#
#                                              filenames  percentage_float
# 7    [W84.jpg, FlipW91.jpg, FlipW92.jpg, W95.jpg, W...             56.25
# 104  [W84.jpg, W92.jpg, FlipW92.jpg, W95.jpg, FlipW...             50.00
# 12   [W84.jpg, FlipW92.jpg, W95.jpg, W86.jpg, FlipW...             46.88
# 8    [FlipW87.jpg, W91.jpg, FlipW91.jpg, FlipW92.jp...             40.62
# 51   [W84.jpg, W95.jpg, FlipW95.jpg, FlipW97.jpg, F...             40.62
# ..                                                 ...               ...
# 32                                       [FlipW97.jpg]              3.12
# 29                                      [FlipWW84.jpg]              3.12
# 99                                      [FlipWW88.jpg]              3.12
# 94                                      [FlipWW84.jpg]              3.12
# 101                                          [W95.jpg]              3.12
#
# [136 rows x 11 columns]

# %%
table = pos_2_sort.reset_index()
table = table.iloc[:,1:]
table
# Out:
#                           name                  pair  count  total_1  \
# 0           Lower Second Molar    Upper Second Molar     18       24
# 1           Upper Second Molar     Lower Third Molar     16       23
# 2           Lower Second Molar     Lower Third Molar     15       24
# 3           Lower Second Molar     Lower First Molar     13       24
# 4                 Upper Canine    Upper Second Molar     13       15
# ..                         ...                   ...    ...      ...
# 131      Upper Second Premolar                 Nasal      1       11
# 132      Upper Second Premolar          Lower Canine      1       11
# 133  Posterior border of Ramus     Upper Third Molar      1        7
# 134  Posterior border of Ramus               Condyle      1        7
# 135         Upper Second Molar  Lower First Premolar      1       23
#
#     percentage_1  total_2 percentage_2  total_files percentage_files  \
# 0         75.00%       23       78.26%           32           56.25%
# 1         69.57%       20       80.00%           32           50.00%
# 2         62.50%       20       75.00%           32           46.88%
# 3         54.17%       14       92.86%           32           40.62%
# 4         86.67%       23       56.52%           32           40.62%
# ..           ...      ...          ...          ...              ...
# 131        9.09%        1      100.00%           32            3.12%
# 132        9.09%        1      100.00%           32            3.12%
# 133       14.29%       12        8.33%           32            3.12%
# 134       14.29%       15        6.67%           32            3.12%
# 135        4.35%        3       33.33%           32            3.12%
#
#                                              filenames  percentage_float
# 0    [W84.jpg, FlipW91.jpg, FlipW92.jpg, W95.jpg, W...             56.25
# 1    [W84.jpg, W92.jpg, FlipW92.jpg, W95.jpg, FlipW...             50.00
# 2    [W84.jpg, FlipW92.jpg, W95.jpg, W86.jpg, FlipW...             46.88
# 3    [FlipW87.jpg, W91.jpg, FlipW91.jpg, FlipW92.jp...             40.62
# 4    [W84.jpg, W95.jpg, FlipW95.jpg, FlipW97.jpg, F...             40.62
# ..                                                 ...               ...
# 131                                      [FlipW97.jpg]              3.12
# 132                                     [FlipWW84.jpg]              3.12
# 133                                     [FlipWW88.jpg]              3.12
# 134                                     [FlipWW84.jpg]              3.12
# 135                                          [W95.jpg]              3.12
#
# [136 rows x 11 columns]

# %%
table.to_csv('/content/gdrive/My Drive/Tooth_Shap_GPT/Deep_tooth/OPG_SHAPer/Result/Age/95_percentie/Pos_9/(2)ALL_.csv', index=False)

# %%
table[table['percentage_float']>=50.00]
# Out:
#                  name                pair  count  total_1 percentage_1  \
# 0  Lower Second Molar  Upper Second Molar     18       24       75.00%
# 1  Upper Second Molar   Lower Third Molar     16       23       69.57%
#
#    total_2 percentage_2  total_files percentage_files  \
# 0       23       78.26%           32           56.25%
# 1       20       80.00%           32           50.00%
#
#                                            filenames  percentage_float
# 0  [W84.jpg, FlipW91.jpg, FlipW92.jpg, W95.jpg, W...             56.25
# 1  [W84.jpg, W92.jpg, FlipW92.jpg, W95.jpg, FlipW...             50.00

# %%
table = table[table['percentage_float']>=50.00]
table
# Out:
#                  name                pair  count  total_1 percentage_1  \
# 0  Lower Second Molar  Upper Second Molar     18       24       75.00%
# 1  Upper Second Molar   Lower Third Molar     16       23       69.57%
#
#    total_2 percentage_2  total_files percentage_files  \
# 0       23       78.26%           32           56.25%
# 1       20       80.00%           32           50.00%
#
#                                            filenames  percentage_float
# 0  [W84.jpg, FlipW91.jpg, FlipW92.jpg, W95.jpg, W...             56.25
# 1  [W84.jpg, W92.jpg, FlipW92.jpg, W95.jpg, FlipW...             50.00

# %%
# table = table.iloc[:10,] #top 10
# table

# %%
table = table.iloc[:,:-1]

# %%
table
# Out:
#                  name                pair  count  total_1 percentage_1  \
# 0  Lower Second Molar  Upper Second Molar     18       24       75.00%
# 1  Upper Second Molar   Lower Third Molar     16       23       69.57%
#
#    total_2 percentage_2  total_files percentage_files  \
# 0       23       78.26%           32           56.25%
# 1       20       80.00%           32           50.00%
#
#                                            filenames
# 0  [W84.jpg, FlipW91.jpg, FlipW92.jpg, W95.jpg, W...
# 1  [W84.jpg, W92.jpg, FlipW92.jpg, W95.jpg, FlipW...

# %%
table.to_csv('/content/gdrive/My Drive/Tooth_Shap_GPT/Deep_tooth/OPG_SHAPer/Result/Age/95_percentie/Pos_9/(2)ALL_(>=50%).csv', index=False)

# %% [markdown]
# ### 3 with combinations (372/99 rows)

# %%
from itertools import combinations

# List of names
names = [
    'Lower Second Molar', 'Upper Second Premolar', 'Lower Second Premolar',
    'Upper Canine', 'Mandibular angle', 'Upper First Premolar',
    'Upper Lateral Incisor', 'Posterior border of Ramus', 'Upper Second Molar',
    'Lower First Molar', 'Lower First Premolar', 'Condyle', 'Upper First Molar',
    'Lower Third Molar', 'Lower Canine', 'Upper Central Incisor',
    'Upper Third Molar', 'Nasal'
]

# Get all combinations of names with length 2
pairs_of_names = list(combinations(names, 3))
print(pairs_of_names)
# Out:
# [('Lower Second Molar', 'Upper Second Premolar', 'Lower Second Premolar'), ('Lower Second Molar', 'Upper Second Premolar', 'Upper Canine'), ('Lower Second Molar', 'Upper Second Premolar', 'Mandibular angle'), ('Lower Second Molar', 'Upper Second Premolar', 'Upper First Premolar'), ('Lower Second Molar', 'Upper Second Premolar', 'Upper Lateral Incisor'), ('Lower Second Molar', 'Upper Second Premolar', 'Posterior border of Ramus'), ('Lower Second Molar', 'Upper Second Premolar', 'Upper Second Molar'), ('Lower Second Molar', 'Upper Second Premolar', 'Lower First Molar'), ('Lower Second Molar', 'Upper Second Premolar', 'Lower First Premolar'), ('Lower Second Molar', 'Upper Second Premolar', 'Condyle'), ('Lower Second Molar', 'Upper Second Premolar', 'Upper First Molar'), ('Lower Second Molar', 'Upper Second Premolar', 'Lower Third Molar'), ('Lower Second Molar', 'Upper Second Premolar', 'Lower Canine'), ('Lower Second Molar', 'Upper Second Premolar', 'Upper Central Incisor'), ('Lower Second Molar', 'Upper Second Premolar', 'Upper Third Molar'), ('Lower Second Molar', 'Upper Second Premolar', 'Nasal'), ('Lower Second Molar', 'Lower Second Premolar', 'Upper Canine'), ('Lower Second Molar', 'Lower Second Premolar', 'Mandibular angle'), ('Lower Second Molar', 'Lower Second Premolar', 'Upper First Premolar'), ('Lower Second Molar', 'Lower Second Premolar', 'Upper Lateral Incisor'), ('Lower Second Molar', 'Lower Second Premolar', 'Posterior border of Ramus'), ('Lower Second Molar', 'Lower Second Premolar', 'Upper Second Molar'), ('Lower Second Molar', 'Lower Second Premolar', 'Lower First Molar'), ('Lower Second Molar', 'Lower Second Premolar', 'Lower First Premolar'), ('Lower Second Molar', 'Lower Second Premolar', 'Condyle'), ('Lower Second Molar', 'Lower Second Premolar', 'Upper First Molar'), ('Lower Second Molar', 'Lower Second Premolar', 'Lower Third Molar'), ('Lower Second Molar', 'Lower Second Premolar', 'Lower Canine'), ('Lower Second Molar', 'Lower Second Premolar', 'Upper Central Incisor'), ('Lower Second Molar', 'Lower Second Premolar', 'Upper Third Molar'), ('Lower Second Molar', 'Lower Second Premolar', 'Nasal'), ('Lower Second Molar', 'Upper Canine', 'Mandibular angle'), ('Lower Second Molar', 'Upper Canine', 'Upper First Premolar'), ('Lower Second Molar', 'Upper Canine', 'Upper Lateral Incisor'), ('Lower Second Molar', 'Upper Canine', 'Posterior border of Ramus'), ('Lower Second Molar', 'Upper Canine', 'Upper Second Molar'), ('Lower Second Molar', 'Upper Canine', 'Lower First Molar'), ('Lower Second Molar', 'Upper Canine', 'Lower First Premolar'), ('Lower Second Molar', 'Upper Canine', 'Condyle'), ('Lower Second Molar', 'Upper Canine', 'Upper First Molar'), ('Lower Second Molar', 'Upper Canine', 'Lower Third Molar'), ('Lower Second Molar', 'Upper Canine', 'Lower Canine'), ('Lower Second Molar', 'Upper Canine', 'Upper Central Incisor'), ('Lower Second Molar', 'Upper Canine', 'Upper Third Molar'), ('Lower Second Molar', 'Upper Canine', 'Nasal'), ('Lower Second Molar', 'Mandibular angle', 'Upper First Premolar'), ('Lower Second Molar', 'Mandibular angle', 'Upper Lateral Incisor'), ('Lower Second Molar', 'Mandibular angle', 'Posterior border of Ramus'), ('Lower Second Molar', 'Mandibular angle', 'Upper Second Molar'), ('Lower Second Molar', 'Mandibular angle', 'Lower First Molar'), ('Lower Second Molar', 'Mandibular angle', 'Lower First Premolar'), ('Lower Second Molar', 'Mandibular angle', 'Condyle'), ('Lower Second Molar', 'Mandibular angle', 'Upper First Molar'), ('Lower Second Molar', 'Mandibular angle', 'Lower Third Molar'), ('Lower Second Molar', 'Mandibular angle', 'Lower Canine'), ('Lower Second Molar', 'Mandibular angle', 'Upper Central Incisor'), ('Lower Second Molar', 'Mandibular angle', 'Upper Third Molar'), ('Lower Second Molar', 'Mandibular angle', 'Nasal'), ('Lower Second Molar', 'Upper First Premolar', 'Upper Lateral Incisor'), ('Lower Second Molar', 'Upper First Premolar', 'Posterior border of Ramus'), ('Low ...

# %%
len(pairs_of_names)
# Out:
# 816

# %%
import pandas as pd

# Dictionary to store results for each pair
pair_results = {}

for name1, name2, name3 in pairs_of_names:
    # Identify filenames that contain name1
    A = set(age_9_pos[age_9_pos['name'] == name1]['filename'])

    # Identify filenames that contain name2
    B = set(age_9_pos[age_9_pos['name'] == name2]['filename'])

    # Identify filenames that contain name3
    C = set(age_9_pos[age_9_pos['name'] == name3]['filename'])

    # Find the intersection of the three sets to get filenames that contain name1, name2, and name3
    common_filenames = A.intersection(B).intersection(C)

    # Filter the DataFrame to include only the common filenames
    filtered_filenames = age_9_pos[age_9_pos['filename'].isin(common_filenames)]

    # Filter the DataFrame to include only name1, name2, or name3
    filtered_region = filtered_filenames[filtered_filenames['name'].isin([name1, name2, name3])]

    # Dictionary to store name counts and associated filenames
    name_count_pos = {}
    name_files = {}

    # List of names
    list_pos = filtered_region['name'].tolist()
    # List of filenames
    filenames = filtered_region['filename'].tolist()

    # Iterate over each name and corresponding filename
    for name, filename in zip(list_pos, filenames):
        if name in name_count_pos:
            name_count_pos[name] += 1
            name_files[name].append(filename)
        else:
            name_count_pos[name] = 1
            name_files[name] = [filename]

    # Sort the name_count_pos dictionary by count of occurrences (descending order)
    sorted_names = sorted(name_count_pos.items(), key=lambda x: x[1], reverse=True)

    # Store the results in the dictionary
    pair_results[(name1, name2, name3)] = {
        'sorted_names': sorted_names,
        'name_files': name_files
    }

    # Print a summary for this pair
    print(f"Pair: {name1}, {name2} and {name3}")
    print("Unique names and their occurrences in posative SHAP values area:")
    total_unique_names = len(sorted_names)
    print(f"Total Unique Names: {total_unique_names}")

    for i, (name, count) in enumerate(sorted_names, start=1):
        unique_filenames = len(set(name_files[name]))  # Calculate unique filenames
        print(f"{i}. {name}: {count}/{len(filtered_region['filename'].unique())} ({(count / len(filtered_region['filename'].unique())):.2%}) of total")
        print(f"    Filenames: {name_files[name]}")

    print("Filenames with the same name:")
    for name, filenames in name_files.items():
        if len(set(filenames)) >= 1:  # Only consider names that appear in more than one filename
            print(f"{name}: {', '.join(filenames)}")
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
# 2. Lower Second Premolar: 3/3 (100.00%) of total
#     Filenames: ['W95.jpg', 'FlipW97.jpg', 'WW81.jpg']
# 3. Upper Canine: 3/3 (100.00%) of total
#     Filenames: ['W95.jpg', 'FlipW97.jpg', 'WW81.jpg']
# Filenames with the same name:
# Upper Second Molar: W95.jpg, FlipW97.jpg, WW81.jpg
# Lower Second Premolar: W95.jpg, FlipW97.jpg, WW81.jpg
# Upper Canine: W95.jpg, FlipW97.jpg, WW81.jpg
# Pair: Lower Second Premolar, Upper Canine and Lower First Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Lower First Molar: 2/2 (100.00%) of total
#     Filenames: ['W95.jpg', 'FlipW97.jpg']
# 2. Lower Second Premolar: 2/2 (100.00%) of total
#     Filenames: ['W95.jpg', 'FlipW97.jpg']
# 3. Upper Canine: 2/2 (100.00%) of total
#     Filenames: ['W95.jpg', 'FlipW97.jpg']
# Filenames with the same name:
# Lower First Molar: W95.jpg, FlipW97.jpg
# Lower Second Premolar: W95.jpg, FlipW97.jpg
# Upper Canine: W95.jpg, FlipW97.jpg
# Pair: Lower Second Premolar, Upper Canine and Lower First Premolar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Lower First Premolar: 1/1 (100.00%) of total
#     Filenames: ['W95.jpg']
# 2. Lower Second Premolar: 1/1 (100.00%) of total
#     Filenames: ['W95.jpg']
# 3. Upper Canine: 1/1 (100.00%) of total
#     Filenames: ['W95.jpg']
# Filenames with the same name:
# Lower First Premolar: W95.jpg
# Lower Second Premolar: W95.jpg
# Upper Canine: W95.jpg
# Pair: Lower Second Premolar, Upper Canine and Condyle
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Upper Canine: 1/1 (100.00%) of total
#     Filenames: ['FlipW97.jpg']
# 2. Lower Second Premolar: 1/1 (100.00%) of total
#     Filenames: ['FlipW97.jpg']
# 3. Condyle: 1/1 (100.00%) of total
#     Filenames: ['FlipW97.jpg']
# Filenames with the same name:
# Upper Canine: FlipW97.jpg
# Lower Second Premolar: FlipW97.jpg
# Condyle: FlipW97.jpg
# Pair: Lower Second Premolar, Upper Canine and Upper First Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Upper Canine: 1/1 (100.00%) of total
#     Filenames: ['FlipW97.jpg']
# 2. Lower Second Premolar: 1/1 (100.00%) of total
#     Filenames: ['FlipW97.jpg']
# 3. Upper First Molar: 1/1 (100.00%) of total
#     Filenames: ['FlipW97.jpg']
# Filenames with the same name:
# Upper Canine: FlipW97.jpg
# Lower Second Premolar: FlipW97.jpg
# Upper First Molar: FlipW97.jpg
# Pair: Lower Second Premolar, Upper Canine and Lower Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Lower Second Premolar: 2/2 (100.00%) of total
#     Filenames: ['W95.jpg', 'WW81.jpg']
# 2. Lower Third Molar: 2/2 (100.00%) of total
#     Filenames: ['W95.jpg', 'WW81.jpg']
# 3. Upper Canine: 2/2 (100.00%) of total
#     Filenames: ['W95.jpg', 'WW81.jpg']
# Filenames with the same name:
# Lower Second Premolar: W95.jpg, WW81.jpg
# Lower Third Molar: W95.jpg, WW81.jpg
# Upper Canine: W95.jpg, WW81.jpg
# Pair: Lower Second Premolar, Upper Canine and Lower Canine
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Second Premolar, Upper Canine and Upper Central Incisor
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Second Premolar, Upper Canine and Upper Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Second Premolar, Upper Canine and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Upper Canine: 1/1 (100.00%) of total
#     Filenames: ['FlipW97.jpg']
# 2. Lower Second Premolar: 1/1 (100.00%) of total
#     Filenames: ['FlipW97.jpg']
# 3. Nasal: 1/1 (100.00%) of total
#     Filenames: ['FlipW97.jpg']
# Filenames with the same name:
# Upper Canine: FlipW97.jpg
# Lower Second Premolar: FlipW97.jpg
# Nasal: FlipW97.jpg
# Pair: Lower Second Premolar, Mandibular angle and Upper First Premolar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Second Premolar, Mandibular angle and Upper Lateral Incisor
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Second Premolar, Mandibular angle and Posterior border of Ramus
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Second Premolar, Mandibular angle and Upper Second Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Lower Second Premolar: 1/1 (100.00%) of total
#     Filenames: ['WW88.jpg']
# 2. Upper Second Molar: 1/1 (100.00%) of total
#     Filenames: ['WW88.jpg']
# 3. Mandibular angle: 1/1 (100.00%) of total
#     Filenames: ['WW88.jpg']
# Filenames with the same name:
# Lower Second Premolar: WW88.jpg
# Upper Second Molar: WW88.jpg
# Mandibular angle: WW88.jpg
# Pair: Lower Second Premolar, Mandibular angle and Lower First Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Lower First Molar: 1/1 (100.00%) of total
#     Filenames: ['WW88.jpg']
# 2. Lower Second Premolar: 1/1 (100.00%) of total
#     Filenames: ['WW88.jpg']
# 3. Mandibular angle: 1/1 (100.00%) of total
#     Filenames: ['WW88.jpg']
# Filenames with the same name:
# Lower First Molar: WW88.jpg
# Lower Second Premolar: WW88.jpg
# Mandibular angle: WW88.jpg
# Pair: Lower Second Premolar, Mandibular angle and Lower First Premolar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Second Premolar, Mandibular angle and Condyle
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Second Premolar, Mandibular angle and Upper First Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Upper First Molar: 1/1 (100.00%) of total
#     Filenames: ['WW88.jpg']
# 2. Lower Second Premolar: 1/1 (100.00%) of total
#     Filenames: ['WW88.jpg']
# 3. Mandibular angle: 1/1 (100.00%) of total
#     Filenames: ['WW88.jpg']
# Filenames with the same name:
# Upper First Molar: WW88.jpg
# Lower Second Premolar: WW88.jpg
# Mandibular angle: WW88.jpg
# Pair: Lower Second Premolar, Mandibular angle and Lower Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Lower Second Premolar: 1/1 (100.00%) of total
#     Filenames: ['WW88.jpg']
# 2. Mandibular angle: 1/1 (100.00%) of total
#     Filenames: ['WW88.jpg']
# 3. Lower Third Molar: 1/1 (100.00%) of total
#     Filenames: ['WW88.jpg']
# Filenames with the same name:
# Lower Second Premolar: WW88.jpg
# Mandibular angle: WW88.jpg
# Lower Third Molar: WW88.jpg
# Pair: Lower Second Premolar, Mandibular angle and Lower Canine
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Second Premolar, Mandibular angle and Upper Central Incisor
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Lower Second Premolar: 1/1 (100.00%) of total
#     Filenames: ['WW88.jpg']
# 2. Mandibular angle: 1/1 (100.00%) of total
#     Filenames: ['WW88.jpg']
# 3. Upper Central Incisor: 1/1 (100.00%) of total
#     Filenames: ['WW88.jpg']
# Filenames with the same name:
# Lower Second Premolar: WW88.jpg
# Mandibular angle: WW88.jpg
# Upper Central Incisor: WW88.jpg
# Pair: Lower Second Premolar, Mandibular angle and Upper Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Lower Second Premolar: 1/1 (100.00%) of total
#     Filenames: ['WW88.jpg']
# 2. Mandibular angle: 1/1 (100.00%) of total
#     Filenames: ['WW88.jpg']
# 3. Upper Third Molar: 1/1 (100.00%) of total
#     Filenames: ['WW88.jpg']
# Filenames with the same name:
# Lower Second Premolar: WW88.jpg
# Mandibular angle: WW88.jpg
# Upper Third Molar: WW88.jpg
# Pair: Lower Second Premolar, Mandibular angle and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Second Premolar, Upper First Premolar and Upper Lateral Incisor
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Lower Second Premolar: 1/1 (100.00%) of total
#     Filenames: ['W95.jpg']
# 2. Upper Lateral Incisor: 1/1 (100.00%) of total
#     Filenames: ['W95.jpg']
# 3. Upper First Premolar: 1/1 (100.00%) of total
#     Filenames: ['W95.jpg']
# Filenames with the same name:
# Lower Second Premolar: W95.jpg
# Upper Lateral Incisor: W95.jpg
# Upper First Premolar: W95.jpg
# Pair: Lower Second Premolar, Upper First Premolar and Posterior border of Ramus
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Lower Second Premolar: 1/1 (100.00%) of total
#     Filenames: ['W95.jpg']
# 2. Posterior border of Ramus: 1/1 (100.00%) of total
#     Filenames: ['W95.jpg']
# 3. Upper First Premolar: 1/1 (100.00%) of total
#     Filenames: ['W95.jpg']
# Filenames with the same name:
# Lower Second Premolar: W95.jpg
# Posterior border of Ramus: W95.jpg
# Upper First Premolar: W95.jpg
# Pair: Lower Second Premolar, Upper First Premolar and Upper Second Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Upper Second Molar: 3/3 (100.00%) of total
#     Filenames: ['W95.jpg', 'WW75.jpg', 'WW81.jpg']
# 2. Lower Second Premolar: 3/3 (100.00%) of total
#     Filenames: ['W95.jpg', 'WW75.jpg', 'WW81.jpg']
# 3. Upper First Premolar: 3/3 (100.00%) of total
#     Filenames: ['W95.jpg', 'WW75.jpg', 'WW81.jpg']
# Filenames with the same name:
# Upper Second Molar: W95.jpg, WW75.jpg, WW81.jpg
# Lower Second Premolar: W95.jpg, WW75.jpg, WW81.jpg
# Upper First Premolar: W95.jpg, WW75.jpg, WW81.jpg
# Pair: Lower Second Premolar, Upper First Premolar and Lower First Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Lower First Molar: 2/2 (100.00%) of total
#     Filenames: ['W95.jpg', 'FlipWW75.jpg']
# 2. Lower Second Premolar: 2/2 (100.00%) of total
#     Filenames: ['W95.jpg', 'FlipWW75.jpg']
# 3. Upper First Premolar: 2/2 (100.00%) of total
#     Filenames: ['W95.jpg', 'FlipWW75.jpg']
# Filenames with the same name:
# Lower First Molar: W95.jpg, FlipWW75.jpg
# Lower Second Premolar: W95.jpg, FlipWW75.jpg
# Upper First Premolar: W95.jpg, FlipWW75.jpg
# Pair: Lower Second Premolar, Upper First Premolar and Lower First Premolar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Lower First Premolar: 1/1 (100.00%) of total
#     Filenames: ['W95.jpg']
# 2. Lower Second Premolar: 1/1 (100.00%) of total
#     Filenames: ['W95.jpg']
# 3. Upper First Premolar: 1/1 (100.00%) of total
#     Filenames: ['W95.jpg']
# Filenames with the same name:
# Lower First Premolar: W95.jpg
# Lower Second Premolar: W95.jpg
# Upper First Premolar: W95.jpg
# Pair: Lower Second Premolar, Upper First Premolar and Condyle
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Lower Second Premolar: 2/2 (100.00%) of total
#     Filenames: ['FlipWW75.jpg', 'WW85.jpg']
# 2. Upper First Premolar: 2/2 (100.00%) of total
#     Filenames: ['FlipWW75.jpg', 'WW85.jpg']
# 3. Condyle: 2/2 (100.00%) of total
#     Filenames: ['FlipWW75.jpg', 'WW85.jpg']
# Filenames with the same name:
# Lower Second Premolar: FlipWW75.jpg, WW85.jpg
# Upper First Premolar: FlipWW75.jpg, WW85.jpg
# Condyle: FlipWW75.jpg, WW85.jpg
# Pair: Lower Second Premolar, Upper First Premolar and Upper First Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Second Premolar, Upper First Premolar and Lower Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Lower Second Premolar: 3/3 (100.00%) of total
#     Filenames: ['W95.jpg', 'WW81.jpg', 'WW85.jpg']
# 2. Lower Third Molar: 3/3 (100.00%) of total
#     Filenames: ['W95.jpg', 'WW81.jpg', 'WW85.jpg']
# 3. Upper First Premolar: 3/3 (100.00%) of total
#     Filenames: ['W95.jpg', 'WW81.jpg', 'WW85.jpg']
# Filenames with the same name:
# Lower Second Premolar: W95.jpg, WW81.jpg, WW85.jpg
# Lower Third Molar: W95.jpg, WW81.jpg, WW85.jpg
# Upper First Premolar: W95.jpg, WW81.jpg, WW85.jpg
# Pair: Lower Second Premolar, Upper First Premolar and Lower Canine
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Second Premolar, Upper First Premolar and Upper Central Incisor
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Second Premolar, Upper First Premolar and Upper Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Upper First Premolar: 2/2 (100.00%) of total
#     Filenames: ['WW75.jpg', 'WW85.jpg']
# 2. Lower Second Premolar: 2/2 (100.00%) of total
#     Filenames: ['WW75.jpg', 'WW85.jpg']
# 3. Upper Third Molar: 2/2 (100.00%) of total
#     Filenames: ['WW75.jpg', 'WW85.jpg']
# Filenames with the same name:
# Upper First Premolar: WW75.jpg, WW85.jpg
# Lower Second Premolar: WW75.jpg, WW85.jpg
# Upper Third Molar: WW75.jpg, WW85.jpg
# Pair: Lower Second Premolar, Upper First Premolar and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Second Premolar, Upper Lateral Incisor and Posterior border of Ramus
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Lower Second Premolar: 2/2 (100.00%) of total
#     Filenames: ['FlipW92.jpg', 'W95.jpg']
# 2. Upper Lateral Incisor: 2/2 (100.00%) of total
#     Filenames: ['FlipW92.jpg', 'W95.jpg']
# 3. Posterior border of Ramus: 2/2 (100.00%) of total
#     Filenames: ['FlipW92.jpg', 'W95.jpg']
# Filenames with the same name:
# Lower Second Premolar: Flip
jpg, FlipWW78.jpg, FlipWW79.jpg, WW80.jpg
# Lower Third Molar: W84.jpg, FlipWW78.jpg, FlipWW79.jpg, WW80.jpg
# Pair: Upper Canine, Mandibular angle and Lower Canine
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper Canine, Mandibular angle and Upper Central Incisor
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Upper Central Incisor: 1/1 (100.00%) of total
#     Filenames: ['WW80.jpg']
# 2. Upper Canine: 1/1 (100.00%) of total
#     Filenames: ['WW80.jpg']
# 3. Mandibular angle: 1/1 (100.00%) of total
#     Filenames: ['WW80.jpg']
# Filenames with the same name:
# Upper Central Incisor: WW80.jpg
# Upper Canine: WW80.jpg
# Mandibular angle: WW80.jpg
# Pair: Upper Canine, Mandibular angle and Upper Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Upper Canine: 2/2 (100.00%) of total
#     Filenames: ['FlipWW78.jpg', 'WW80.jpg']
# 2. Mandibular angle: 2/2 (100.00%) of total
#     Filenames: ['FlipWW78.jpg', 'WW80.jpg']
# 3. Upper Third Molar: 2/2 (100.00%) of total
#     Filenames: ['FlipWW78.jpg', 'WW80.jpg']
# Filenames with the same name:
# Upper Canine: FlipWW78.jpg, WW80.jpg
# Mandibular angle: FlipWW78.jpg, WW80.jpg
# Upper Third Molar: FlipWW78.jpg, WW80.jpg
# Pair: Upper Canine, Mandibular angle and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper Canine, Upper First Premolar and Upper Lateral Incisor
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Upper Canine: 2/2 (100.00%) of total
#     Filenames: ['W95.jpg', 'FlipWW78.jpg']
# 2. Upper Lateral Incisor: 2/2 (100.00%) of total
#     Filenames: ['W95.jpg', 'FlipWW78.jpg']
# 3. Upper First Premolar: 2/2 (100.00%) of total
#     Filenames: ['W95.jpg', 'FlipWW78.jpg']
# Filenames with the same name:
# Upper Canine: W95.jpg, FlipWW78.jpg
# Upper Lateral Incisor: W95.jpg, FlipWW78.jpg
# Upper First Premolar: W95.jpg, FlipWW78.jpg
# Pair: Upper Canine, Upper First Premolar and Posterior border of Ramus
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Upper Canine: 1/1 (100.00%) of total
#     Filenames: ['W95.jpg']
# 2. Posterior border of Ramus: 1/1 (100.00%) of total
#     Filenames: ['W95.jpg']
# 3. Upper First Premolar: 1/1 (100.00%) of total
#     Filenames: ['W95.jpg']
# Filenames with the same name:
# ...
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Lower First Premolar: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# 2. Condyle: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# 3. Upper Central Incisor: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# Filenames with the same name:
# Lower First Premolar: FlipWW84.jpg
# Condyle: FlipWW84.jpg
# Upper Central Incisor: FlipWW84.jpg
# Pair: Lower First Premolar, Condyle and Upper Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Lower First Premolar: 1/1 (100.00%) of total
#     Filenames: ['WW76.jpg']
# 2. Upper Third Molar: 1/1 (100.00%) of total
#     Filenames: ['WW76.jpg']
# 3. Condyle: 1/1 (100.00%) of total
#     Filenames: ['WW76.jpg']
# Filenames with the same name:
# Lower First Premolar: WW76.jpg
# Upper Third Molar: WW76.jpg
# Condyle: WW76.jpg
# Pair: Lower First Premolar, Condyle and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower First Premolar, Upper First Molar and Lower Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower First Premolar, Upper First Molar and Lower Canine
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower First Premolar, Upper First Molar and Upper Central Incisor
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower First Premolar, Upper First Molar and Upper Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Upper First Molar: 1/1 (100.00%) of total
#     Filenames: ['WW76.jpg']
# 2. Lower First Premolar: 1/1 (100.00%) of total
#     Filenames: ['WW76.jpg']
# 3. Upper Third Molar: 1/1 (100.00%) of total
#     Filenames: ['WW76.jpg']
# Filenames with the same name:
# Upper First Molar: WW76.jpg
# Lower First Premolar: WW76.jpg
# Upper Third Molar: WW76.jpg
# Pair: Lower First Premolar, Upper First Molar and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower First Premolar, Lower Third Molar and Lower Canine
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Lower First Premolar: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# 2. Lower Canine: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# 3. Lower Third Molar: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# Filenames with the same name:
# Lower First Premolar: FlipWW84.jpg
# Lower Canine: FlipWW84.jpg
# Lower Third Molar: FlipWW84.jpg
# Pair: Lower First Premolar, Lower Third Molar and Upper Central Incisor
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Lower First Premolar: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# 2. Upper Central Incisor: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# 3. Lower Third Molar: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# Filenames with the same name:
# Lower First Premolar: FlipWW84.jpg
# Upper Central Incisor: FlipWW84.jpg
# Lower Third Molar: FlipWW84.jpg
# Pair: Lower First Premolar, Lower Third Molar and Upper Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower First Premolar, Lower Third Molar and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower First Premolar, Lower Canine and Upper Central Incisor
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Lower First Premolar: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# 2. Lower Canine: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# 3. Upper Central Incisor: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# Filenames with the same name:
# Lower First Premolar: FlipWW84.jpg
# Lower Canine: FlipWW84.jpg
# Upper Central Incisor: FlipWW84.jpg
# Pair: Lower First Premolar, Lower Canine and Upper Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower First Premolar, Lower Canine and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower First Premolar, Upper Central Incisor and Upper Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower First Premolar, Upper Central Incisor and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower First Premolar, Upper Third Molar and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Condyle, Upper First Molar and Lower Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Lower Third Molar: 1/1 (100.00%) of total
#     Filenames: ['FlipW95.jpg']
# 2. Upper First Molar: 1/1 (100.00%) of total
#     Filenames: ['FlipW95.jpg']
# 3. Condyle: 1/1 (100.00%) of total
#     Filenames: ['FlipW95.jpg']
# Filenames with the same name:
# Lower Third Molar: FlipW95.jpg
# Upper First Molar: FlipW95.jpg
# Condyle: FlipW95.jpg
# Pair: Condyle, Upper First Molar and Lower Canine
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Condyle, Upper First Molar and Upper Central Incisor
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Condyle, Upper First Molar and Upper Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Upper First Molar: 2/2 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'WW76.jpg']
# 2. Condyle: 2/2 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'WW76.jpg']
# 3. Upper Third Molar: 2/2 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'WW76.jpg']
# Filenames with the same name:
# Upper First Molar: FlipW95.jpg, WW76.jpg
# Condyle: FlipW95.jpg, WW76.jpg
# Upper Third Molar: FlipW95.jpg, WW76.jpg
# Pair: Condyle, Upper First Molar and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Upper First Molar: 1/1 (100.00%) of total
#     Filenames: ['FlipW97.jpg']
# 2. Nasal: 1/1 (100.00%) of total
#     Filenames: ['FlipW97.jpg']
# 3. Condyle: 1/1 (100.00%) of total
#     Filenames: ['FlipW97.jpg']
# Filenames with the same name:
# Upper First Molar: FlipW97.jpg
# Nasal: FlipW97.jpg
# Condyle: FlipW97.jpg
# Pair: Condyle, Lower Third Molar and Lower Canine
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Condyle: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# 2. Lower Canine: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# 3. Lower Third Molar: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# Filenames with the same name:
# Condyle: FlipWW84.jpg
# Lower Canine: FlipWW84.jpg
# Lower Third Molar: FlipWW84.jpg
# Pair: Condyle, Lower Third Molar and Upper Central Incisor
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Condyle: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# 2. Upper Central Incisor: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# 3. Lower Third Molar: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# Filenames with the same name:
# Condyle: FlipWW84.jpg
# Upper Central Incisor: FlipWW84.jpg
# Lower Third Molar: FlipWW84.jpg
# Pair: Condyle, Lower Third Molar and Upper Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Lower Third Molar: 2/2 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'WW85.jpg']
# 2. Condyle: 2/2 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'WW85.jpg']
# 3. Upper Third Molar: 2/2 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'WW85.jpg']
# Filenames with the same name:
# Lower Third Molar: FlipW95.jpg, WW85.jpg
# Condyle: FlipW95.jpg, WW85.jpg
# Upper Third Molar: FlipW95.jpg, WW85.jpg
# Pair: Condyle, Lower Third Molar and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Condyle, Lower Canine and Upper Central Incisor
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Condyle: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# 2. Lower Canine: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# 3. Upper Central Incisor: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# Filenames with the same name:
# Condyle: FlipWW84.jpg
# Lower Canine: FlipWW84.jpg
# Upper Central Incisor: FlipWW84.jpg
# Pair: Condyle, Lower Canine and Upper Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Condyle, Lower Canine and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Condyle, Upper Central Incisor and Upper Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Condyle, Upper Central Incisor and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Condyle, Upper Third Molar and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper First Molar, Lower Third Molar and Lower Canine
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper First Molar, Lower Third Molar and Upper Central Incisor
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Lower Third Molar: 4/4 (100.00%) of total
#     Filenames: ['WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg', 'WW88.jpg']
# 2. Upper First Molar: 4/4 (100.00%) of total
#     Filenames: ['WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg', 'WW88.jpg']
# 3. Upper Central Incisor: 4/4 (100.00%) of total
#     Filenames: ['WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg', 'WW88.jpg']
# Filenames with the same name:
# Lower Third Molar: WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg
# Upper First Molar: WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg
# Upper Central Incisor: WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg
# Pair: Upper First Molar, Lower Third Molar and Upper Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Lower Third Molar: 6/6 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'FlipWW78.jpg', 'WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg', 'WW88.jpg']
# 2. Upper First Molar: 6/6 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'FlipWW78.jpg', 'WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg', 'WW88.jpg']
# 3. Upper Third Molar: 6/6 (100.00%) of total
#     Filenames: ['FlipW95.jpg', 'FlipWW78.jpg', 'WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg', 'WW88.jpg']
# Filenames with the same name:
# Lower Third Molar: FlipW95.jpg, FlipWW78.jpg, WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg
# Upper First Molar: FlipW95.jpg, FlipWW78.jpg, WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg
# Upper Third Molar: FlipW95.jpg, FlipWW78.jpg, WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg
# Pair: Upper First Molar, Lower Third Molar and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper First Molar, Lower Canine and Upper Central Incisor
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper First Molar, Lower Canine and Upper Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper First Molar, Lower Canine and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper First Molar, Upper Central Incisor and Upper Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Upper First Molar: 4/4 (100.00%) of total
#     Filenames: ['WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg', 'WW88.jpg']
# 2. Upper Central Incisor: 4/4 (100.00%) of total
#     Filenames: ['WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg', 'WW88.jpg']
# 3. Upper Third Molar: 4/4 (100.00%) of total
#     Filenames: ['WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg', 'WW88.jpg']
# Filenames with the same name:
# Upper First Molar: WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg
# Upper Central Incisor: WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg
# Upper Third Molar: WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg
# Pair: Upper First Molar, Upper Central Incisor and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper First Molar, Upper Third Molar and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Third Molar, Lower Canine and Upper Central Incisor
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Lower Canine: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# 2. Upper Central Incisor: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# 3. Lower Third Molar: 1/1 (100.00%) of total
#     Filenames: ['FlipWW84.jpg']
# Filenames with the same name:
# Lower Canine: FlipWW84.jpg
# Upper Central Incisor: FlipWW84.jpg
# Lower Third Molar: FlipWW84.jpg
# Pair: Lower Third Molar, Lower Canine and Upper Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Third Molar, Lower Canine and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Third Molar, Upper Central Incisor and Upper Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 3
# 1. Lower Third Molar: 4/4 (100.00%) of total
#     Filenames: ['WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg', 'WW88.jpg']
# 2. Upper Central Incisor: 4/4 (100.00%) of total
#     Filenames: ['WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg', 'WW88.jpg']
# 3. Upper Third Molar: 4/4 (100.00%) of total
#     Filenames: ['WW80.jpg', 'FlipWW80.jpg', 'WW82.jpg', 'WW88.jpg']
# Filenames with the same name:
# Lower Third Molar: WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg
# Upper Central Incisor: WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg
# Upper Third Molar: WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg
# Pair: Lower Third Molar, Upper Central Incisor and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Third Molar, Upper Third Molar and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Canine, Upper Central Incisor and Upper Third Molar
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Canine, Upper Central Incisor and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Lower Canine, Upper Third Molar and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:
# Pair: Upper Central Incisor, Upper Third Molar and Nasal
# Unique names and their occurrences in posative SHAP values area:
# Total Unique Names: 0
# Filenames with the same name:

# %%
# Optional: Create a DataFrame to keep all the information together
age_pos = []
for (name1, name2, name3), result in pair_results.items():
    for name, count in result['sorted_names']:
      if name in name1 and name2 in name2:
        age_pos.append({
            'name': name,
            'second': name2, #'pair': f"{name1} and {name2}"
            'third': name3,
            'count': count,
            'total_1': len(age_9_pos[age_9_pos['name']== name1]),
            'percentage_1':  f"{(count / len(age_9_pos[age_9_pos['name']== name1])) * 100 :.2f}%",
            'total_2': len(age_9_pos[age_9_pos['name']== name2]),
            'percentage_2':  f"{(count / len(age_9_pos[age_9_pos['name']== name2])) * 100 :.2f}%",
            'total_3': len(age_9_pos[age_9_pos['name']== name3]),
            'percentage_3':  f"{(count / len(age_9_pos[age_9_pos['name']== name3])) * 100 :.2f}%",
            'total_files': len(age_9_pos['filename'].unique()),
            'percentage_files':  f"{(count / len(age_9_pos['filename'].unique())) * 100 :.2f}%",
            'filenames': result['name_files'][name]
        })

pos_3 = pd.DataFrame(age_pos)
pos_3
# Out:
#                    name                 second                  third  count  \
# 0    Lower Second Molar  Upper Second Premolar  Lower Second Premolar      4
# 1    Lower Second Molar  Upper Second Premolar           Upper Canine      7
# 2    Lower Second Molar  Upper Second Premolar       Mandibular angle      2
# 3    Lower Second Molar  Upper Second Premolar   Upper First Premolar      2
# 4    Lower Second Molar  Upper Second Premolar  Upper Lateral Incisor      3
# ..                  ...                    ...                    ...    ...
# 510   Upper First Molar      Lower Third Molar  Upper Central Incisor      4
# 511   Upper First Molar      Lower Third Molar      Upper Third Molar      6
# 512   Upper First Molar  Upper Central Incisor      Upper Third Molar      4
# 513   Lower Third Molar           Lower Canine  Upper Central Incisor      1
# 514   Lower Third Molar  Upper Central Incisor      Upper Third Molar      4
#
#      total_1 percentage_1  total_2 percentage_2  total_3 percentage_3  \
# 0         24       16.67%       11       36.36%       11       36.36%
# 1         24       29.17%       11       63.64%       15       46.67%
# 2         24        8.33%       11       18.18%        6       33.33%
# 3         24        8.33%       11       18.18%       10       20.00%
# 4         24       12.50%       11       27.27%        7       42.86%
# ..       ...          ...      ...          ...      ...          ...
# 510       13       30.77%       20       20.00%        7       57.14%
# 511       13       46.15%       20       30.00%       12       50.00%
# 512       13       30.77%        7       57.14%       12       33.33%
# 513       20        5.00%        1      100.00%        7       14.29%
# 514       20       20.00%        7       57.14%       12       33.33%
#
#      total_files percentage_files  \
# 0             32           12.50%
# 1             32           21.88%
# 2             32            6.25%
# 3             32            6.25%
# 4             32            9.38%
# ..           ...              ...
# 510           32           12.50%
# 511           32           18.75%
# 512           32           12.50%
# 513           32            3.12%
# 514           32           12.50%
#
#                                              filenames
# 0       [FlipW97.jpg, FlipW90.jpg, WW76.jpg, WW81.jpg]
# 1    [W84.jpg, FlipW97.jpg, WW79.jpg, WW81.jpg, WW8...
# 2                                  [W84.jpg, WW79.jpg]
# 3                                 [WW79.jpg, WW81.jpg]
# 4                    [W84.jpg, WW82.jpg, FlipWW84.jpg]
# ..                                                 ...
# 510       [WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg]
# 511  [FlipW95.jpg, FlipWW78.jpg, WW80.jpg, FlipWW80...
# 512       [WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg]
# 513                                     [FlipWW84.jpg]
# 514       [WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg]
#
# [515 rows x 13 columns]

# %%
percentage = pos_3['percentage_files'].tolist()
# Convert to a list of integers
pos_3['percentage_float'] = [float(p.replace('%', '')) for p in percentage]

# %%
pos_3
# Out:
#                    name                 second                  third  count  \
# 0    Lower Second Molar  Upper Second Premolar  Lower Second Premolar      4
# 1    Lower Second Molar  Upper Second Premolar           Upper Canine      7
# 2    Lower Second Molar  Upper Second Premolar       Mandibular angle      2
# 3    Lower Second Molar  Upper Second Premolar   Upper First Premolar      2
# 4    Lower Second Molar  Upper Second Premolar  Upper Lateral Incisor      3
# ..                  ...                    ...                    ...    ...
# 510   Upper First Molar      Lower Third Molar  Upper Central Incisor      4
# 511   Upper First Molar      Lower Third Molar      Upper Third Molar      6
# 512   Upper First Molar  Upper Central Incisor      Upper Third Molar      4
# 513   Lower Third Molar           Lower Canine  Upper Central Incisor      1
# 514   Lower Third Molar  Upper Central Incisor      Upper Third Molar      4
#
#      total_1 percentage_1  total_2 percentage_2  total_3 percentage_3  \
# 0         24       16.67%       11       36.36%       11       36.36%
# 1         24       29.17%       11       63.64%       15       46.67%
# 2         24        8.33%       11       18.18%        6       33.33%
# 3         24        8.33%       11       18.18%       10       20.00%
# 4         24       12.50%       11       27.27%        7       42.86%
# ..       ...          ...      ...          ...      ...          ...
# 510       13       30.77%       20       20.00%        7       57.14%
# 511       13       46.15%       20       30.00%       12       50.00%
# 512       13       30.77%        7       57.14%       12       33.33%
# 513       20        5.00%        1      100.00%        7       14.29%
# 514       20       20.00%        7       57.14%       12       33.33%
#
#      total_files percentage_files  \
# 0             32           12.50%
# 1             32           21.88%
# 2             32            6.25%
# 3             32            6.25%
# 4             32            9.38%
# ..           ...              ...
# 510           32           12.50%
# 511           32           18.75%
# 512           32           12.50%
# 513           32            3.12%
# 514           32           12.50%
#
#                                              filenames  percentage_float
# 0       [FlipW97.jpg, FlipW90.jpg, WW76.jpg, WW81.jpg]             12.50
# 1    [W84.jpg, FlipW97.jpg, WW79.jpg, WW81.jpg, WW8...             21.88
# 2                                  [W84.jpg, WW79.jpg]              6.25
# 3                                 [WW79.jpg, WW81.jpg]              6.25
# 4                    [W84.jpg, WW82.jpg, FlipWW84.jpg]              9.38
# ..                                                 ...               ...
# 510       [WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg]             12.50
# 511  [FlipW95.jpg, FlipWW78.jpg, WW80.jpg, FlipWW80...             18.75
# 512       [WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg]             12.50
# 513                                     [FlipWW84.jpg]              3.12
# 514       [WW80.jpg, FlipWW80.jpg, WW82.jpg, WW88.jpg]             12.50
#
# [515 rows x 14 columns]

# %%
pos_3_sort =  pos_3.sort_values(by='percentage_float', ascending=False)

# %%
pos_3_sort
# Out:
#                       name                     second                  third  \
# 84      Lower Second Molar         Upper Second Molar      Lower Third Molar
# 308           Upper Canine         Upper Second Molar      Lower Third Molar
# 34      Lower Second Molar               Upper Canine     Upper Second Molar
# 89      Lower Second Molar          Lower First Molar                Condyle
# 307           Upper Canine         Upper Second Molar      Upper First Molar
# ..                     ...                        ...                    ...
# 345       Mandibular angle      Upper Lateral Incisor      Lower First Molar
# 346       Mandibular angle      Upper Lateral Incisor                Condyle
# 347       Mandibular angle      Upper Lateral Incisor      Upper First Molar
# 168  Upper Second Premolar  Posterior border of Ramus  Upper Central Incisor
# 87      Lower Second Molar         Upper Second Molar                  Nasal
#
#      count  total_1 percentage_1  total_2 percentage_2  total_3 percentage_3  \
# 84      12       24       50.00%       23       52.17%       20       60.00%
# 308     11       15       73.33%       23       47.83%       20       55.00%
# 34      10       24       41.67%       15       66.67%       23       43.48%
# 89       9       24       37.50%       14       64.29%       15       60.00%
# 307      9       15       60.00%       23       39.13%       13       69.23%
# ..     ...      ...          ...      ...          ...      ...          ...
# 345      1        6       16.67%        7       14.29%       14        7.14%
# 346      1        6       16.67%        7       14.29%       15        6.67%
# 347      1        6       16.67%        7       14.29%       13        7.69%
# 168      1       11        9.09%        7       14.29%        7       14.29%
# 87       1       24        4.17%       23        4.35%        1      100.00%
#
#      total_files percentage_files  \
# 84            32           37.50%
# 308           32           34.38%
# 34            32           31.25%
# 89            32           28.12%
# 307           32           28.12%
# ..           ...              ...
# 345           32            3.12%
# 346           32            3.12%
# 347           32            3.12%
# 168           32            3.12%
# 87            32            3.12%
#
#                                              filenames  percentage_float
# 84   [W84.jpg, FlipW92.jpg, W95.jpg, W86.jpg, FlipW...             37.50
# 308  [W84.jpg, W95.jpg, FlipW95.jpg, FlipWW78.jpg, ...             34.38
# 34   [W84.jpg, W95.jpg, FlipW97.jpg, FlipWW78.jpg, ...             31.25
# 89   [FlipW87.jpg, W91.jpg, FlipW91.jpg, W88.jpg, W...             28.12
# 307  [FlipW95.jpg, FlipW97.jpg, FlipWW78.jpg, WW79....             28.12
# ..                                                 ...               ...
# 345                                     [FlipWW78.jpg]              3.12
# 346                                          [W84.jpg]              3.12
# 347                                     [FlipWW78.jpg]              3.12
# 168                                     [FlipWW84.jpg]              3.12
# 87                                       [FlipW97.jpg]              3.12
#
# [515 rows x 14 columns]

# %%
table = pos_3_sort.reset_index()
table = table.iloc[:,1:]
table
# Out:
#                       name                     second                  third  \
# 0       Lower Second Molar         Upper Second Molar      Lower Third Molar
# 1             Upper Canine         Upper Second Molar      Lower Third Molar
# 2       Lower Second Molar               Upper Canine     Upper Second Molar
# 3       Lower Second Molar          Lower First Molar                Condyle
# 4             Upper Canine         Upper Second Molar      Upper First Molar
# ..                     ...                        ...                    ...
# 510       Mandibular angle      Upper Lateral Incisor      Lower First Molar
# 511       Mandibular angle      Upper Lateral Incisor                Condyle
# 512       Mandibular angle      Upper Lateral Incisor      Upper First Molar
# 513  Upper Second Premolar  Posterior border of Ramus  Upper Central Incisor
# 514     Lower Second Molar         Upper Second Molar                  Nasal
#
#      count  total_1 percentage_1  total_2 percentage_2  total_3 percentage_3  \
# 0       12       24       50.00%       23       52.17%       20       60.00%
# 1       11       15       73.33%       23       47.83%       20       55.00%
# 2       10       24       41.67%       15       66.67%       23       43.48%
# 3        9       24       37.50%       14       64.29%       15       60.00%
# 4        9       15       60.00%       23       39.13%       13       69.23%
# ..     ...      ...          ...      ...          ...      ...          ...
# 510      1        6       16.67%        7       14.29%       14        7.14%
# 511      1        6       16.67%        7       14.29%       15        6.67%
# 512      1        6       16.67%        7       14.29%       13        7.69%
# 513      1       11        9.09%        7       14.29%        7       14.29%
# 514      1       24        4.17%       23        4.35%        1      100.00%
#
#      total_files percentage_files  \
# 0             32           37.50%
# 1             32           34.38%
# 2             32           31.25%
# 3             32           28.12%
# 4             32           28.12%
# ..           ...              ...
# 510           32            3.12%
# 511           32            3.12%
# 512           32            3.12%
# 513           32            3.12%
# 514           32            3.12%
#
#                                              filenames  percentage_float
# 0    [W84.jpg, FlipW92.jpg, W95.jpg, W86.jpg, FlipW...             37.50
# 1    [W84.jpg, W95.jpg, FlipW95.jpg, FlipWW78.jpg, ...             34.38
# 2    [W84.jpg, W95.jpg, FlipW97.jpg, FlipWW78.jpg, ...             31.25
# 3    [FlipW87.jpg, W91.jpg, FlipW91.jpg, W88.jpg, W...             28.12
# 4    [FlipW95.jpg, FlipW97.jpg, FlipWW78.jpg, WW79....             28.12
# ..                                                 ...               ...
# 510                                     [FlipWW78.jpg]              3.12
# 511                                          [W84.jpg]              3.12
# 512                                     [FlipWW78.jpg]              3.12
# 513                                     [FlipWW84.jpg]              3.12
# 514                                      [FlipW97.jpg]              3.12
#
# [515 rows x 14 columns]

# %%
table.to_csv('/content/gdrive/My Drive/Tooth_Shap_GPT/Deep_tooth/OPG_SHAPer/Result/Age/95_percentie/Pos_9/(3)ALL_.csv', index=False)

# %%
table[table['percentage_float']>=50.00]
# Out:
# Empty DataFrame
# Columns: [name, second, third, count, total_1, percentage_1, total_2, percentage_2, total_3, percentage_3, total_files, percentage_files, filenames, percentage_float]
# Index: []

# %%
# table = table[table['percentage_float']>=50.00]
# table

# %%
table = table.iloc[:10,] #top 10
table
# Out:
#                     name              second               third  count  \
# 0     Lower Second Molar  Upper Second Molar   Lower Third Molar     12
# 1           Upper Canine  Upper Second Molar   Lower Third Molar     11
# 2     Lower Second Molar        Upper Canine  Upper Second Molar     10
# 3     Lower Second Molar   Lower First Molar             Condyle      9
# 4           Upper Canine  Upper Second Molar   Upper First Molar      9
# 5     Lower Second Molar  Upper Second Molar   Lower First Molar      9
# 6     Lower Second Molar        Upper Canine   Lower Third Molar      9
# 7     Lower Second Molar  Upper Second Molar   Upper First Molar      9
# 8     Upper Second Molar   Lower Third Molar   Upper Third Molar      8
# 9  Upper Second Premolar        Upper Canine  Upper Second Molar      8
#
#    total_1 percentage_1  total_2 percentage_2  total_3 percentage_3  \
# 0       24       50.00%       23       52.17%       20       60.00%
# 1       15       73.33%       23       47.83%       20       55.00%
# 2       24       41.67%       15       66.67%       23       43.48%
# 3       24       37.50%       14       64.29%       15       60.00%
# 4       15       60.00%       23       39.13%       13       69.23%
# 5       24       37.50%       23       39.13%       14       64.29%
# 6       24       37.50%       15       60.00%       20       45.00%
# 7       24       37.50%       23       39.13%       13       69.23%
# 8       23       34.78%       20       40.00%       12       66.67%
# 9       11       72.73%       15       53.33%       23       34.78%
#
#    total_files percentage_files  \
# 0           32           37.50%
# 1           32           34.38%
# 2           32           31.25%
# 3           32           28.12%
# 4           32           28.12%
# 5           32           28.12%
# 6           32           28.12%
# 7           32           28.12%
# 8           32           25.00%
# 9           32           25.00%
#
#                                            filenames  percentage_float
# 0  [W84.jpg, FlipW92.jpg, W95.jpg, W86.jpg, FlipW...             37.50
# 1  [W84.jpg, W95.jpg, FlipW95.jpg, FlipWW78.jpg, ...             34.38
# 2  [W84.jpg, W95.jpg, FlipW97.jpg, FlipWW78.jpg, ...             31.25
# 3  [FlipW87.jpg, W91.jpg, FlipW91.jpg, W88.jpg, W...             28.12
# 4  [FlipW95.jpg, FlipW97.jpg, FlipWW78.jpg, WW79....             28.12
# 5  [FlipW91.jpg, FlipW92.jpg, W95.jpg, W88.jpg, W...             28.12
# 6  [W84.jpg, W95.jpg, FlipWW78.jpg, WW81.jpg, Fli...             28.12
# 7  [FlipW91.jpg, W88.jpg, FlipW97.jpg, FlipWW78.j...             28.12
# 8  [FlipW95.jpg, W86.jpg, FlipWW78.jpg, WW80.jpg,...             25.00
# 9  [W84.jpg, FlipW95.jpg, FlipW97.jpg, WW79.jpg, ...             25.00

# %%
table = table.iloc[:,:-1]
table
# Out:
#                     name              second               third  count  \
# 0     Lower Second Molar  Upper Second Molar   Lower Third Molar     12
# 1           Upper Canine  Upper Second Molar   Lower Third Molar     11
# 2     Lower Second Molar        Upper Canine  Upper Second Molar     10
# 3     Lower Second Molar   Lower First Molar             Condyle      9
# 4           Upper Canine  Upper Second Molar   Upper First Molar      9
# 5     Lower Second Molar  Upper Second Molar   Lower First Molar      9
# 6     Lower Second Molar        Upper Canine   Lower Third Molar      9
# 7     Lower Second Molar  Upper Second Molar   Upper First Molar      9
# 8     Upper Second Molar   Lower Third Molar   Upper Third Molar      8
# 9  Upper Second Premolar        Upper Canine  Upper Second Molar      8
#
#    total_1 percentage_1  total_2 percentage_2  total_3 percentage_3  \
# 0       24       50.00%       23       52.17%       20       60.00%
# 1       15       73.33%       23       47.83%       20       55.00%
# 2       24       41.67%       15       66.67%       23       43.48%
# 3       24       37.50%       14       64.29%       15       60.00%
# 4       15       60.00%       23       39.13%       13       69.23%
# 5       24       37.50%       23       39.13%       14       64.29%
# 6       24       37.50%       15       60.00%       20       45.00%
# 7       24       37.50%       23       39.13%       13       69.23%
# 8       23       34.78%       20       40.00%       12       66.67%
# 9       11       72.73%       15       53.33%       23       34.78%
#
#    total_files percentage_files  \
# 0           32           37.50%
# 1           32           34.38%
# 2           32           31.25%
# 3           32           28.12%
# 4           32           28.12%
# 5           32           28.12%
# 6           32           28.12%
# 7           32           28.12%
# 8           32           25.00%
# 9           32           25.00%
#
#                                            filenames
# 0  [W84.jpg, FlipW92.jpg, W95.jpg, W86.jpg, FlipW...
# 1  [W84.jpg, W95.jpg, FlipW95.jpg, FlipWW78.jpg, ...
# 2  [W84.jpg, W95.jpg, FlipW97.jpg, FlipWW78.jpg, ...
# 3  [FlipW87.jpg, W91.jpg, FlipW91.jpg, W88.jpg, W...
# 4  [FlipW95.jpg, FlipW97.jpg, FlipWW78.jpg, WW79....
# 5  [FlipW91.jpg, FlipW92.jpg, W95.jpg, W88.jpg, W...
# 6  [W84.jpg, W95.jpg, FlipWW78.jpg, WW81.jpg, Fli...
# 7  [FlipW91.jpg, W88.jpg, FlipW97.jpg, FlipWW78.j...
# 8  [FlipW95.jpg, W86.jpg, FlipWW78.jpg, WW80.jpg,...
# 9  [W84.jpg, FlipW95.jpg, FlipW97.jpg, WW79.jpg, ...

# %%
table.to_csv('/content/gdrive/My Drive/Tooth_Shap_GPT/Deep_tooth/OPG_SHAPer/Result/Age/95_percentie/Pos_9/(3)ALL_(top10).csv', index=False)
